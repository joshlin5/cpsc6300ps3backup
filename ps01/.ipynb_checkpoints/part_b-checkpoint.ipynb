# %% [markdown]
# # CPSC 4300/6300-001 Applied Data Science (Fall 2020)
#
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Joshua Lin"
COLLABORATORS = ""

# %% [markdown]
# # CPSC4300/6300-001 Problem Set #1

# %% [markdown]
# In this assignment, you will create a NCAA College Football team dataset by scraping data from the Internet and perform some basic data manipulations. The assignment has four parts: the first three are auto-graded. Th elast part is manually graded by the TA.
#
# Before submission, make sure you run all the cells. Because the TA could not run your notebook, your grade will be only based on the output and the writing part of your submitted notebook.

# %% [markdown]
# ## Part B: Scape the Rosters of Any NCAA Collge Football Team (50 points)
#
# During the class, we have shown how to extract the roster of the Clemson Tiger's defense team, now we want to extend the work to apply to the entire team roster of any NCAA coolege football teams.

# %% [markdown]
# ### Question 1. Wriet a function to computer the Team URL
#
# Look at the URLs of server college football team at the ESPN site, generalize the pattern, and write a python function  `get_team_url(team_id, team_name)` to compute a url from team_id and team_name. (4 points)

# %%
def get_team_url(team_id, team_name):
    """
    Get the team URL for a NCAA college football team
    
    Args:
        team_id: the id of a NACC football team assigned by ESPN
        team_name: the name of the football team
        
    Returns:
        team_url: a string representing the URL of the team
    """
    # YOUR CODE HERE
    #raise NotImplementedError()
    url = "https://www.espn.com/college-football/team/roster/_/id/" + str(team_id) + "/"
    real_team_name = team_name.split( )
    #print(real_team_name)
    i = 1
    while (len(real_team_name) > i):     
        url = url + real_team_name[i-1].lower()+"-"
        i = i + 1
    else: 
        url = url + real_team_name[i-1].lower()
    #print(url)
    return url

# %%
team_id = 228
team_name = "Clemson Tigers"
team_url = get_team_url(team_id, team_name)
assert team_url == 'https://www.espn.com/college-football/team/roster/_/id/228/clemson-tigers'

# %%
# This cell contains some hidden test cases.

# %% [markdown]
# ### Question 2. Create a BeautifulSoup Object
#
# Complete the following code to create a BeautifulSoup Object from a team url and name the object `soup`. (4 points)

# %%
import requests
import re
from bs4 import BeautifulSoup
from requests.exceptions import HTTPError

url = get_team_url(228, "Clemson Tigers")

# YOUR CODE HERE
#raise NotImplementedError()
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html, 'html.parser')
#soup

# %%
assert (type(soup) == BeautifulSoup)

# %%
assert soup.find('title').text.startswith('Clemson')

# %% [markdown]
# ### Question 3. Find the Team Name
#
# Write a statement to find a tag whose text is formatted as "{Team Name} Rosters" on the page. The {Team Name} would be the actual team name like 'Clemson Tigers'. (2 points)

# %%
# YOUR CODE HERE
#raise NotImplementedError()
team_tag = soup.find('h1', string=re.compile(' Roster$'))

# %%
assert str(type(team_tag)) == "<class 'bs4.element.Tag'>" and team_tag.text.endswith("Roster")

# %% [markdown]
# ### Question 5. Search for Team Groups
#
# A football team roster is usually divied into three groups: *Offense*, *Defense*, and *Special Teams*. Write some statements to find the tags for all these three groups and save the tags into a variable called groups. (2 points)

# %%
# YOUR CODE HERE
#raise NotImplementedError()
groups = soup.find_all(class_="Table__Title", string=["Offense", "Defense", "Special Teams"])
print(len(groups), "groups")
for g in groups:
    print(g)
# Out:
# 3 groups
# <div class="Table__Title">Offense</div>
# <div class="Table__Title">Defense</div>
# <div class="Table__Title">Special Teams</div>

# %%
assert ','.join(sorted([g.text for g in groups])) == 'Defense,Offense,Special Teams'

# %%
assert len(groups) == 3

# %% [markdown]
# ### Question 6. Find the Column Names
#
# Complete the code segment to extract the names of the columns in a table rows and save those names into a list named col_names. (4 points)

# %%
col_names = []
for g in groups:
    t = g.find_next("table")
    for c in t.thead.tr.children:
        col_names.append(c.text)
# YOUR CODE HERE
#raise NotImplementedError()
#col_names

# %%
assert "Name" in col_names and "Class" in col_names

# %%
assert type(col_names) is list and len(col_names) >= 6

# %% [markdown]
# ### Question 7. Find the Attributes of a Player
#
# Write code segment to extract the attributes of the first defense player and save them into a dict. The player should have the attributes as shown in the following example.
# ```
# player_name: Lannden Zanders
# player_id: 4428971
# player_no: 36
# POS: S
# HT: 6' 1"
# WT: 195 lbs
# Class: SO
# Birthplace: Shelby, NC
# ```
# (10 points)

# %%
player = {}
players = []
# YOUR CODE HERE
#raise NotImplementedError()
table = groups[1].find_next("table")
def is_player_row(tag):
    if tag.name == 'tr' and tag.has_attr('data-idx'):
        return True
    return False
for c in table.tbody.find_all(is_player_row):
    tds = c.find_all('td')
    #print(tds)
    cols = []
    for td in tds:
        cols.append(td.get_text())
    players.append(cols)
    
def mysplit(s, ex):
    head = s.rstrip(ex)
    tail = s[len(head):]
    return head, tail

name = mysplit(players[-1][1], '0123456789')
player["player_name"] = name[0]

player_url_name = name[0].split()
totalURL = ""
i = 1
for x in player_url_name :
    if i != len(player_url_name) :
        if x.find(".") :
            x = x.replace('.', '') 
        totalURL = totalURL + x.lower() + "-"
    else :
        if x.find(".") :
            x = x.replace('.', '')
        totalURL = totalURL + x.lower()
    i = i + 1
totalURL = '/' + totalURL

id = soup.find('a', href=re.compile(totalURL))['href']
id = re.sub('http://www.espn.com/college-football/player/_/id/', '', id)
id = re.sub(totalURL, '', id)

player["player_id"] = id
player["player_no"] = name[1]
player["POS"] = players[-1][2]
player["HT"] = players[-1][3]
player["WT"] = players[-1][4]
player["Class"] = players[-1][5]
player["Birthplace"] = players[-1][6]
print(player)
# Out:
# {'player_name': 'Lannden Zanders', 'player_id': '4428971', 'player_no': '36', 'POS': 'S', 'HT': '6\' 1"', 'WT': '200 lbs', 'Class': 'SO', 'Birthplace': 'Shelby, NC'}

# %%
assert type(player) is dict

# %%
assert len(player) == 8

# %%
assert ','.join(sorted(player.keys())) == 'Birthplace,Class,HT,POS,WT,player_id,player_name,player_no'

# %%
assert int(player['player_no']) > 0 and int(player['player_no']) < 200

# %%
assert int(player['WT'].split()[0]) > 150 and player['WT'].split()[1] == 'lbs'

# %% [markdown]
# ### Question 8. Abstract the tasks into a function
#
# Since you don't want to repeat the above steps for every player and every team, it is necessary to abstract the above scraping task into a function which you can reuse over and over. (10 points)

# %%
import requests
import re
from requests.exceptions import HTTPError
from bs4 import BeautifulSoup

def extract_team_roster(team_id, team_name):
    """
    Extract the team roster for a NCAA college football team
    
    Args:
        team_id: the id of a NACC football team assigned by ESPN
        team_name: the name of the football team
        
    Returns:
        a list of dict representing the roster of the entire team.
    """
    print("wrong")
    #team_id = 150
    #team_name = "Duke Blue Devils"
    roster = []
    def mysplit(s, ex):
        head = s.rstrip(ex)
        tail = s[len(head):]
        return head, tail
    
    def is_player_row(tag):
        if tag.name == 'tr' and tag.has_attr('data-idx'):
            return True
        return False
    
    #Computing Team URL
    url = "https://www.espn.com/college-football/team/roster/_/id/" + str(team_id) + "/"
    real_team_name = team_name.split( )
    #print(real_team_name)
    i = 1
    while (len(real_team_name) > i):     
        url = url + real_team_name[i-1].lower()+"-"
        i = i + 1
    else: 
        url = url + real_team_name[i-1].lower()

    #Create a BeautifulSoup Object
    response = requests.get(url)
    html = response.content
    soup = BeautifulSoup(html, 'html.parser')
        
    #Finding Team Name
    team_tag = soup.find('h1', string=re.compile(' Roster$'))
        
    #Searching For Team Group
    groups = soup.find_all(class_="Table__Title", string=["Offense", "Defense", "Special Teams"])
    #print(len(groups), "groups")
    #for g in groups:
        #print(g)
        
    #Finding the Column Names
    col_names = []
    for g in groups:
        t = g.find_next("table")
        for c in t.thead.tr.children:
            col_names.append(c.text)
        
    #Find the Attributes of a Player
    players = []
    id_list = []
    for x in groups :
        table = x.find_next("table")
        for c in table.tbody.find_all(is_player_row):
            tds = c.find_all('td')
            cols = []
            for td in tds:
                cols.append(td.get_text())
            players.append(cols)
        for aPlayer in players :
            player = {}
            name = mysplit(aPlayer[1], '0123456789')
            player["player_name"] = name[0]

            player_url_name = name[0].split()
            totalURL = ""
            i = 1
            for x in player_url_name :
                if i != len(player_url_name) :
                    if x.find(".") :
                        x = x.replace('.', '') 
                    if x.find('\'') :
                        x = x.replace('\'', '') 
                    totalURL = totalURL + x.lower() + "-"
                else :
                    if x.find(".") :
                        x = x.replace('.', '')
                    if x.find('\'') :
                        x = x.replace('\'', '') 
                    totalURL = totalURL + x.lower()
                i = i + 1
            totalURL = '/' + totalURL
            #print(totalURL)
            #print(soup.find('a', href=re.compile(totalURL))['href'])
            id = soup.find('a', href=re.compile(totalURL))['href']
            id = re.sub('http://www.espn.com/college-football/player/_/id/', '', id)
            id = re.sub(totalURL, '', id)
            if id_list.count(id) == 0: 
                id_list.append(id)
                player["player_id"] = id
                if name[1] == '' :
                    player["player_no"] = "NA"
                else :
                    player["player_no"] = name[1]
                player["POS"] = aPlayer[2]
                player["HT"] = aPlayer[3]
                player["WT"] = aPlayer[4]
                player["Class"] = aPlayer[5]
                player["Birthplace"] = aPlayer[6]
                #print(player)
                roster.append(player)
        
    # YOUR CODE HERE
    #raise NotImplementedError()
    return roster

# %%
import pprint
import numpy as np
team_name = "Virginia Cavaliers"
team_id = 258
team_roster = extract_team_roster(team_id, team_name)
pp = pprint.PrettyPrinter(indent=4)
#pp.pprint(team_roster)
player_ids = np.array([p['player_id'] for p in team_roster])
unqiue_ids = np.unique(player_ids)
#assert len(unqiue_ids) == len(team_roster)
#print(len(unqiue_ids))
#print(len(team_roster))
player_nos = np.array([p['player_no'] for p in team_roster])
na_count = len([no for no in player_nos if no == 'NA'])
print(na_count)
#assert na_count > 10
# Out:
# wrong
# 45

# %%
# test the function
import pprint

team_id = 150
team_name = "Duke Blue Devils"
team_roster = extract_team_roster(team_id, team_name)

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(team_roster[:3])
# Out:
# wrong
# [   {   'Birthplace': 'Grayson, GA',
#         'Class': 'JR',
#         'HT': '6\' 3"',
#         'POS': 'QB',
#         'WT': '235 lbs',
#         'player_id': '4239994',
#         'player_name': 'Chase Brice',
#         'player_no': '8'},
#     {   'Birthplace': 'Langhorne, PA',
#         'Class': 'SO',
#         'HT': '6\' 3"',
#         'POS': 'QB',
#         'WT': '190 lbs',
#         'player_id': '4568231',
#         'player_name': 'Jack Colyar',
#         'player_no': '13'},
#     {   'Birthplace': 'Venice, CA',
#         'Class': 'FR',
#         'HT': '6\' 3"',
#         'POS': 'QB',
#         'WT': '180 lbs',
#         'player_id': '4429578',
#         'player_name': 'Luca Diamont',
#         'player_no': '2'}]

# %%
type(team_roster) is list
# Out:
# True

# %%
assert len(team_roster) >= 80

# %%
assert ','.join(sorted(team_roster[50].keys())) == 'Birthplace,Class,HT,POS,WT,player_id,player_name,player_no'

# %%
import numpy as np
classes = np.array([p['Class'] for p in team_roster])
class_labels, class_counts = np.unique(classes, return_counts=True)
assert ''.join(class_labels.tolist()) == 'FRJRSOSR'

# %%
import numpy as np
player_ids = np.array([p['player_id'] for p in team_roster])
unqiue_ids = np.unique(player_ids)
assert len(unqiue_ids) == len(team_roster)

# %% [markdown]
# ### Question 9. Debug and Testing Functions
#
# When you write a program, you have to make sure that it always works correctly even if some exteral data (e.g., the ESPN website) may be corrupted. For example, Some players in a certain team may not have their player no. Your code should be able tp catch such exceptions and replace the missing player no with the value "NA". (10 points)

# %%
# YOUR CODE HERE
#raise NotImplementedError()
import requests
import re
from requests.exceptions import HTTPError
from bs4 import BeautifulSoup
team_name = "Virginia Cavaliers"
team_id = 258

print("wrong3")
roster = []
def mysplit(s, ex):
    head = s.rstrip(ex)
    tail = s[len(head):]
    return head, tail

def is_player_row(tag):
    if tag.name == 'tr' and tag.has_attr('data-idx'):
        return True
    return False

#Computing Team URL
url = "https://www.espn.com/college-football/team/roster/_/id/" + str(team_id) + "/"
real_team_name = team_name.split( )
#print(real_team_name)
i = 1
while (len(real_team_name) > i):     
    url = url + real_team_name[i-1].lower()+"-"
    i = i + 1
else: 
    url = url + real_team_name[i-1].lower()

#Create a BeautifulSoup Object
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html, 'html.parser')

#Finding Team Name
team_tag = soup.find('h1', string=re.compile(' Roster$'))

#Searching For Team Group
groups = soup.find_all(class_="Table__Title", string=["Offense", "Defense", "Special Teams"])
#print(len(groups), "groups")
#for g in groups:
    #print(g)

#Finding the Column Names
col_names = []
for g in groups:
    t = g.find_next("table")
    for c in t.thead.tr.children:
        col_names.append(c.text)

#Find the Attributes of a Player
players = []
id_list = []
for x in groups :
    table = x.find_next("table")
    for c in table.tbody.find_all(is_player_row):
        tds = c.find_all('td')
        cols = []
        for td in tds:
            cols.append(td.get_text())
        players.append(cols)
    for aPlayer in players :
        player = {}
        name = mysplit(aPlayer[1], '0123456789')
        player["player_name"] = name[0]

        player_url_name = name[0].split()
        totalURL = ""
        i = 1
        for x in player_url_name :
            if i != len(player_url_name) :
                if x.find(".") :
                    x = x.replace('.', '') 
                if x.find('\'') :
                    x = x.replace('\'', '') 
                totalURL = totalURL + x.lower() + "-"
            else :
                if x.find(".") :
                    x = x.replace('.', '')
                if x.find('\'') :
                    x = x.replace('\'', '') 
                totalURL = totalURL + x.lower()
            i = i + 1
        totalURL = '/' + totalURL
        #print(totalURL)
        #print(soup.find('a', href=re.compile(totalURL))['href'])
        id = soup.find('a', href=re.compile(totalURL))['href']
        id = re.sub('http://www.espn.com/college-football/player/_/id/', '', id)
        id = re.sub(totalURL, '', id)
        if id_list.count(id) == 0: 
            id_list.append(id)
            player["player_id"] = id
            if name[1] == '' :
                player["player_no"] = "NA"
            else :
                player["player_no"] = name[1]
            player["POS"] = aPlayer[2]
            player["HT"] = aPlayer[3]
            player["WT"] = aPlayer[4]
            player["Class"] = aPlayer[5]
            player["Birthplace"] = aPlayer[6]
            #print(player)
            roster.append(player)

team_roster = roster
# Out:
# wrong3

# %%
import numpy as np
positions = np.array([p['POS'] for p in team_roster])
position_label, position_counts = np.unique(positions, return_counts=True)
assert ''.join(position_label.tolist()) == 'CCBDBDEDLDTFBGLBLSNTOLOTPPKQBRBSTEWR'

# %%
player_nos = np.array([p['player_no'] for p in team_roster])
na_count = len([no for no in player_nos if no == 'NA'])
assert na_count > 10

# %% [markdown]
# ### Question 10. Add functions into a Python Modules
#
# Now you have developed two solid functions: `get_team_url` and `extract_team_roster` and you would like to reuse them in other projects or share them with other people. Use the Notebook magic command to write the two functions with other neccessary  statements into a python file named `roster.py`. (4 points)

# %%
# %%writefile roster.py

# YOUR CODE HERE
#raise NotImplementedError()
import requests
import re
from requests.exceptions import HTTPError
from bs4 import BeautifulSoup

def get_team_url(team_id, team_name):
    url = "https://www.espn.com/college-football/team/roster/_/id/" + str(team_id) + "/"
    real_team_name = team_name.split( )
    #print(real_team_name)
    i = 1
    while (len(real_team_name) > i):     
        url = url + real_team_name[i-1].lower()+"-"
        i = i + 1
    else: 
        url = url + real_team_name[i-1].lower()
    return url

def extract_team_roster(team_id, team_name):
    """
    Extract the team roster for a NCAA college football team
    
    Args:
        team_id: the id of a NACC football team assigned by ESPN
        team_name: the name of the football team
        
    Returns:
        a list of dict representing the roster of the entire team.
    """
    #team_id = 150
    #team_name = "Duke Blue Devils"
    roster = []
    def mysplit(s, ex):
        head = s.rstrip(ex)
        tail = s[len(head):]
        return head, tail
    
    def is_player_row(tag):
        if tag.name == 'tr' and tag.has_attr('data-idx'):
            return True
        return False
    
    #Computing Team URL
    url = get_team_url(team_id, team_name)

    #Create a BeautifulSoup Object
    response = requests.get(url)
    html = response.content
    soup = BeautifulSoup(html, 'html.parser')
        
    #Finding Team Name
    team_tag = soup.find('h1', string=re.compile(' Roster$'))
        
    #Searching For Team Group
    groups = soup.find_all(class_="Table__Title", string=["Offense", "Defense", "Special Teams"])
    #print(len(groups), "groups")
    #for g in groups:
        #print(g)
        
    #Finding the Column Names
    col_names = []
    for g in groups:
        t = g.find_next("table")
        for c in t.thead.tr.children:
            col_names.append(c.text)
        
    #Find the Attributes of a Player
    players = []
    id_list = []
    for x in groups :
        table = x.find_next("table")
        for c in table.tbody.find_all(is_player_row):
            tds = c.find_all('td')
            cols = []
            for td in tds:
                cols.append(td.get_text())
            players.append(cols)
        for aPlayer in players :
            player = {}
            name = mysplit(aPlayer[1], '0123456789')
            player["player_name"] = name[0]
            
            player_url_name = name[0].split()
            #print(player_url_name)
            totalURL = ""
            i = 1
            for x in player_url_name :
                #print(x)
                if i != len(player_url_name) :
                    if x.find(".") :
                        x = x.replace('.', '') 
                    if x.find('\'') :
                        #print(x)
                        x = x.replace('\'', '') 
                    if x.find(',') :
                        x = x.replace(',', '')
                    #print(x)
                    totalURL = totalURL + x.lower() + "-"
                else :
                    if x.find(".") :
                        x = x.replace('.', '')
                    if x.find('\'') :
                        #print(x)
                        x = x.replace('\'', '') 
                    if x.find(',') :
                        x = x.replace(',', '')
                    if x != '' :
                        #print(x)
                        totalURL = totalURL + x.lower()
                i = i + 1
            totalURL = '/' + totalURL
            #print(totalURL)
            #print(soup.find('a', href=re.compile(totalURL))['href'])
            id = soup.find('a', href=re.compile(totalURL))['href']
            id = re.sub('http://www.espn.com/college-football/player/_/id/', '', id)
            id = re.sub(totalURL, '', id)
            if id_list.count(id) == 0: 
                id_list.append(id)
                player["player_id"] = id
                if name[1] == '' :
                    player["player_no"] = "NA"
                else :
                    player["player_no"] = name[1]
                player["POS"] = aPlayer[2]
                player["HT"] = aPlayer[3]
                player["WT"] = aPlayer[4]
                player["Class"] = aPlayer[5]
                player["Birthplace"] = aPlayer[6]
                #print(player)
                roster.append(player)
        
    # YOUR CODE HERE
    #raise NotImplementedError()
    return roster
# Out:
# Overwriting roster.py

# %%
#import os
#import json
#import pandas as pd
#import numpy as np
#from roster import extract_team_roster
#hi = extract_team_roster(2390, 'Miami Hurricanes')
#print(hi)
# Out:
# ["D'Eriq", 'King']
# D'Eriq
# D'Eriq
# DEriq
# King
# King
# /deriq-king
# http://www.espn.com/college-football/player/_/id/4039300/deriq-king
# ['Tate', 'Martell']
# Tate
# Tate
# Tate
# Martell
# Martell
# /tate-martell
# http://www.espn.com/college-football/player/_/id/4241992/tate-martell
# ['Peyton', 'Matocha']
# Peyton
# Peyton
# Peyton
# Matocha
# Matocha
# /peyton-matocha
# http://www.espn.com/college-football/player/_/id/4427918/peyton-matocha
# ["N'Kosi", 'Perry']
# N'Kosi
# N'Kosi
# NKosi
# Perry
# Perry
# /nkosi-perry
# http://www.espn.com/college-football/player/_/id/4240628/nkosi-perry
# ['Ryan', 'Rizk']
# Ryan
# Ryan
# Ryan
# Rizk
# Rizk
# /ryan-rizk
# http://www.espn.com/college-football/player/_/id/4373230/ryan-rizk
# ['Tyler', 'Van', 'Dyke']
# Tyler
# Tyler
# Tyler
# Van
# Van
# Van
# Dyke
# Dyke
# /tyler-van-dyke
# http://www.espn.com/college-football/player/_/id/4685186/tyler-van-dyke
# ['Robert', 'Burns']
# Robert
# Robert
# Robert
# Burns
# Burns
# /robert-burns
# http://www.espn.com/college-football/player/_/id/4240636/robert-burns
# ['Isaiah', 'Cashwell']
# Isaiah
# Isaiah
# Isaiah
# Cashwell
# Cashwell
# /isaiah-cashwell
# http://www.espn.com/college-football/player/_/id/4591750/isaiah-cashwell
# ['Donald', 'Chaney', 'Jr.']
# Donald
# Donald
# Donald
# Chaney
# Chaney
# Chaney
# Jr.
# Jr
# /donald-chaney-jr
# http://www.espn.com/college-football/player/_/id/4685184/donald-chaney-jr
# ["Cam'Ron", 'Harris']
# Cam'Ron
# Cam'Ron
# CamRon
# Harris
# Harris
# /camron-harris
# http://www.espn.com/college-football/player/_/id/4362509/camron-harris
# ['Jaylan', 'Knighton']
# Jaylan
# Jaylan
# Jaylan
# Knighton
# Knighton
# /jaylan-knighton
# http://www.espn.com/college-football/player/_/id/4429043/jaylan-knighton
# ['Michael', 'Parrott']
# Michael
# Michael
# Michael
# Parrott
# Parrott
# /michael-parrott
# http://www.espn.com/college-football/player/_/id/4240641/michael-parrott
# ['Connor', 'Byrne']
# Connor
# Connor
# Connor
# Byrne
# Byrne
# /connor-byrne
# http://www.espn.com/college-football/player/_/id/4591751/connor-byrne
# ['Marshall', 'Few']
# Marshall
# Marshall
# Marshall
# Few
# Few
# /marshall-few
# http://www.espn.com/college-football/player/_/id/4240638/marshall-few
# ['Mike', 'Harley']
# Mike
# Mike
# Mike
# Harley
# Harley
# /mike-harley
# http://www.espn.com/college-football/player/_/id/4240625/mike-harley
# ['Jarius', 'Howard']
# Jarius
# Jarius
# Jarius
# Howard
# Howard
# /jarius-howard
# http://www.espn.com/college-football/player/_/id/4568306/jarius-howard
# ['Will', 'Huggins']
# Will
# Will
# Will
# Huggins
# Huggins
# /will-huggins
# http://www.espn.com/college-football/player/_/id/4362513/will-huggins
# ['Dante', 'Johnson']
# Dante
# Dante
# Dante
# Johnson
# Johnson
# /dante-johnson
# http://www.espn.com/college-football/player/_/id/4591752/dante-johnson
# ['Elias', 'Lugo-Fagundo']
# Elias
# Elias
# Elias
# Lugo-Fagundo
# Lugo-Fagundo
# /elias-lugo-fagundo
# http://www.espn.com/college-football/player/_/id/4240639/elias-lugo-fagundo
# ['Jeremiah', 'Payton']
# Jeremiah
# Jeremiah
# Jeremiah
# Payton
# Payton
# /jeremiah-payton
# http://www.espn.com/college-football/player/_/id/4426361/jeremiah-payton
# ['Mark', 'Pope']
# Mark
# Mark
# Mark
# Pope
# Pope
# /mark-pope
# http://www.espn.com/college-football/player/_/id/4362499/mark-pope
# ['Michael', 'Redding', 'III']
# Michael
# Michael
# Michael
# Redding
# Redding
# Redding
# III
# III
# /michael-redding-iii
# http://www.espn.com/college-football/player/_/id/4685188/michael-redding-iii
# ['Xavier', 'Restrepo']
# Xavier
# Xavier
# Xavier
# Restrepo
# Restrepo
# /xavier-restrepo
# http://www.espn.com/college-football/player/_/id/4431353/xavier-restrepo
# ['Keyshawn', 'Smith']
# Keyshawn
# Keyshawn
# Keyshawn
# Smith
# Smith
# /keyshawn-smith
# http://www.espn.com/college-football/player/_/id/4607419/keyshawn-smith
# ['Mykel', 'Tubbs']
# Mykel
# Mykel
# Mykel
# Tubbs
# Tubbs
# /mykel-tubbs
# http://www.espn.com/college-football/player/_/id/4574756/mykel-tubbs
# ['Dee', 'Wiggins']
# Dee
# Dee
# Dee
# Wiggins
# Wiggins
# /dee-wiggins
# http://www.espn.com/college-football/player/_/id/4362503/dee-wiggins
# ['Dazalin', 'Worsham']
# Dazalin
# Dazalin
# Dazalin
# Worsham
# Worsham
# /dazalin-worsham
# http://www.espn.com/college-football/player/_/id/4429107/dazalin-worsham
# ['Larry', 'Hodges']
# Larry
# Larry
# Larry
# Hodges
# Hodges
# /larry-hodges
# http://www.espn.com/college-football/player/_/id/4427491/larry-hodges
# ['Brevin', 'Jordan']
# Brevin
# Brevin
# Brevin
# Jordan
# Jordan
# /brevin-jordan
# http://www.espn.com/college-football/player/_/id/4362504/brevin-jordan
# ['Will', 'Mallory']
# Will
# Will
# Will
# Mallory
# Mallory
# /will-mallory
# http://www.espn.com/college-football/player/_/id/4362523/will-mallory
# ['Dominic', 'Mammarelli']
# Dominic
# Dominic
# Dominic
# Mammarelli
# Mammarelli
# /dominic-mammarelli
# http://www.espn.com/college-football/player/_/id/4430308/dominic-mammarelli
# ['Robert', 'Prosek']
# Robert
# Robert
# Robert
# Prosek
# Prosek
# /robert-prosek
# http://www.espn.com/college-football/player/_/id/4568301/robert-prosek
# ['Gavin', 'Adams']
# Gavin
# Gavin
# Gavin
# Adams
# Adams
# /gavin-adams
# http://www.espn.com/college-football/player/_/id/4691361/gavin-adams
# ['John', 'Campbell', 'Jr.']
# John
# John
# John
# Campbell
# Campbell
# Campbell
# Jr.
# Jr
# /john-campbell-jr
# http://www.espn.com/college-football/player/_/id/4362522/john-campbell-jr
# ['Jakai', 'Clark']
# Jakai
# Jakai
# Jakai
# Clark
# Clark
# /jakai-clark
# http://www.espn.com/college-football/player/_/id/4429409/jakai-clark
# ['Navaughn', 'Donaldson']
# Navaughn
# Navaughn
# Navaughn
# Donaldson
# Donaldson
# /navaughn-donaldson
# http://www.espn.com/college-football/player/_/id/4240647/navaughn-donaldson
# ['Adam', 'ElGammal']
# Adam
# Adam
# Adam
# ElGammal
# ElGammal
# /adam-elgammal
# http://www.espn.com/college-football/player/_/id/4427136/adam-elgammal
# ['Corey', 'Gaynor']
# Corey
# Corey
# Corey
# Gaynor
# Gaynor
# /corey-gaynor
# http://www.espn.com/college-football/player/_/id/4240649/corey-gaynor
# ['Jared', 'Griffith']
# Jared
# Jared
# Jared
# Griffith
# Griffith
# /jared-griffith
# http://www.espn.com/college-football/player/_/id/4362521/jared-griffith
# ['Kai-Leon', 'Herbert']
# Kai-Leon
# Kai-Leon
# Kai-Leon
# Herbert
# Herbert
# /kai-leon-herbert
# http://www.espn.com/college-football/player/_/id/4240648/kai-leon-herbert
# ["Zalon'tae", 'Hillery']
# Zalon'tae
# Zalon'tae
# Zalontae
# Hillery
# Hillery
# /zalontae-hillery
# http://www.espn.com/college-football/player/_/id/4240651/zalontae-hillery
# ['Zion', 'Nelson']
# Zion
# Zion
# Zion
# Nelson
# Nelson
# /zion-nelson
# http://www.espn.com/college-football/player/_/id/4428103/zion-nelson
# ['Cleveland', 'Reed', 'Jr.']
# Cleveland
# Cleveland
# Cleveland
# Reed
# Reed
# Reed
# Jr.
# Jr
# /cleveland-reed-jr
# http://www.espn.com/college-football/player/_/id/4362519/cleveland-reed-jr
# ['Jalen', 'Rivers']
# Jalen
# Jalen
# Jalen
# Rivers
# Rivers
# /jalen-rivers
# http://www.espn.com/college-football/player/_/id/4429010/jalen-rivers
# ['DJ', 'Scaife', 'Jr.']
# DJ
# DJ
# DJ
# Scaife
# Scaife
# Scaife
# Jr.
# Jr
# /dj-scaife-jr
# http://www.espn.com/college-football/player/_/id/4362517/dj-scaife-jr
# ['Ousman', 'Traore']
# Ousman
# Ousman
# Ousman
# Traore
# Traore
# /ousman-traore
# http://www.espn.com/college-football/player/_/id/4568304/ousman-traore
# ['Issiah', 'Walker,', 'Jr.']
# Issiah
# Issiah
# Issiah
# Walker,
# Walker,
# Walker
# Jr.
# Jr
# /issiah-walker-jr
# http://www.espn.com/college-football/player/_/id/4690796/issiah-walker-jr
# ['Chris', 'Washington']
# Chris
# Chris
# Chris
# Washington
# Washington
# /chris-washington
# http://www.espn.com/college-football/player/_/id/4685187/chris-washington
# ['Jarrid', 'Williams']
# Jarrid
# Jarrid
# Jarrid
# Williams
# Williams
# /jarrid-williams
# http://www.espn.com/college-football/player/_/id/3914628/jarrid-williams
# ["D'Eriq", 'King']
# D'Eriq
# D'Eriq
# DEriq
# King
# King
# /deriq-king
# http://www.espn.com/college-football/player/_/id/4039300/deriq-king
# ['Tate', 'Martell']
# Tate
# Tate
# Tate
# Martell
# Martell
# /tate-martell
# http://www.espn.com/college-football/player/_/id/4241992/tate-martell
# ['Peyton', 'Matocha']
# Peyton
# Peyton
# Peyton
# Matocha
# Matocha
# /peyton-matocha
# http://www.espn.com/college-football/player/_/id/4427918/peyton-matocha
# ["N'Kosi", 'Perry']
# N'Kosi
# N'Kosi
# NKosi
# Perry
# Perry
# /nkosi-perry
# http://www.espn.com/college-football/player/_/id/4240628/nkosi-perry
# ['Ryan', 'Rizk']
# Ryan
# Ryan
# Ryan
# Rizk
# Rizk
# /ryan-rizk
# http://www.espn.com/college-football/player/_/id/4373230/ryan-rizk
# ['Tyler', 'Van', 'Dyke']
# Tyler
# Tyler
# Tyler
# Van
# Van
# Van
# Dyke
# Dyke
# /tyler-van-dyke
# http://www.espn.com/college-football/player/_/id/4685186/tyler-van-dyke
# ['Robert', 'Burns']
# Robert
# Robert
# Robert
# Burns
# Burns
# /robert-burns
# http://www.espn.com/college-football/player/_/id/4240636/robert-burns
# ['Isaiah', 'Cashwell']
# Isaiah
# Isaiah
# Isaiah
# Cashwell
# Cashwell
# /isaiah-cashwell
# http://www.espn.com/college-football/player/_/id/4591750/isaiah-cashwell
# ['Donald', 'Chaney', 'Jr.']
# Donald
# Donald
# Donald
# Chaney
# Chaney
# Chaney
# Jr.
# Jr
# /donald-chaney-jr
# http://www.espn.com/college-football/player/_/id/4685184/donald-chaney-jr
# ["Cam'Ron", 'Harris']
# Cam'Ron
# Cam'Ron
# CamRon
# Harris
# Harris
# /camron-harris
# http://www.espn.com/college-football/player/_/id/4362509/camron-harris
# ['Jaylan', 'Knighton']
# Jaylan
# Jaylan
# Jaylan
# Knighton
# Knighton
# /jaylan-knighton
# http://www.espn.com/college-football/player/_/id/4429043/jaylan-knighton
# ['Michael', 'Parrott']
# Michael
# Michael
# Michael
# Parrott
# Parrott
# /michael-parrott
# http://www.espn.com/college-football/player/_/id/4240641/michael-parrott
# ['Connor', 'Byrne']
# Connor
# Connor
# Connor
# Byrne
# Byrne
# /connor-byrne
# http://www.espn.com/college-football/player/_/id/4591751/connor-byrne
# ['Marshall', 'Few']
# Marshall
# Marshall
# Marshall
# Few
# Few
# /marshall-few
# http://www.espn.com/college-football/player/_/id/4240638/marshall-few
# ['Mike', 'Harley']
# Mike
# Mike
# Mike
# Harley
# Harley
# /mike-harley
# http://www.espn.com/college-football/player/_/id/4240625/mike-harley
# ['Jarius', 'Howard']
# Jarius
# Jarius
# Jarius
# Howard
# Howard
# /jarius-howard
# http://www.espn.com/college-football/player/_/id/4568306/jarius-howard
# ['Will', 'Huggins']
# Will
# Will
# Will
# Huggins
# Huggins
# /will-huggins
# http://www.espn.com/college-football/player/_/id/4362513/will-huggins
# ['Dante', 'Johnson']
# Dante
# Dante
# Dante
# Johnson
# Johnson
# /dante-johnson
# http://www.espn.com/college-football/player/_/id/4591752/dante-johnson
# ['Elias', 'Lugo-Fagundo']
# Elias
# Elias
# Elias
# Lugo-Fagundo
# Lugo-Fagundo
# /elias-lugo-fagundo
# http://www.espn.com/college-football/player/_/id/4240639/elias-lugo-fagundo
# ['Jeremiah', 'Payton']
# Jeremiah
# Jeremiah
# Jeremiah
# Payton
# Payton
# /jeremiah-payton
# http://www.espn.com/college-football/player/_/id/4426361/jeremiah-payton
# ['Mark', 'Pope']
# Mark
# Mark
# Mark
# Pope
# Pope
# /mark-pope
# http://www.espn.com/college-football/player/_/id/4362499/mark-pope
# ['Michael', 'Redding', 'III']
# Michael
# Michael
# Michael
# Redding
# Redding
# Redding
# III
# III
# /michael-redding-iii
# http://www.espn.com/college-football/player/_/id/4685188/michael-redding-iii
# ['Xavier', 'Restrepo']
# Xavier
# Xavier
# Xavier
# Restrepo
# Restrepo
# /xavier-restrepo
# http://www.espn.com/college-football/player/_/id/4431353/xavier-restrepo
# ['Keyshawn', 'Smith']
# Keyshawn
# Keyshawn
# Keyshawn
# Smith
# Smith
# /keyshawn-smith
# http://www.espn.com/college-football/player/_/id/4607419/keyshawn-smith
# ['Mykel', 'Tubbs']
# Mykel
# Mykel
# Mykel
# Tubbs
# Tubbs
# /mykel-tubbs
# http://www.espn.com/college-football/player/_/id/4574756/mykel-tubbs
# ['Dee', 'Wiggins']
# Dee
# Dee
# Dee
# Wiggins
# Wiggins
# /dee-wiggins
# http://www.espn.com/college-football/player/_/id/4362503/dee-wiggins
# ['Dazalin', 'Worsham']
# Dazalin
# Dazalin
# Dazalin
# Worsham
# Worsham
# /dazalin-worsham
# http://www.espn.com/college-football/player/_/id/4429107/dazalin-worsham
# ['Larry', 'Hodges']
# Larry
# Larry
# Larry
# Hodges
# Hodges
# /larry-hodges
# http://www.espn.com/college-football/player/_/id/4427491/larry-hodges
# ['Brevin', 'Jordan']
# Brevin
# Brevin
# Brevin
# Jordan
# Jordan
# /brevin-jordan
# http://www.espn.com/college-football/player/_/id/4362504/brevin-jordan
# ['Will', 'Mallory']
# Will
# Will
# Will
# Mallory
# Mallory
# /will-mallory
# http://www.espn.com/college-football/player/_/id/4362523/will-mallory
# ['Dominic', 'Mammarelli']
# Dominic
# Dominic
# Dominic
# Mammarelli
# Mammarelli
# /dominic-mammarelli
# http://www.espn.com/college-football/player/_/id/4430308/dominic-mammarelli
# ['Robert', 'Prosek']
# Robert
# Robert
# Robert
# Prosek
# Prosek
# /robert-prosek
# http://www.espn.com/college-football/player/_/id/4568301/robert-prosek
# ['Gavin', 'Adams']
# Gavin
# Gavin
# Gavin
# Adams
# Adams
# /gavin-adams
# http://www.espn.com/college-football/player/_/id/4691361/gavin-adams
# ['John', 'Campbell', 'Jr.']
# John
# John
# John
# Campbell
# Campbell
# Campbell
# Jr.
# Jr
# /john-campbell-jr
# http://www.espn.com/college-football/player/_/id/4362522/john-campbell-jr
# ['Jakai', 'Clark']
# Jakai
# Jakai
# Jakai
# Clark
# Clark
# /jakai-clark
# http://www.espn.com/college-football/player/_/id/4429409/jakai-clark
# ['Navaughn', 'Donaldson']
# Navaughn
# Navaughn
# Navaughn
# Donaldson
# Donaldson
# /navaughn-donaldson
# http://www.espn.com/college-football/player/_/id/4240647/navaughn-donaldson
# ['Adam', 'ElGammal']
# Adam
# Adam
# Adam
# ElGammal
# ElGammal
# /adam-elgammal
# http://www.espn.com/college-football/player/_/id/4427136/adam-elgammal
# ['Corey', 'Gaynor']
# Corey
# Corey
# Corey
# Gaynor
# Gaynor
# /corey-gaynor
# http://www.espn.com/college-football/player/_/id/4240649/corey-gaynor
# ['Jared', 'Griffith']
# Jared
# Jared
# Jared
# Griffith
# Griffith
# /jared-griffith
# http://www.espn.com/college-football/player/_/id/4362521/jared-griffith
# ['Kai-Leon', 'Herbert']
# Kai-Leon
# Kai-Leon
# Kai-Leon
# Herbert
# Herbert
# /kai-leon-herbert
# http://www.espn.com/college-football/player/_/id/4240648/kai-leon-herbert
# ["Zalon'tae", 'Hillery']
# Zalon'tae
# Zalon'tae
# Zalontae
# Hillery
# Hillery
# /zalontae-hillery
# http://www.espn.com/college-football/player/_/id/4240651/zalontae-hillery
# ['Zion', 'Nelson']
# Zion
# Zion
# Zion
# Nelson
# Nelson
# /zion-nelson
# http://www.espn.com/college-football/player/_/id/4428103/zion-nelson
# ['Cleveland', 'Reed', 'Jr.']
# Cleveland
# Cleveland
# Cleveland
# Reed
# Reed
# Reed
# Jr.
# Jr
# /cleveland-reed-jr
# http://www.espn.com/college-football/player/_/id/4362519/cleveland-reed-jr
# ['Jalen', 'Rivers']
# Jalen
# Jalen
# Jalen
# Rivers
# Rivers
# /jalen-rivers
# http://www.espn.com/college-football/player/_/id/4429010/jalen-rivers
# ['DJ', 'Scaife', 'Jr.']
# DJ
# DJ
# DJ
# Scaife
# Scaife
# Scaife
# Jr.
# Jr
# /dj-scaife-jr
# http://www.espn.com/college-football/player/_/id/4362517/dj-scaife-jr
# ['Ousman', 'Traore']
# Ousman
# Ousman
# Ousman
# Traore
# Traore
# /ousman-traore
# http://www.espn.com/college-football/player/_/id/4568304/ousman-traore
# ['Issiah', 'Walker,', 'Jr.']
# Issiah
# Issiah
# Issiah
# Walker,
# Walker,
# Walker
# Jr.
# Jr
# /issiah-walker-jr
# http://www.espn.com/college-football/player/_/id/4690796/issiah-walker-jr
# ['Chris', 'Washington']
# Chris
# Chris
# Chris
# Washington
# Washington
# /chris-washington
# http://www.espn.com/college-football/player/_/id/4685187/chris-washington
# ['Jarrid', 'Williams']
# Jarrid
# Jarrid
# Jarrid
# Williams
# Williams
# /jarrid-williams
# http://www.espn.com/college-football/player/_/id/3914628/jarrid-williams
# ['Jason', 'Blissett', 'Jr.']
# Jason
# Jason
# Jason
# Blissett
# Blissett
# Blissett
# Jr.
# Jr
# /jason-blissett-jr
# http://www.espn.com/college-football/player/_/id/4428982/jason-blissett-jr
# ['Earnest', 'Carter', 'Jr.']
# Earnest
# Earnest
# Earnest
# Carter
# Carter
# Carter
# Jr.
# Jr
# /earnest-carter-jr
# http://www.espn.com/college-football/player/_/id/4693621/earnest-carter-jr
# ['Sam', 'Fishman']
# Sam
# Sam
# Sam
# Fishman
# Fishman
# /sam-fishman
# http://www.espn.com/college-football/player/_/id/4691363/sam-fishman
# ['Jonathan', 'Ford']
# Jonathan
# Jonathan
# Jonathan
# Ford
# Ford
# /jonathan-ford
# http://www.espn.com/college-football/player/_/id/4259762/jonathan-ford
# ['Jared', 'Harrison-Hunte']
# Jared
# Jared
# Jared
# Harrison-Hunte
# Harrison-Hunte
# /jared-harrison-hunte
# http://www.espn.com/college-football/player/_/id/4427401/jared-harrison-hunte
# ['Jahfari', 'Harvey']
# Jahfari
# Jahfari
# Jahfari
# Harvey
# Harvey
# /jahfari-harvey
# http://www.espn.com/college-football/player/_/id/4427408/jahfari-harvey
# ['Jalar', 'Holley']
# Jalar
# Jalar
# Jalar
# Holley
# Holley
# /jalar-holley
# http://www.espn.com/college-football/player/_/id/4429841/jalar-holley
# ['Bryan', 'Levine']
# Bryan
# Bryan
# Bryan
# Levine
# Levine
# /bryan-levine
# http://www.espn.com/college-football/player/_/id/4568299/bryan-levine
# ['Jordan', 'Miller']
# Jordan
# Jordan
# Jordan
# Miller
# Miller
# /jordan-miller
# http://www.espn.com/college-football/player/_/id/4362524/jordan-miller
# ['Josh', 'Neely']
# Josh
# Josh
# Josh
# Neely
# Neely
# /josh-neely
# http://www.espn.com/college-football/player/_/id/4568307/josh-neely
# ['Jaelan', 'Phillips']
# Jaelan
# Jaelan
# Jaelan
# Phillips
# Phillips
# /jaelan-phillips
# http://www.espn.com/college-football/player/_/id/4242975/jaelan-phillips
# ['Elijah', 'Roberts']
# Elijah
# Elijah
# Elijah
# Roberts
# Roberts
# /elijah-roberts
# http://www.espn.com/college-football/player/_/id/4690795/elijah-roberts
# ['Quincy', 'Roche']
# Quincy
# Quincy
# Quincy
# Roche
# Roche
# /quincy-roche
# http://www.espn.com/college-football/player/_/id/4044145/quincy-roche
# ['Michael', 'Scibelli']
# Michael
# Michael
# Michael
# Scibelli
# Scibelli
# /michael-scibelli
# http://www.espn.com/college-football/player/_/id/4373239/michael-scibelli
# ['Nesta', 'Jade', 'Silvera']
# Nesta
# Nesta
# Nesta
# Jade
# Jade
# Jade
# Silvera
# Silvera
# /nesta-jade-silvera
# http://www.espn.com/college-football/player/_/id/4362497/nesta-jade-silvera
# ['Cameron', 'Williams']
# Cameron
# Cameron
# Cameron
# Williams
# Williams
# /cameron-williams
# http://www.espn.com/college-football/player/_/id/4568293/cameron-williams
# ['Chantz', 'Williams']
# Chantz
# Chantz
# Chantz
# Williams
# Williams
# /chantz-williams
# http://www.espn.com/college-football/player/_/id/4430813/chantz-williams
# ['Quentin', 'Williams']
# Quentin
# Quentin
# Quentin
# Williams
# Williams
# /quentin-williams
# http://www.espn.com/college-football/player/_/id/4690798/quentin-williams
# ['Colvin', 'Alford']
# Colvin
# Colvin
# Colvin
# Alford
# Alford
# /colvin-alford
# http://www.espn.com/college-football/player/_/id/4240640/colvin-alford
# ['Tirek', 'Austin-Cave']
# Tirek
# Tirek
# Tirek
# Austin-Cave
# Austin-Cave
# /tirek-austin-cave
# http://www.espn.com/college-football/player/_/id/4430917/tirek-austin-cave
# ['Sam', 'Brooks', 'Jr.']
# Sam
# Sam
# Sam
# Brooks
# Brooks
# Brooks
# Jr.
# Jr
# /sam-brooks-jr
# http://www.espn.com/college-football/player/_/id/4568292/sam-brooks-jr
# ['Graden', 'Feldmann']
# Graden
# Graden
# Graden
# Feldmann
# Feldmann
# /graden-feldmann
# http://www.espn.com/college-football/player/_/id/4692501/graden-feldmann
# ['Corey', 'Flagg', 'Jr.']
# Corey
# Corey
# Corey
# Flagg
# Flagg
# Flagg
# Jr.
# Jr
# /corey-flagg-jr
# http://www.espn.com/college-football/player/_/id/4685185/corey-flagg-jr
# ['Gilbert', 'Frierson']
# Gilbert
# Gilbert
# Gilbert
# Frierson
# Frierson
# /gilbert-frierson
# http://www.espn.com/college-football/player/_/id/4362498/gilbert-frierson
# ['Jake', 'Hoffman']
# Jake
# Jake
# Jake
# Hoffman
# Hoffman
# /jake-hoffman
# http://www.espn.com/college-football/player/_/id/4568300/jake-hoffman
# ['Avery', 'Huff']
# Avery
# Avery
# Avery
# Huff
# Huff
# /avery-huff
# http://www.espn.com/college-football/player/_/id/4574755/avery-huff
# ['Bradley', 'Jennings', 'Jr.']
# Bradley
# Bradley
# Bradley
# Jennings
# Jennings
# Jennings
# Jr.
# Jr
# /bradley-jennings-jr
# http://www.espn.com/college-football/player/_/id/4240642/bradley-jennings-jr
# ['Patrick', 'Joyner', 'Jr.']
# Patrick
# Patrick
# Patrick
# Joyner
# Joyner
# Joyner
# Jr.
# Jr
# /patrick-joyner-jr
# http://www.espn.com/college-football/player/_/id/4362518/patrick-joyner-jr
# ['Zach', 'McCloud']
# Zach
# Zach
# Zach
# McCloud
# McCloud
# /zach-mccloud
# http://www.espn.com/college-football/player/_/id/4037464/zach-mccloud
# ['Ryan', 'Ragone']
# Ryan
# Ryan
# Ryan
# Ragone
# Ragone
# /ryan-ragone
# http://www.espn.com/college-football/player/_/id/4373583/ryan-ragone
# ['Shane', 'Sawyer']
# Shane
# Shane
# Shane
# Sawyer
# Sawyer
# /shane-sawyer
# http://www.espn.com/college-football/player/_/id/4691366/shane-sawyer
# ['Keontra', 'Smith']
# Keontra
# Keontra
# Keontra
# Smith
# Smith
# /keontra-smith
# http://www.espn.com/college-football/player/_/id/4426471/keontra-smith
# ['Zac', 'Smith']
# Zac
# Zac
# Zac
# Smith
# Smith
# /zac-smith
# http://www.espn.com/college-football/player/_/id/4568295/zac-smith
# ['Waynmon', 'Steed']
# Waynmon
# Waynmon
# Waynmon
# Steed
# Steed
# /waynmon-steed
# http://www.espn.com/college-football/player/_/id/4240632/waynmon-steed
# ['Al', 'Blades', 'Jr.']
# Al
# Al
# Al
# Blades
# Blades
# Blades
# Jr.
# Jr
# /al-blades-jr
# http://www.espn.com/college-football/player/_/id/4362500/al-blades-jr
# ['Suleman', 'Burrows']
# Suleman
# Suleman
# Suleman
# Burrows
# Burrows
# /suleman-burrows
# http://www.espn.com/college-football/player/_/id/4362525/suleman-burrows
# ['Marcus', 'Clarke']
# Marcus
# Marcus
# Marcus
# Clarke
# Clarke
# /marcus-clarke
# http://www.espn.com/college-football/player/_/id/4690793/marcus-clarke
# ["Te'Cory", 'Couch']
# Te'Cory
# Te'Cory
# TeCory
# Couch
# Couch
# /tecory-couch
# http://www.espn.com/college-football/player/_/id/4427348/tecory-couch
# ['Isaiah', 'Dunson']
# Isaiah
# Isaiah
# Isaiah
# Dunson
# Dunson
# /isaiah-dunson
# http://www.espn.com/college-football/player/_/id/4691362/isaiah-dunson
# ['Luis', 'Gutierrez', 'Jr.']
# Luis
# Luis
# Luis
# Gutierrez
# Gutierrez
# Gutierrez
# Jr.
# Jr
# /luis-gutierrez-jr
# http://www.espn.com/college-football/player/_/id/4568298/luis-gutierrez-jr
# ['DJ', 'Ivey']
# DJ
# DJ
# DJ
# Ivey
# Ivey
# /dj-ivey
# http://www.espn.com/college-football/player/_/id/4362502/dj-ivey
# ['Christian', 'Williams']
# Christian
# Christian
# Christian
# Williams
# Williams
# /christian-williams
# http://www.espn.com/college-football/player/_/id/4568294/christian-williams
# ['Gannon', 'Feldmann']
# Gannon
# Gannon
# Gannon
# Feldmann
# Feldmann
# /gannon-feldmann
# http://www.espn.com/college-football/player/_/id/4568297/gannon-feldmann
# ['Brian', 'Balom']
# Brian
# Brian
# Brian
# Balom
# Balom
# /brian-balom
# http://www.espn.com/college-football/player/_/id/4690792/brian-balom
# ['Andrew', 'Barnes']
# Andrew
# Andrew
# Andrew
# Barnes
# Barnes
# /andrew-barnes
# http://www.espn.com/college-football/player/_/id/4568296/andrew-barnes
# ['Bubba', 'Bolden']
# Bubba
# Bubba
# Bubba
# Bolden
# Bolden
# /bubba-bolden
# http://www.espn.com/college-football/player/_/id/4259631/bubba-bolden
# ['Amari', 'Carter']
# Amari
# Amari
# Amari
# Carter
# Carter
# /amari-carter
# http://www.espn.com/college-football/player/_/id/4240627/amari-carter
# ['Gurvan', 'Hall', 'Jr.']
# Gurvan
# Gurvan
# Gurvan
# Hall
# Hall
# Hall
# Jr.
# Jr
# /gurvan-hall-jr
# http://www.espn.com/college-football/player/_/id/4362510/gurvan-hall-jr
# ['Jalen', 'Harrell']
# Jalen
# Jalen
# Jalen
# Harrell
# Harrell
# /jalen-harrell
# http://www.espn.com/college-football/player/_/id/4690794/jalen-harrell
# ['Keshawn', 'Washington']
# Keshawn
# Keshawn
# Keshawn
# Washington
# Washington
# /keshawn-washington
# http://www.espn.com/college-football/player/_/id/4432621/keshawn-washington
# ['Avantae', 'Williams']
# Avantae
# Avantae
# Avantae
# Williams
# Williams
# /avantae-williams
# http://www.espn.com/college-football/player/_/id/4690797/avantae-williams
# ["D'Eriq", 'King']
# D'Eriq
# D'Eriq
# DEriq
# King
# King
# /deriq-king
# http://www.espn.com/college-football/player/_/id/4039300/deriq-king
# ['Tate', 'Martell']
# Tate
# Tate
# Tate
# Martell
# Martell
# /tate-martell
# http://www.espn.com/college-football/player/_/id/4241992/tate-martell
# ['Peyton', 'Matocha']
# Peyton
# Peyton
# Peyton
# Matocha
# Matocha
# /peyton-matocha
# http://www.espn.com/college-football/player/_/id/4427918/peyton-matocha
# ["N'Kosi", 'Perry']
# N'Kosi
# N'Kosi
# NKosi
# Perry
# Perry
# /nkosi-perry
# http://www.espn.com/college-football/player/_/id/4240628/nkosi-perry
# ['Ryan', 'Rizk']
# Ryan
# Ryan
# Ryan
# Rizk
# Rizk
# /ryan-rizk
# http://www.espn.com/college-football/player/_/id/4373230/ryan-rizk
# ['Tyler', 'Van', 'Dyke']
# Tyler
# Tyler
# Tyler
# Van
# Van
# Van
# Dyke
# Dyke
# /tyler-van-dyke
# http://www.espn.com/college-football/player/_/id/4685186/tyler-van-dyke
# ['Robert', 'Burns']
# Robert
# Robert
# Robert
# Burns
# Burns
# /robert-burns
# http://www.espn.com/college-football/player/_/id/4240636/robert-burns
# ['Isaiah', 'Cashwell']
# Isaiah
# Isaiah
# Isaiah
# Cashwell
# Cashwell
# /isaiah-cashwell
# http://www.espn.com/college-football/player/_/id/4591750/isaiah-cashwell
# ['Donald', 'Chaney', 'Jr.']
# Donald
# Donald
# Donald
# Chaney
# Chaney
# Chaney
# Jr.
# Jr
# /donald-chaney-jr
# http://www.espn.com/college-football/player/_/id/4685184/donald-chaney-jr
# ["Cam'Ron", 'Harris']
# Cam'Ron
# Cam'Ron
# CamRon
# Harris
# Harris
# /camron-harris
# http://www.espn.com/college-football/player/_/id/4362509/camron-harris
# ['Jaylan', 'Knighton']
# Jaylan
# Jaylan
# Jaylan
# Knighton
# Knighton
# /jaylan-knighton
# http://www.espn.com/college-football/player/_/id/4429043/jaylan-knighton
# ['Michael', 'Parrott']
# Michael
# Michael
# Michael
# Parrott
# Parrott
# /michael-parrott
# http://www.espn.com/college-football/player/_/id/4240641/michael-parrott
# ['Connor', 'Byrne']
# Connor
# Connor
# Connor
# Byrne
# Byrne
# /connor-byrne
# http://www.espn.com/college-football/player/_/id/4591751/connor-byrne
# ['Marshall', 'Few']
# Marshall
# Marshall
# Marshall
# Few
# Few
# /marshall-few
# http://www.espn.com/college-football/player/_/id/4240638/marshall-few
# ['Mike', 'Harley']
# Mike
# Mike
# Mike
# Harley
# Harley
# /mike-harley
# http://www.espn.com/college-football/player/_/id/4240625/mike-harley
# ['Jarius', 'Howard']
# Jarius
# Jarius
# Jarius
# Howard
# Howard
# /jarius-howard
# http://www.espn.com/college-football/player/_/id/4568306/jarius-howard
# ['Will', 'Huggins']
# Will
# Will
# Will
# Huggins
# Huggins
# /will-huggins
# http://www.espn.com/college-football/player/_/id/4362513/will-huggins
# ['Dante', 'Johnson']
# Dante
# Dante
# Dante
# Johnson
# Johnson
# /dante-johnson
# http://www.espn.com/college-football/player/_/id/4591752/dante-johnson
# ['Elias', 'Lugo-Fagundo']
# Elias
# Elias
# Elias
# Lugo-Fagundo
# Lugo-Fagundo
# /elias-lugo-fagundo
# http://www.espn.com/college-football/player/_/id/4240639/elias-lugo-fagundo
# ['Jeremiah', 'Payton']
# Jeremiah
# Jeremiah
# Jeremiah
# Payton
# Payton
# /jeremiah-payton
# http://www.espn.com/college-football/player/_/id/4426361/jeremiah-payton
# ['Mark', 'Pope']
# Mark
# Mark
# Mark
# Pope
# Pope
# /mark-pope
# http://www.espn.com/college-football/player/_/id/4362499/mark-pope
# ['Michael', 'Redding', 'III']
# Michael
# Michael
# Michael
# Redding
# Redding
# Redding
# III
# III
# /michael-redding-iii
# http://www.espn.com/college-football/player/_/id/4685188/michael-redding-iii
# ['Xavier', 'Restrepo']
# Xavier
# Xavier
# Xavier
# Restrepo
# Restrepo
# /xavier-restrepo
# http://www.espn.com/college-football/player/_/id/4431353/xavier-restrepo
# ['Keyshawn', 'Smith']
# Keyshawn
# Keyshawn
# Keyshawn
# Smith
# Smith
# /keyshawn-smith
# http://www.espn.com/college-football/player/_/id/4607419/keyshawn-smith
# ['Mykel', 'Tubbs']
# Mykel
# Mykel
# Mykel
# Tubbs
# Tubbs
# /mykel-tubbs
# http://www.espn.com/college-football/player/_/id/4574756/mykel-tubbs
# ['Dee', 'Wiggins']
# Dee
# Dee
# Dee
# Wiggins
# Wiggins
# /dee-wiggins
# http://www.espn.com/college-football/player/_/id/4362503/dee-wiggins
# ['Dazalin', 'Worsham']
# Dazalin
# Dazalin
# Dazalin
# Worsham
# Worsham
# /dazalin-worsham
# http://www.espn.com/college-football/player/_/id/4429107/dazalin-worsham
# ['Larry', 'Hodges']
# Larry
# Larry
# Larry
# Hodges
# Hodges
# /larry-hodges
# http://www.espn.com/college-football/player/_/id/4427491/larry-hodges
# ['Brevin', 'Jordan']
# Brevin
# Brevin
# Brevin
# Jordan
# Jordan
# /brevin-jordan
# http://www.espn.com/college-football/player/_/id/4362504/brevin-jordan
# ['Will', 'Mallory']
# Will
# Will
# Will
# Mallory
# Mallory
# /will-mallory
# http://www.espn.com/college-football/player/_/id/4362523/will-mallory
# ['Dominic', 'Mammarelli']
# Dominic
# Dominic
# Dominic
# Mammarelli
# Mammarelli
# /dominic-mammarelli
# http://www.espn.com/college-football/player/_/id/4430308/dominic-mammarelli
# ['Robert', 'Prosek']
# Robert
# Robert
# Robert
# Prosek
# Prosek
# /robert-prosek
# http://www.espn.com/college-football/player/_/id/4568301/robert-prosek
# ['Gavin', 'Adams']
# Gavin
# Gavin
# Gavin
# Adams
# Adams
# /gavin-adams
# http://www.espn.com/college-football/player/_/id/4691361/gavin-adams
# ['John', 'Campbell', 'Jr.']
# John
# John
# John
# Campbell
# Campbell
# Campbell
# Jr.
# Jr
# /john-campbell-jr
# http://www.espn.com/college-football/player/_/id/4362522/john-campbell-jr
# ['Jakai', 'Clark']
# Jakai
# Jakai
# Jakai
# Clark
# Clark
# /jakai-clark
# http://www.espn.com/college-football/player/_/id/4429409/jakai-clark
# ['Navaughn', 'Donaldson']
# Navaughn
# Navaughn
# Navaughn
# Donaldson
# Donaldson
# /navaughn-donaldson
# http://www.espn.com/college-football/player/_/id/4240647/navaughn-donaldson
# ['Adam', 'ElGammal']
# Adam
# Adam
# Adam
# ElGammal
# ElGammal
# /adam-elgammal
# http://www.espn.com/college-football/player/_/id/4427136/adam-elgammal
# ['Corey', 'Gaynor']
# Corey
# Corey
# Corey
# Gaynor
# Gaynor
# /corey-gaynor
# http://www.espn.com/college-football/player/_/id/4240649/corey-gaynor
# ['Jared', 'Griffith']
# Jared
# Jared
# Jared
# Griffith
# Griffith
# /jared-griffith
# http://www.espn.com/college-football/player/_/id/4362521/jared-griffith
# ['Kai-Leon', 'Herbert']
# Kai-Leon
# Kai-Leon
# Kai-Leon
# Herbert
# Herbert
# /kai-leon-herbert
# http://www.espn.com/college-football/player/_/id/4240648/kai-leon-herbert
# ["Zalon'tae", 'Hillery']
# Zalon'tae
# Zalon'tae
# Zalontae
# Hillery
# Hillery
# /zalontae-hillery
# http://www.espn.com/college-football/player/_/id/4240651/zalontae-hillery
# ['Zion', 'Nelson']
# Zion
# Zion
# Zion
# Nelson
# Nelson
# /zion-nelson
# http://www.espn.com/college-football/player/_/id/4428103/zion-nelson
# ['Cleveland', 'Reed', 'Jr.']
# Cleveland
# Cleveland
# Cleveland
# Reed
# Reed
# Reed
# Jr.
# Jr
# /cleveland-reed-jr
# http://www.espn.com/college-football/player/_/id/4362519/cleveland-reed-jr
# ['Jalen', 'Rivers']
# Jalen
# Jalen
# Jalen
# Rivers
# Rivers
# /jalen-rivers
# http://www.espn.com/college-football/player/_/id/4429010/jalen-rivers
# ['DJ', 'Scaife', 'Jr.']
# DJ
# DJ
# DJ
# Scaife
# Scaife
# Scaife
# Jr.
# Jr
# /dj-scaife-jr
# http://www.espn.com/college-football/player/_/id/4362517/dj-scaife-jr
# ['Ousman', 'Traore']
# Ousman
# Ousman
# Ousman
# Traore
# Traore
# /ousman-traore
# http://www.espn.com/college-football/player/_/id/4568304/ousman-traore
# ['Issiah', 'Walker,', 'Jr.']
# Issiah
# Issiah
# Issiah
# Walker,
# Walker,
# Walker
# Jr.
# Jr
# /issiah-walker-jr
# http://www.espn.com/college-football/player/_/id/4690796/issiah-walker-jr
# ['Chris', 'Washington']
# Chris
# Chris
# Chris
# Washington
# Washington
# /chris-washington
# http://www.espn.com/college-football/player/_/id/4685187/chris-washington
# ['Jarrid', 'Williams']
# Jarrid
# Jarrid
# Jarrid
# Williams
# Williams
# /jarrid-williams
# http://www.espn.com/college-football/player/_/id/3914628/jarrid-williams
# ['Jason', 'Blissett', 'Jr.']
# Jason
# Jason
# Jason
# Blissett
# Blissett
# Blissett
# Jr.
# Jr
# /jason-blissett-jr
# http://www.espn.com/college-football/player/_/id/4428982/jason-blissett-jr
# ['Earnest', 'Carter', 'Jr.']
# Earnest
# Earnest
# Earnest
# Carter
# Carter
# Carter
# Jr.
# Jr
# /earnest-carter-jr
# http://www.espn.com/college-football/player/_/id/4693621/earnest-carter-jr
# ['Sam', 'Fishman']
# Sam
# Sam
# Sam
# Fishman
# Fishman
# /sam-fishman
# http://www.espn.com/college-football/player/_/id/4691363/sam-fishman
# ['Jonathan', 'Ford']
# Jonathan
# Jonathan
# Jonathan
# Ford
# Ford
# /jonathan-ford
# http://www.espn.com/college-football/player/_/id/4259762/jonathan-ford
# ['Jared', 'Harrison-Hunte']
# Jared
# Jared
# Jared
# Harrison-Hunte
# Harrison-Hunte
# /jared-harrison-hunte
# http://www.espn.com/college-football/player/_/id/4427401/jared-harrison-hunte
# ['Jahfari', 'Harvey']
# Jahfari
# Jahfari
# Jahfari
# Harvey
# Harvey
# /jahfari-harvey
# http://www.espn.com/college-football/player/_/id/4427408/jahfari-harvey
# ['Jalar', 'Holley']
# Jalar
# Jalar
# Jalar
# Holley
# Holley
# /jalar-holley
# http://www.espn.com/college-football/player/_/id/4429841/jalar-holley
# ['Bryan', 'Levine']
# Bryan
# Bryan
# Bryan
# Levine
# Levine
# /bryan-levine
# http://www.espn.com/college-football/player/_/id/4568299/bryan-levine
# ['Jordan', 'Miller']
# Jordan
# Jordan
# Jordan
# Miller
# Miller
# /jordan-miller
# http://www.espn.com/college-football/player/_/id/4362524/jordan-miller
# ['Josh', 'Neely']
# Josh
# Josh
# Josh
# Neely
# Neely
# /josh-neely
# http://www.espn.com/college-football/player/_/id/4568307/josh-neely
# ['Jaelan', 'Phillips']
# Jaelan
# Jaelan
# Jaelan
# Phillips
# Phillips
# /jaelan-phillips
# http://www.espn.com/college-football/player/_/id/4242975/jaelan-phillips
# ['Elijah', 'Roberts']
# Elijah
# Elijah
# Elijah
# Roberts
# Roberts
# /elijah-roberts
# http://www.espn.com/college-football/player/_/id/4690795/elijah-roberts
# ['Quincy', 'Roche']
# Quincy
# Quincy
# Quincy
# Roche
# Roche
# /quincy-roche
# http://www.espn.com/college-football/player/_/id/4044145/quincy-roche
# ['Michael', 'Scibelli']
# Michael
# Michael
# Michael
# Scibelli
# Scibelli
# /michael-scibelli
# http://www.espn.com/college-football/player/_/id/4373239/michael-scibelli
# ['Nesta', 'Jade', 'Silvera']
# Nesta
# Nesta
# Nesta
# Jade
# Jade
# Jade
# Silvera
# Silvera
# /nesta-jade-silvera
# http://www.espn.com/college-football/player/_/id/4362497/nesta-jade-silvera
# ['Cameron', 'Williams']
# Cameron
# Cameron
# Cameron
# Williams
# Williams
# /cameron-williams
# http://www.espn.com/college-football/player/_/id/4568293/cameron-williams
# ['Chantz', 'Williams']
# Chantz
# Chantz
# Chantz
# Williams
# Williams
# /chantz-williams
# http://www.espn.com/college-football/player/_/id/4430813/chantz-williams
# ['Quentin', 'Williams']
# Quentin
# Quentin
# Quentin
# Williams
# Williams
# /quentin-williams
# http://www.espn.com/college-football/player/_/id/4690798/quentin-williams
# ['Colvin', 'Alford']
# Colvin
# Colvin
# Colvin
# Alford
# Alford
# /colvin-alford
# http://www.espn.com/college-football/player/_/id/4240640/colvin-alford
# ['Tirek', 'Austin-Cave']
# Tirek
# Tirek
# Tirek
# Austin-Cave
# Austin-Cave
# /tirek-austin-cave
# http://www.espn.com/college-football/player/_/id/4430917/tirek-austin-cave
# ['Sam', 'Brooks', 'Jr.']
# Sam
# Sam
# Sam
# Brooks
# Brooks
# Brooks
# Jr.
# Jr
# /sam-brooks-jr
# http://www.espn.com/college-football/player/_/id/4568292/sam-brooks-jr
# ['Graden', 'Feldmann']
# Graden
# Graden
# Graden
# Feldmann
# Feldmann
# /graden-feldmann
# http://www.espn.com/college-football/player/_/id/4692501/graden-feldmann
# ['Corey', 'Flagg', 'Jr.']
# Corey
# Corey
# Corey
# Flagg
# Flagg
# Flagg
# Jr.
# Jr
# /corey-flagg-jr
# http://www.espn.com/college-football/player/_/id/4685185/corey-flagg-jr
# ['Gilbert', 'Frierson']
# Gilbert
# Gilbert
# Gilbert
# Frierson
# Frierson
# /gilbert-frierson
# http://www.espn.com/college-football/player/_/id/4362498/gilbert-frierson
# ['Jake', 'Hoffman']
# Jake
# Jake
# Jake
# Hoffman
# Hoffman
# /jake-hoffman
# http://www.espn.com/college-football/player/_/id/4568300/jake-hoffman
# ['Avery', 'Huff']
# Avery
# Avery
# Avery
# Huff
# Huff
# /avery-huff
# http://www.espn.com/college-football/player/_/id/4574755/avery-huff
# ['Bradley', 'Jennings', 'Jr.']
# Bradley
# Bradley
# Bradley
# Jennings
# Jennings
# Jennings
# Jr.
# Jr
# /bradley-jennings-jr
# http://www.espn.com/college-football/player/_/id/4240642/bradley-jennings-jr
# ['Patrick', 'Joyner', 'Jr.']
# Patrick
# Patrick
# Patrick
# Joyner
# Joyner
# Joyner
# Jr.
# Jr
# /patrick-joyner-jr
# http://www.espn.com/college-football/player/_/id/4362518/patrick-joyner-jr
# ['Zach', 'McCloud']
# Zach
# Zach
# Zach
# McCloud
# McCloud
# /zach-mccloud
# http://www.espn.com/college-football/player/_/id/4037464/zach-mccloud
# ['Ryan', 'Ragone']
# Ryan
# Ryan
# Ryan
# Ragone
# Ragone
# /ryan-ragone
# http://www.espn.com/college-football/player/_/id/4373583/ryan-ragone
# ['Shane', 'Sawyer']
# Shane
# Shane
# Shane
# Sawyer
# Sawyer
# /shane-sawyer
# http://www.espn.com/college-football/player/_/id/4691366/shane-sawyer
# ['Keontra', 'Smith']
# Keontra
# Keontra
# Keontra
# Smith
# Smith
# /keontra-smith
# http://www.espn.com/college-football/player/_/id/4426471/keontra-smith
# ['Zac', 'Smith']
# Zac
# Zac
# Zac
# Smith
# Smith
# /zac-smith
# http://www.espn.com/college-football/player/_/id/4568295/zac-smith
# ['Waynmon', 'Steed']
# Waynmon
# Waynmon
# Waynmon
# Steed
# Steed
# /waynmon-steed
# http://www.espn.com/college-football/player/_/id/4240632/waynmon-steed
# ['Al', 'Blades', 'Jr.']
# Al
# Al
# Al
# Blades
# Blades
# Blades
# Jr.
# Jr
# /al-blades-jr
# http://www.espn.com/college-football/player/_/id/4362500/al-blades-jr
# ['Suleman', 'Burrows']
# Suleman
# Suleman
# Suleman
# Burrows
# Burrows
# /suleman-burrows
# http://www.espn.com/college-football/player/_/id/4362525/suleman-burrows
# ['Marcus', 'Clarke']
# Marcus
# Marcus
# Marcus
# Clarke
# Clarke
# /marcus-clarke
# http://www.espn.com/college-football/player/_/id/4690793/marcus-clarke
# ["Te'Cory", 'Couch']
# Te'Cory
# Te'Cory
# TeCory
# Couch
# Couch
# /tecory-couch
# http://www.espn.com/college-football/player/_/id/4427348/tecory-couch
# ['Isaiah', 'Dunson']
# Isaiah
# Isaiah
# Isaiah
# Dunson
# Dunson
# /isaiah-dunson
# http://www.espn.com/college-football/player/_/id/4691362/isaiah-dunson
# ['Luis', 'Gutierrez', 'Jr.']
# Luis
# Luis
# Luis
# Gutierrez
# Gutierrez
# Gutierrez
# Jr.
# Jr
# /luis-gutierrez-jr
# http://www.espn.com/college-football/player/_/id/4568298/luis-gutierrez-jr
# ['DJ', 'Ivey']
# DJ
# DJ
# DJ
# Ivey
# Ivey
# /dj-ivey
# http://www.espn.com/college-football/player/_/id/4362502/dj-ivey
# ['Christian', 'Williams']
# Christian
# Christian
# Christian
# Williams
# Williams
# /christian-williams
# http://www.espn.com/college-football/player/_/id/4568294/christian-williams
# ['Gannon', 'Feldmann']
# Gannon
# Gannon
# Gannon
# Feldmann
# Feldmann
# /gannon-feldmann
# http://www.espn.com/college-football/player/_/id/4568297/gannon-feldmann
# ['Brian', 'Balom']
# Brian
# Brian
# Brian
# Balom
# Balom
# /brian-balom
# http://www.espn.com/college-football/player/_/id/4690792/brian-balom
# ['Andrew', 'Barnes']
# Andrew
# Andrew
# Andrew
# Barnes
# Barnes
# /andrew-barnes
# http://www.espn.com/college-football/player/_/id/4568296/andrew-barnes
# ['Bubba', 'Bolden']
# Bubba
# Bubba
# Bubba
# Bolden
# Bolden
# /bubba-bolden
# http://www.espn.com/college-football/player/_/id/4259631/bubba-bolden
# ['Amari', 'Carter']
# Amari
# Amari
# Amari
# Carter
# Carter
# /amari-carter
# http://www.espn.com/college-football/player/_/id/4240627/amari-carter
# ['Gurvan', 'Hall', 'Jr.']
# Gurvan
# Gurvan
# Gurvan
# Hall
# Hall
# Hall
# Jr.
# Jr
# /gurvan-hall-jr
# http://www.espn.com/college-football/player/_/id/4362510/gurvan-hall-jr
# ['Jalen', 'Harrell']
# Jalen
# Jalen
# Jalen
# Harrell
# Harrell
# /jalen-harrell
# http://www.espn.com/college-football/player/_/id/4690794/jalen-harrell
# ['Keshawn', 'Washington']
# Keshawn
# Keshawn
# Keshawn
# Washington
# Washington
# /keshawn-washington
# http://www.espn.com/college-football/player/_/id/4432621/keshawn-washington
# ['Avantae', 'Williams']
# Avantae
# Avantae
# Avantae
# Williams
# Williams
# /avantae-williams
# http://www.espn.com/college-football/player/_/id/4690797/avantae-williams
# ['Jose', 'Borregales']
# Jose
# Jose
# Jose
# Borregales
# Borregales
# /jose-borregales
# http://www.espn.com/college-football/player/_/id/4046356/jose-borregales
# ['Turner', 'Davidson']
# Turner
# Turner
# Turner
# Davidson
# Davidson
# /turner-davidson
# http://www.espn.com/college-football/player/_/id/4240645/turner-davidson
# ['Camden', 'Price']
# Camden
# Camden
# Camden
# Price
# Price
# /camden-price
# http://www.espn.com/college-football/player/_/id/4373235/camden-price
# ['Sebastian', 'Przytula']
# Sebastian
# Sebastian
# Sebastian
# Przytula
# Przytula
# /sebastian-przytula
# http://www.espn.com/college-football/player/_/id/4691365/sebastian-przytula
# ['Matias', 'Gasc']
# Matias
# Matias
# Matias
# Gasc
# Gasc
# /matias-gasc
# http://www.espn.com/college-football/player/_/id/4030040/matias-gasc
# ['Lou', 'Hedley']
# Lou
# Lou
# Lou
# Hedley
# Hedley
# /lou-hedley
# http://www.espn.com/college-football/player/_/id/4568308/lou-hedley
# ['Fred', 'Potter']
# Fred
# Fred
# Fred
# Potter
# Potter
# /fred-potter
# http://www.espn.com/college-football/player/_/id/4691364/fred-potter
# ['Clay', 'James']
# Clay
# Clay
# Clay
# James
# James
# /clay-james
# http://www.espn.com/college-football/player/_/id/4373238/clay-james
# ['Alan', 'Nadelsticher']
# Alan
# Alan
# Alan
# Nadelsticher
# Nadelsticher
# /alan-nadelsticher
# http://www.espn.com/college-football/player/_/id/4568303/alan-nadelsticher
# ['Mason', 'Napper']
# Mason
# Mason
# Mason
# Napper
# Napper
# /mason-napper
# http://www.espn.com/college-football/player/_/id/4568302/mason-napper

# %%
# !cat roster.py
# Out:
# # YOUR CODE HERE
# #raise NotImplementedError()
# import requests
# import re
# from requests.exceptions import HTTPError
# from bs4 import BeautifulSoup
#
# def get_team_url(team_id, team_name):
#     url = "https://www.espn.com/college-football/team/roster/_/id/" + str(team_id) + "/"
#     real_team_name = team_name.split( )
#     #print(real_team_name)
#     i = 1
#     while (len(real_team_name) > i):
#         url = url + real_team_name[i-1].lower()+"-"
#         i = i + 1
#     else:
#         url = url + real_team_name[i-1].lower()
#     return url
#
# def extract_team_roster(team_id, team_name):
#     """
#     Extract the team roster for a NCAA college football team
#
#     Args:
#         team_id: the id of a NACC football team assigned by ESPN
#         team_name: the name of the football team
#
#     Returns:
#         a list of dict representing the roster of the entire team.
#     """
#     #team_id = 150
#     #team_name = "Duke Blue Devils"
#     roster = []
#     def mysplit(s, ex):
#         head = s.rstrip(ex)
#         tail = s[len(head):]
#         return head, tail
#
#     def is_player_row(tag):
#         if tag.name == 'tr' and tag.has_attr('data-idx'):
#             return True
#         return False
#
#     #Computing Team URL
#     url = get_team_url(team_id, team_name)
#
#     #Create a BeautifulSoup Object
#     response = requests.get(url)
#     html = response.content
#     soup = BeautifulSoup(html, 'html.parser')
#
#     #Finding Team Name
#     team_tag = soup.find('h1', string=re.compile(' Roster$'))
#
#     #Searching For Team Group
#     groups = soup.find_all(class_="Table__Title", string=["Offense", "Defense", "Special Teams"])
#     #print(len(groups), "groups")
#     #for g in groups:
#         #print(g)
#
#     #Finding the Column Names
#     col_names = []
#     for g in groups:
#         t = g.find_next("table")
#         for c in t.thead.tr.children:
#             col_names.append(c.text)
#
#     #Find the Attributes of a Player
#     players = []
#     id_list = []
#     for x in groups :
#         table = x.find_next("table")
#         for c in table.tbody.find_all(is_player_row):
#             tds = c.find_all('td')
#             cols = []
#             for td in tds:
#                 cols.append(td.get_text())
#             players.append(cols)
#         for aPlayer in players :
#             player = {}
#             name = mysplit(aPlayer[1], '0123456789')
#             player["player_name"] = name[0]
#
#             player_url_name = name[0].split()
#             print(player_url_name)
#             totalURL = ""
#             i = 1
#             for x in player_url_name :
#                 print(x)
#                 if i != len(player_url_name) :
#                     if x.find(".") :
#                         x = x.replace('.', '')
#                     if x.find('\'') :
#                         print(x)
#                         x = x.replace('\'', '')
#                     if x.find(',') :
#                         x = x.replace(',', '')
#                     print(x)
#                     totalURL = totalURL + x.lower() + "-"
#                 else :
#                     if x.find(".") :
#                         x = x.replace('.', '')
#                     if x.find('\'') :
#                         print(x)
#                         x = x.replace('\'', '')
#                     if x.find(',') :
#                         x = x.replace(',', '')
#                     if x != '' :
#                         #print(x)
#                         totalURL = totalURL + x.lower()
#                 i = i + 1
#             totalURL = '/' + totalURL
#             print(totalURL)
#             print(soup.find('a', href=re.compile(totalURL))['href'])
#             id = soup.find('a', href=re.compile(totalURL))['href']
#             id = re.sub('http://www.espn.com/college-football/player/_/id/', '', id)
#             id = re.sub(totalURL, '', id)
#             if id_list.count(id) == 0:
#                 id_list.append(id)
#                 player["player_id"] = id
#                 if name[1] == '' :
#                     player["player_no"] = "NA"
#                 else :
#                     player["player_no"] = name[1]
#                 player["POS"] = aPlayer[2]
#                 player["HT"] = aPlayer[3]
#                 player["WT"] = aPlayer[4]
#                 player["Class"] = aPlayer[5]
#                 player["Birthplace"] = aPlayer[6]
#                 #print(player)
#                 roster.append(player)
#
#     # YOUR CODE HERE
#     #raise NotImplementedError()
#     return roster

# %%
import os
assert os.path.exists("roster.py")

# %%
try:
    from bs4 import BeautifulSoup
    import requests
    from roster import get_team_url, extract_team_roster
    
    clemson_tiger_roster = extract_team_roster(258, "Virginia Cavaliers")
except:
    raise AssertionError("could not import")
# Out:
# ['Ira', 'Armstead']
# Ira
# Ira
# Ira
# Armstead
# Armstead
# /ira-armstead
# http://www.espn.com/college-football/player/_/id/4429219/ira-armstead
# ['Brennan', 'Armstrong']
# Brennan
# Brennan
# Brennan
# Armstrong
# Armstrong
# /brennan-armstrong
# http://www.espn.com/college-football/player/_/id/4370775/brennan-armstrong
# ['Jared', 'Rayman']
# Jared
# Jared
# Jared
# Rayman
# Rayman
# /jared-rayman
# http://www.espn.com/college-football/player/_/id/4568497/jared-rayman
# ['Lindell', 'Stone']
# Lindell
# Lindell
# Lindell
# Stone
# Stone
# /lindell-stone
# http://www.espn.com/college-football/player/_/id/4240850/lindell-stone
# ['Keytaon', 'Thompson']
# Keytaon
# Keytaon
# Keytaon
# Thompson
# Thompson
# /keytaon-thompson
# http://www.espn.com/college-football/player/_/id/4242243/keytaon-thompson
# ['Chris', 'Barfield']
# Chris
# Chris
# Chris
# Barfield
# Barfield
# /chris-barfield
# http://www.espn.com/college-football/player/_/id/4684946/chris-barfield
# ['Mike', 'Hollins']
# Mike
# Mike
# Mike
# Hollins
# Hollins
# /mike-hollins
# http://www.espn.com/college-football/player/_/id/4427503/mike-hollins
# ['Perris', 'Jones']
# Perris
# Perris
# Perris
# Jones
# Jones
# /perris-jones
# http://www.espn.com/college-football/player/_/id/4370794/perris-jones
# ['Billy', 'Kemp', 'IV']
# Billy
# Billy
# Billy
# Kemp
# Kemp
# Kemp
# IV
# IV
# /billy-kemp-iv
# http://www.espn.com/college-football/player/_/id/4370797/billy-kemp-iv
# ['Shane', 'Simpson']
# Shane
# Shane
# Shane
# Simpson
# Simpson
# /shane-simpson
# http://www.espn.com/college-football/player/_/id/3935232/shane-simpson
# ['Wayne', 'Taulapapa']
# Wayne
# Wayne
# Wayne
# Taulapapa
# Taulapapa
# /wayne-taulapapa
# http://www.espn.com/college-football/player/_/id/4370813/wayne-taulapapa
# ['Ronnie', 'Walker', 'Jr.']
# Ronnie
# Ronnie
# Ronnie
# Walker
# Walker
# Walker
# Jr.
# Jr
# /ronnie-walker-jr
# http://www.espn.com/college-football/player/_/id/4360425/ronnie-walker-jr
# ['Justin', 'Zollar']
# Justin
# Justin
# Justin
# Zollar
# Zollar
# /justin-zollar
# http://www.espn.com/college-football/player/_/id/4240857/justin-zollar
# ['Jamari', 'Peacock']
# Jamari
# Jamari
# Jamari
# Peacock
# Peacock
# /jamari-peacock
# http://www.espn.com/college-football/player/_/id/4240844/jamari-peacock
# ['Andrew', 'Yavinsky']
# Andrew
# Andrew
# Andrew
# Yavinsky
# Yavinsky
# /andrew-yavinsky
# http://www.espn.com/college-football/player/_/id/4240854/andrew-yavinsky
# ['Nathaniel', 'Beal', 'III']
# Nathaniel
# Nathaniel
# Nathaniel
# Beal
# Beal
# Beal
# III
# III
# /nathaniel-beal-iii
# http://www.espn.com/college-football/player/_/id/4426654/nathaniel-beal-iii
# ['Josh', 'Clifford']
# Josh
# Josh
# Josh
# Clifford
# Clifford
# /josh-clifford
# http://www.espn.com/college-football/player/_/id/4370781/josh-clifford
# ['Lavel', 'Davis']
# Lavel
# Lavel
# Lavel
# Davis
# Davis
# /lavel-davis
# http://www.espn.com/college-football/player/_/id/4431058/lavel-davis
# ['Dorien', 'Goddard']
# Dorien
# Dorien
# Dorien
# Goddard
# Goddard
# /dorien-goddard
# http://www.espn.com/college-football/player/_/id/4427287/dorien-goddard
# ['Jalen', 'Harrison']
# Jalen
# Jalen
# Jalen
# Harrison
# Harrison
# /jalen-harrison
# http://www.espn.com/college-football/player/_/id/4228300/jalen-harrison
# ["Ra'Shaun", 'Henry']
# Ra'Shaun
# Ra'Shaun
# RaShaun
# Henry
# Henry
# /rashaun-henry
# http://www.espn.com/college-football/player/_/id/4032625/rashaun-henry
# ['Terrell', 'Jana']
# Terrell
# Terrell
# Terrell
# Jana
# Jana
# /terrell-jana
# http://www.espn.com/college-football/player/_/id/4240838/terrell-jana
# ['Tavares', 'Kelly', 'Jr.']
# Tavares
# Tavares
# Tavares
# Kelly
# Kelly
# Kelly
# Jr.
# Jr
# /tavares-kelly-jr
# http://www.espn.com/college-football/player/_/id/4370796/tavares-kelly-jr
# ['Zack', 'Kindel']
# Zack
# Zack
# Zack
# Kindel
# Kindel
# /zack-kindel
# http://www.espn.com/college-football/player/_/id/4568493/zack-kindel
# ['Hayden', 'Mitchell']
# Hayden
# Hayden
# Hayden
# Mitchell
# Mitchell
# /hayden-mitchell
# http://www.espn.com/college-football/player/_/id/4240842/hayden-mitchell
# ['Sean', 'Moore']
# Sean
# Sean
# Sean
# Moore
# Moore
# /sean-moore
# http://www.espn.com/college-football/player/_/id/4568495/sean-moore
# ['Ugo', 'Obasi']
# Ugo
# Ugo
# Ugo
# Obasi
# Obasi
# /ugo-obasi
# http://www.espn.com/college-football/player/_/id/4370806/ugo-obasi
# ['Demick', 'Starling']
# Demick
# Demick
# Demick
# Starling
# Starling
# /demick-starling
# http://www.espn.com/college-football/player/_/id/4613165/demick-starling
# ['Luke', 'Wentz']
# Luke
# Luke
# Luke
# Wentz
# Wentz
# /luke-wentz
# http://www.espn.com/college-football/player/_/id/4428820/luke-wentz
# ['Brandon', 'White']
# Brandon
# Brandon
# Brandon
# White
# White
# /brandon-white
# http://www.espn.com/college-football/player/_/id/4370819/brandon-white
# ['Dontayvion', 'Wicks']
# Dontayvion
# Dontayvion
# Dontayvion
# Wicks
# Wicks
# /dontayvion-wicks
# http://www.espn.com/college-football/player/_/id/4428850/dontayvion-wicks
# ['T.J.', 'Kitts']
# T.J.
# TJ
# TJ
# Kitts
# Kitts
# /tj-kitts
# http://www.espn.com/college-football/player/_/id/4257941/tj-kitts
# ['Mike', 'Kosar']
# Mike
# Mike
# Mike
# Kosar
# Kosar
# /mike-kosar
# http://www.espn.com/college-football/player/_/id/4568494/mike-kosar
# ['Grant', 'Misch']
# Grant
# Grant
# Grant
# Misch
# Misch
# /grant-misch
# http://www.espn.com/college-football/player/_/id/4370803/grant-misch
# ['Joshua', 'Rawlings']
# Joshua
# Joshua
# Joshua
# Rawlings
# Rawlings
# /joshua-rawlings
# http://www.espn.com/college-football/player/_/id/4565360/joshua-rawlings
# ['Sackett', 'Wood', 'Jr.']
# Sackett
# Sackett
# Sackett
# Wood
# Wood
# Wood
# Jr.
# Jr
# /sackett-wood-jr
# http://www.espn.com/college-football/player/_/id/4684953/sackett-wood-jr
# ['Tyler', 'Fannin']
# Tyler
# Tyler
# Tyler
# Fannin
# Fannin
# /tyler-fannin
# http://www.espn.com/college-football/player/_/id/4240834/tyler-fannin
# ['Olusegun', 'Oluwatimi']
# Olusegun
# Olusegun
# Olusegun
# Oluwatimi
# Oluwatimi
# /olusegun-oluwatimi
# http://www.espn.com/college-football/player/_/id/4370807/olusegun-oluwatimi
# ['Kariem', 'Al', 'Soufi']
# Kariem
# Kariem
# Kariem
# Al
# Al
# Al
# Soufi
# Soufi
# /kariem-al-soufi
# http://www.espn.com/college-football/player/_/id/4426547/kariem-al-soufi
# ['Joe', 'Bissinger']
# Joe
# Joe
# Joe
# Bissinger
# Bissinger
# /joe-bissinger
# http://www.espn.com/college-football/player/_/id/4370777/joe-bissinger
# ['Zachary', 'Teter']
# Zachary
# Zachary
# Zachary
# Teter
# Teter
# /zachary-teter
# http://www.espn.com/college-football/player/_/id/4428654/zachary-teter
# ['Gerrik', 'Vollmer']
# Gerrik
# Gerrik
# Gerrik
# Vollmer
# Vollmer
# /gerrik-vollmer
# http://www.espn.com/college-football/player/_/id/4240853/gerrik-vollmer
# ['Jestus', 'Johnson', 'III']
# Jestus
# Jestus
# Jestus
# Johnson
# Johnson
# Johnson
# III
# III
# /jestus-johnson-iii
# http://www.espn.com/college-football/player/_/id/4430074/jestus-johnson-iii
# ['Tommy', 'Christ']
# Tommy
# Tommy
# Tommy
# Christ
# Christ
# /tommy-christ
# http://www.espn.com/college-football/player/_/id/4240829/tommy-christ
# ['Derek', 'Devine']
# Derek
# Derek
# Derek
# Devine
# Devine
# /derek-devine
# http://www.espn.com/college-football/player/_/id/4370784/derek-devine
# ['Alex', 'Gellerstedt']
# Alex
# Alex
# Alex
# Gellerstedt
# Gellerstedt
# /alex-gellerstedt
# http://www.espn.com/college-football/player/_/id/4033747/alex-gellerstedt
# ['Chris', 'Glaser']
# Chris
# Chris
# Chris
# Glaser
# Glaser
# /chris-glaser
# http://www.espn.com/college-football/player/_/id/4240836/chris-glaser
# ['Bobby', 'Haskins']
# Bobby
# Bobby
# Bobby
# Haskins
# Haskins
# /bobby-haskins
# http://www.espn.com/college-football/player/_/id/4370790/bobby-haskins
# ['Luke', 'Johnson']
# Luke
# Luke
# Luke
# Johnson
# Johnson
# /luke-johnson
# http://www.espn.com/college-football/player/_/id/4684949/luke-johnson
# ['Jack', 'Keenan']
# Jack
# Jack
# Jack
# Keenan
# Keenan
# /jack-keenan
# http://www.espn.com/college-football/player/_/id/4370795/jack-keenan
# ['Jonathan', 'Leech']
# Jonathan
# Jonathan
# Jonathan
# Leech
# Leech
# /jonathan-leech
# http://www.espn.com/college-football/player/_/id/4430032/jonathan-leech
# ['Colby', 'McGhee']
# Colby
# Colby
# Colby
# McGhee
# McGhee
# /colby-mcghee
# http://www.espn.com/college-football/player/_/id/4684950/colby-mcghee
# ['Ryan', 'Nelson']
# Ryan
# Ryan
# Ryan
# Nelson
# Nelson
# /ryan-nelson
# http://www.espn.com/college-football/player/_/id/4240843/ryan-nelson
# ['Dillon', 'Reinkensmeyer']
# Dillon
# Dillon
# Dillon
# Reinkensmeyer
# Reinkensmeyer
# /dillon-reinkensmeyer
# http://www.espn.com/college-football/player/_/id/4037592/dillon-reinkensmeyer
# ['Ryan', 'Swoboda']
# Ryan
# Ryan
# Ryan
# Swoboda
# Swoboda
# /ryan-swoboda
# http://www.espn.com/college-football/player/_/id/4240851/ryan-swoboda
# ['Ira', 'Armstead']
# Ira
# Ira
# Ira
# Armstead
# Armstead
# /ira-armstead
# http://www.espn.com/college-football/player/_/id/4429219/ira-armstead
# ['Brennan', 'Armstrong']
# Brennan
# Brennan
# Brennan
# Armstrong
# Armstrong
# /brennan-armstrong
# http://www.espn.com/college-football/player/_/id/4370775/brennan-armstrong
# ['Jared', 'Rayman']
# Jared
# Jared
# Jared
# Rayman
# Rayman
# /jared-rayman
# http://www.espn.com/college-football/player/_/id/4568497/jared-rayman
# ['Lindell', 'Stone']
# Lindell
# Lindell
# Lindell
# Stone
# Stone
# /lindell-stone
# http://www.espn.com/college-football/player/_/id/4240850/lindell-stone
# ['Keytaon', 'Thompson']
# Keytaon
# Keytaon
# Keytaon
# Thompson
# Thompson
# /keytaon-thompson
# http://www.espn.com/college-football/player/_/id/4242243/keytaon-thompson
# ['Chris', 'Barfield']
# Chris
# Chris
# Chris
# Barfield
# Barfield
# /chris-barfield
# http://www.espn.com/college-football/player/_/id/4684946/chris-barfield
# ['Mike', 'Hollins']
# Mike
# Mike
# Mike
# Hollins
# Hollins
# /mike-hollins
# http://www.espn.com/college-football/player/_/id/4427503/mike-hollins
# ['Perris', 'Jones']
# Perris
# Perris
# Perris
# Jones
# Jones
# /perris-jones
# http://www.espn.com/college-football/player/_/id/4370794/perris-jones
# ['Billy', 'Kemp', 'IV']
# Billy
# Billy
# Billy
# Kemp
# Kemp
# Kemp
# IV
# IV
# /billy-kemp-iv
# http://www.espn.com/college-football/player/_/id/4370797/billy-kemp-iv
# ['Shane', 'Simpson']
# Shane
# Shane
# Shane
# Simpson
# Simpson
# /shane-simpson
# http://www.espn.com/college-football/player/_/id/3935232/shane-simpson
# ['Wayne', 'Taulapapa']
# Wayne
# Wayne
# Wayne
# Taulapapa
# Taulapapa
# /wayne-taulapapa
# http://www.espn.com/college-football/player/_/id/4370813/wayne-taulapapa
# ['Ronnie', 'Walker', 'Jr.']
# Ronnie
# Ronnie
# Ronnie
# Walker
# Walker
# Walker
# Jr.
# Jr
# /ronnie-walker-jr
# http://www.espn.com/college-football/player/_/id/4360425/ronnie-walker-jr
# ['Justin', 'Zollar']
# Justin
# Justin
# Justin
# Zollar
# Zollar
# /justin-zollar
# http://www.espn.com/college-football/player/_/id/4240857/justin-zollar
# ['Jamari', 'Peacock']
# Jamari
# Jamari
# Jamari
# Peacock
# Peacock
# /jamari-peacock
# http://www.espn.com/college-football/player/_/id/4240844/jamari-peacock
# ['Andrew', 'Yavinsky']
# Andrew
# Andrew
# Andrew
# Yavinsky
# Yavinsky
# /andrew-yavinsky
# http://www.espn.com/college-football/player/_/id/4240854/andrew-yavinsky
# ['Nathaniel', 'Beal', 'III']
# Nathaniel
# Nathaniel
# Nathaniel
# Beal
# Beal
# Beal
# III
# III
# /nathaniel-beal-iii
# http://www.espn.com/college-football/player/_/id/4426654/nathaniel-beal-iii
# ['Josh', 'Clifford']
# Josh
# Josh
# Josh
# Clifford
# Clifford
# /josh-clifford
# http://www.espn.com/college-football/player/_/id/4370781/josh-clifford
# ['Lavel', 'Davis']
# Lavel
# Lavel
# Lavel
# Davis
# Davis
# /lavel-davis
# http://www.espn.com/college-football/player/_/id/4431058/lavel-davis
# ['Dorien', 'Goddard']
# Dorien
# Dorien
# Dorien
# Goddard
# Goddard
# /dorien-goddard
# http://www.espn.com/college-football/player/_/id/4427287/dorien-goddard
# ['Jalen', 'Harrison']
# Jalen
# Jalen
# Jalen
# Harrison
# Harrison
# /jalen-harrison
# http://www.espn.com/college-football/player/_/id/4228300/jalen-harrison
# ["Ra'Shaun", 'Henry']
# Ra'Shaun
# Ra'Shaun
# RaShaun
# Henry
# Henry
# /rashaun-henry
# http://www.espn.com/college-football/player/_/id/4032625/rashaun-henry
# ['Terrell', 'Jana']
# Terrell
# Terrell
# Terrell
# Jana
# Jana
# /terrell-jana
# http://www.espn.com/college-football/player/_/id/4240838/terrell-jana
# ['Tavares', 'Kelly', 'Jr.']
# Tavares
# Tavares
# Tavares
# Kelly
# Kelly
# Kelly
# Jr.
# Jr
# /tavares-kelly-jr
# http://www.espn.com/college-football/player/_/id/4370796/tavares-kelly-jr
# ['Zack', 'Kindel']
# Zack
# Zack
# Zack
# Kindel
# Kindel
# /zack-kindel
# http://www.espn.com/college-football/player/_/id/4568493/zack-kindel
# ['Hayden', 'Mitchell']
# Hayden
# Hayden
# Hayden
# Mitchell
# Mitchell
# /hayden-mitchell
# http://www.espn.com/college-football/player/_/id/4240842/hayden-mitchell
# ['Sean', 'Moore']
# Sean
# Sean
# Sean
# Moore
# Moore
# /sean-moore
# http://www.espn.com/college-football/player/_/id/4568495/sean-moore
# ['Ugo', 'Obasi']
# Ugo
# Ugo
# Ugo
# Obasi
# Obasi
# /ugo-obasi
# http://www.espn.com/college-football/player/_/id/4370806/ugo-obasi
# ['Demick', 'Starling']
# Demick
# Demick
# Demick
# Starling
# Starling
# /demick-starling
# http://www.espn.com/college-football/player/_/id/4613165/demick-starling
# ['Luke', 'Wentz']
# Luke
# Luke
# Luke
# Wentz
# Wentz
# /luke-wentz
# http://www.espn.com/college-football/player/_/id/4428820/luke-wentz
# ['Brandon', 'White']
# Brandon
# Brandon
# Brandon
# White
# White
# /brandon-white
# http://www.espn.com/college-football/player/_/id/4370819/brandon-white
# ['Dontayvion', 'Wicks']
# Dontayvion
# Dontayvion
# Dontayvion
# Wicks
# Wicks
# /dontayvion-wicks
# http://www.espn.com/college-football/player/_/id/4428850/dontayvion-wicks
# ['T.J.', 'Kitts']
# T.J.
# TJ
# TJ
# Kitts
# Kitts
# /tj-kitts
# http://www.espn.com/college-football/player/_/id/4257941/tj-kitts
# ['Mike', 'Kosar']
# Mike
# Mike
# Mike
# Kosar
# Kosar
# /mike-kosar
# http://www.espn.com/college-football/player/_/id/4568494/mike-kosar
# ['Grant', 'Misch']
# Grant
# Grant
# Grant
# Misch
# Misch
# /grant-misch
# http://www.espn.com/college-football/player/_/id/4370803/grant-misch
# ['Joshua', 'Rawlings']
# Joshua
# Joshua
# Joshua
# Rawlings
# Rawlings
# /joshua-rawlings
# http://www.espn.com/college-football/player/_/id/4565360/joshua-rawlings
# ['Sackett', 'Wood', 'Jr.']
# Sackett
# Sackett
# Sackett
# Wood
# Wood
# Wood
# Jr.
# Jr
# /sackett-wood-jr
# http://www.espn.com/college-football/player/_/id/4684953/sackett-wood-jr
# ['Tyler', 'Fannin']
# Tyler
# Tyler
# Tyler
# Fannin
# Fannin
# /tyler-fannin
# http://www.espn.com/college-football/player/_/id/4240834/tyler-fannin
# ['Olusegun', 'Oluwatimi']
# Olusegun
# Olusegun
# Olusegun
# Oluwatimi
# Oluwatimi
# /olusegun-oluwatimi
# http://www.espn.com/college-football/player/_/id/4370807/olusegun-oluwatimi
# ['Kariem', 'Al', 'Soufi']
# Kariem
# Kariem
# Kariem
# Al
# Al
# Al
# Soufi
# Soufi
# /kariem-al-soufi
# http://www.espn.com/college-football/player/_/id/4426547/kariem-al-soufi
# ['Joe', 'Bissinger']
# Joe
# Joe
# Joe
# Bissinger
# Bissinger
# /joe-bissinger
# http://www.espn.com/college-football/player/_/id/4370777/joe-bissinger
# ['Zachary', 'Teter']
# Zachary
# Zachary
# Zachary
# Teter
# Teter
# /zachary-teter
# http://www.espn.com/college-football/player/_/id/4428654/zachary-teter
# ['Gerrik', 'Vollmer']
# Gerrik
# Gerrik
# Gerrik
# Vollmer
# Vollmer
# /gerrik-vollmer
# http://www.espn.com/college-football/player/_/id/4240853/gerrik-vollmer
# ['Jestus', 'Johnson', 'III']
# Jestus
# Jestus
# Jestus
# Johnson
# Johnson
# Johnson
# III
# III
# /jestus-johnson-iii
# http://www.espn.com/college-football/player/_/id/4430074/jestus-johnson-iii
# ['Tommy', 'Christ']
# Tommy
# Tommy
# Tommy
# Christ
# Christ
# /tommy-christ
# http://www.espn.com/college-football/player/_/id/4240829/tommy-christ
# ['Derek', 'Devine']
# Derek
# Derek
# Derek
# Devine
# Devine
# /derek-devine
# http://www.espn.com/college-football/player/_/id/4370784/derek-devine
# ['Alex', 'Gellerstedt']
# Alex
# Alex
# Alex
# Gellerstedt
# Gellerstedt
# /alex-gellerstedt
# http://www.espn.com/college-football/player/_/id/4033747/alex-gellerstedt
# ['Chris', 'Glaser']
# Chris
# Chris
# Chris
# Glaser
# Glaser
# /chris-glaser
# http://www.espn.com/college-football/player/_/id/4240836/chris-glaser
# ['Bobby', 'Haskins']
# Bobby
# Bobby
# Bobby
# Haskins
# Haskins
# /bobby-haskins
# http://www.espn.com/college-football/player/_/id/4370790/bobby-haskins
# ['Luke', 'Johnson']
# Luke
# Luke
# Luke
# Johnson
# Johnson
# /luke-johnson
# http://www.espn.com/college-football/player/_/id/4684949/luke-johnson
# ['Jack', 'Keenan']
# Jack
# Jack
# Jack
# Keenan
# Keenan
# /jack-keenan
# http://www.espn.com/college-football/player/_/id/4370795/jack-keenan
# ['Jonathan', 'Leech']
# Jonathan
# Jonathan
# Jonathan
# Leech
# Leech
# /jonathan-leech
# http://www.espn.com/college-football/player/_/id/4430032/jonathan-leech
# ['Colby', 'McGhee']
# Colby
# Colby
# Colby
# McGhee
# McGhee
# /colby-mcghee
# http://www.espn.com/college-football/player/_/id/4684950/colby-mcghee
# ['Ryan', 'Nelson']
# Ryan
# Ryan
# Ryan
# Nelson
# Nelson
# /ryan-nelson
# http://www.espn.com/college-football/player/_/id/4240843/ryan-nelson
# ['Dillon', 'Reinkensmeyer']
# Dillon
# Dillon
# Dillon
# Reinkensmeyer
# Reinkensmeyer
# /dillon-reinkensmeyer
# http://www.espn.com/college-football/player/_/id/4037592/dillon-reinkensmeyer
# ['Ryan', 'Swoboda']
# Ryan
# Ryan
# Ryan
# Swoboda
# Swoboda
# /ryan-swoboda
# http://www.espn.com/college-football/player/_/id/4240851/ryan-swoboda
# ['Su', 'Agunloye']
# Su
# Su
# Su
# Agunloye
# Agunloye
# /su-agunloye
# http://www.espn.com/college-football/player/_/id/4684945/su-agunloye
# ['Adeeb', 'Atariwa']
# Adeeb
# Adeeb
# Adeeb
# Atariwa
# Atariwa
# /adeeb-atariwa
# http://www.espn.com/college-football/player/_/id/4028748/adeeb-atariwa
# ['Jahmeer', 'Carter']
# Jahmeer
# Jahmeer
# Jahmeer
# Carter
# Carter
# /jahmeer-carter
# http://www.espn.com/college-football/player/_/id/4429371/jahmeer-carter
# ['Sam', 'Galletta']
# Sam
# Sam
# Sam
# Galletta
# Galletta
# /sam-galletta
# http://www.espn.com/college-football/player/_/id/4568488/sam-galletta
# ['Nusi', 'Malani']
# Nusi
# Nusi
# Nusi
# Malani
# Malani
# /nusi-malani
# http://www.espn.com/college-football/player/_/id/4430306/nusi-malani
# ['Jordan', 'Redmond']
# Jordan
# Jordan
# Jordan
# Redmond
# Redmond
# /jordan-redmond
# http://www.espn.com/college-football/player/_/id/4370809/jordan-redmond
# ['Samson', 'Reed']
# Samson
# Samson
# Samson
# Reed
# Reed
# /samson-reed
# http://www.espn.com/college-football/player/_/id/4370810/samson-reed
# ['Mandy', 'Alonso']
# Mandy
# Mandy
# Mandy
# Alonso
# Alonso
# /mandy-alonso
# http://www.espn.com/college-football/player/_/id/4240822/mandy-alonso
# ['Sam', 'Bond']
# Sam
# Sam
# Sam
# Bond
# Bond
# /sam-bond
# http://www.espn.com/college-football/player/_/id/4684947/sam-bond
# ['Richard', 'Burney']
# Richard
# Richard
# Richard
# Burney
# Burney
# /richard-burney
# http://www.espn.com/college-football/player/_/id/3917922/richard-burney
# ['Nate', 'Morris']
# Nate
# Nate
# Nate
# Morris
# Morris
# /nate-morris
# http://www.espn.com/college-football/player/_/id/4684951/nate-morris
# ['Ben', 'Smiley', 'III']
# Ben
# Ben
# Ben
# Smiley
# Smiley
# Smiley
# III
# III
# /ben-smiley-iii
# http://www.espn.com/college-football/player/_/id/4430499/ben-smiley-iii
# ['Jowon', 'Briggs']
# Jowon
# Jowon
# Jowon
# Briggs
# Briggs
# /jowon-briggs
# http://www.espn.com/college-football/player/_/id/4426676/jowon-briggs
# ['Aaron', 'Faumui']
# Aaron
# Aaron
# Aaron
# Faumui
# Faumui
# /aaron-faumui
# http://www.espn.com/college-football/player/_/id/4370786/aaron-faumui
# ['Josh', 'Ahern']
# Josh
# Josh
# Josh
# Ahern
# Ahern
# /josh-ahern
# http://www.espn.com/college-football/player/_/id/4426541/josh-ahern
# ['Sam', 'Brady']
# Sam
# Sam
# Sam
# Brady
# Brady
# /sam-brady
# http://www.espn.com/college-football/player/_/id/4429292/sam-brady
# ['Elliott', 'Brown']
# Elliott
# Elliott
# Elliott
# Brown
# Brown
# /elliott-brown
# http://www.espn.com/college-football/player/_/id/4240826/elliott-brown
# ['Dre', 'Bryant']
# Dre
# Dre
# Dre
# Bryant
# Bryant
# /dre-bryant
# http://www.espn.com/college-football/player/_/id/4037578/dre-bryant
# ['Matt', 'Gahm']
# Matt
# Matt
# Matt
# Gahm
# Gahm
# /matt-gahm
# http://www.espn.com/college-football/player/_/id/4240835/matt-gahm
# ['John', 'Hardy']
# John
# John
# John
# Hardy
# Hardy
# /john-hardy
# http://www.espn.com/college-football/player/_/id/4684948/john-hardy
# ['T.C.', 'Harrison']
# T.C.
# TC
# TC
# Harrison
# Harrison
# /tc-harrison
# http://www.espn.com/college-football/player/_/id/4370789/tc-harrison
# ['Jonathan', 'Horton']
# Jonathan
# Jonathan
# Jonathan
# Horton
# Horton
# /jonathan-horton
# http://www.espn.com/college-football/player/_/id/4608680/jonathan-horton
# ['Nick', 'Jackson']
# Nick
# Nick
# Nick
# Jackson
# Jackson
# /nick-jackson
# http://www.espn.com/college-football/player/_/id/4568492/nick-jackson
# ['DaJuan', 'Moore']
# DaJuan
# DaJuan
# DaJuan
# Moore
# Moore
# /dajuan-moore
# http://www.espn.com/college-football/player/_/id/4370804/dajuan-moore
# ["D'Sean", 'Perry']
# D'Sean
# D'Sean
# DSean
# Perry
# Perry
# /dsean-perry
# http://www.espn.com/college-football/player/_/id/4428221/dsean-perry
# ['Jairus', 'Satiu']
# Jairus
# Jairus
# Jairus
# Satiu
# Satiu
# /jairus-satiu
# http://www.espn.com/college-football/player/_/id/4428429/jairus-satiu
# ['Brayden', 'Sheffer']
# Brayden
# Brayden
# Brayden
# Sheffer
# Sheffer
# /brayden-sheffer
# http://www.espn.com/college-football/player/_/id/4684952/brayden-sheffer
# ['Charles', 'Snowden']
# Charles
# Charles
# Charles
# Snowden
# Snowden
# /charles-snowden
# http://www.espn.com/college-football/player/_/id/4240849/charles-snowden
# ['Rob', 'Snyder']
# Rob
# Rob
# Rob
# Snyder
# Snyder
# /rob-snyder
# http://www.espn.com/college-football/player/_/id/4037595/rob-snyder
# ['Hunter', 'Stewart']
# Hunter
# Hunter
# Hunter
# Stewart
# Stewart
# /hunter-stewart
# http://www.espn.com/college-football/player/_/id/4568500/hunter-stewart
# ['Noah', 'Taylor']
# Noah
# Noah
# Noah
# Taylor
# Taylor
# /noah-taylor
# http://www.espn.com/college-football/player/_/id/4370814/noah-taylor
# ['Brandon', 'Williams']
# Brandon
# Brandon
# Brandon
# Williams
# Williams
# /brandon-williams
# http://www.espn.com/college-football/player/_/id/4429188/brandon-williams
# ['Zane', 'Zandier']
# Zane
# Zane
# Zane
# Zandier
# Zandier
# /zane-zandier
# http://www.espn.com/college-football/player/_/id/4240855/zane-zandier
# ['Jaylon', 'Baker']
# Jaylon
# Jaylon
# Jaylon
# Baker
# Baker
# /jaylon-baker
# http://www.espn.com/college-football/player/_/id/4370776/jaylon-baker
# ['Darrius', 'Bratton']
# Darrius
# Darrius
# Darrius
# Bratton
# Bratton
# /darrius-bratton
# http://www.espn.com/college-football/player/_/id/4240825/darrius-bratton
# ['Mark', 'Chichester']
# Mark
# Mark
# Mark
# Chichester
# Chichester
# /mark-chichester
# http://www.espn.com/college-football/player/_/id/4370779/mark-chichester
# ['Nick', 'Grant']
# Nick
# Nick
# Nick
# Grant
# Grant
# /nick-grant
# http://www.espn.com/college-football/player/_/id/4037583/nick-grant
# ['Heskin', 'Smith']
# Heskin
# Heskin
# Heskin
# Smith
# Smith
# /heskin-smith
# http://www.espn.com/college-football/player/_/id/4240848/heskin-smith
# ['Chayce', 'Chalmers']
# Chayce
# Chayce
# Chayce
# Chalmers
# Chalmers
# /chayce-chalmers
# http://www.espn.com/college-football/player/_/id/4426895/chayce-chalmers
# ['Antonio', 'Clary']
# Antonio
# Antonio
# Antonio
# Clary
# Clary
# /antonio-clary
# http://www.espn.com/college-football/player/_/id/4426931/antonio-clary
# ['Fentrell', 'Cypress', 'II']
# Fentrell
# Fentrell
# Fentrell
# Cypress
# Cypress
# Cypress
# II
# II
# /fentrell-cypress-ii
# http://www.espn.com/college-football/player/_/id/4429488/fentrell-cypress-ii
# ['Jake', 'Dewease']
# Jake
# Jake
# Jake
# Dewease
# Dewease
# /jake-dewease
# http://www.espn.com/college-football/player/_/id/4568485/jake-dewease
# ['Tenyeh', 'Dixon']
# Tenyeh
# Tenyeh
# Tenyeh
# Dixon
# Dixon
# /tenyeh-dixon
# http://www.espn.com/college-football/player/_/id/4429522/tenyeh-dixon
# ['Elijah', 'Gaines']
# Elijah
# Elijah
# Elijah
# Gaines
# Gaines
# /elijah-gaines
# http://www.espn.com/college-football/player/_/id/4429785/elijah-gaines
# ['Dave', 'Herard']
# Dave
# Dave
# Dave
# Herard
# Herard
# /dave-herard
# http://www.espn.com/college-football/player/_/id/4565536/dave-herard
# ['Donovan', 'Johnson']
# Donovan
# Donovan
# Donovan
# Johnson
# Johnson
# /donovan-johnson
# http://www.espn.com/college-football/player/_/id/4431177/donovan-johnson
# ['Coen', 'King']
# Coen
# Coen
# Coen
# King
# King
# /coen-king
# http://www.espn.com/college-football/player/_/id/4370799/coen-king
# ['Darnell', 'Pratt']
# Darnell
# Darnell
# Darnell
# Pratt
# Pratt
# /darnell-pratt
# http://www.espn.com/college-football/player/_/id/4240846/darnell-pratt
# ['Joseph', 'White']
# Joseph
# Joseph
# Joseph
# White
# White
# /joseph-white
# http://www.espn.com/college-football/player/_/id/4370820/joseph-white
# ["D'Angelo", 'Amos']
# D'Angelo
# D'Angelo
# DAngelo
# Amos
# Amos
# /dangelo-amos
# http://www.espn.com/college-football/player/_/id/4049429/dangelo-amos
# ['Joey', 'Blount']
# Joey
# Joey
# Joey
# Blount
# Blount
# /joey-blount
# http://www.espn.com/college-football/player/_/id/4240824/joey-blount
# ["De'Vante", 'Cross']
# De'Vante
# De'Vante
# DeVante
# Cross
# Cross
# /devante-cross
# http://www.espn.com/college-football/player/_/id/4037579/devante-cross
# ['Darren', 'Klein']
# Darren
# Darren
# Darren
# Klein
# Klein
# /darren-klein
# http://www.espn.com/college-football/player/_/id/4370800/darren-klein
# ['Brenton', 'Nelson']
# Brenton
# Brenton
# Brenton
# Nelson
# Nelson
# /brenton-nelson
# http://www.espn.com/college-football/player/_/id/4047915/brenton-nelson
# ['Vinnie', 'Vladic']
# Vinnie
# Vinnie
# Vinnie
# Vladic
# Vladic
# /vinnie-vladic
# http://www.espn.com/college-football/player/_/id/4370816/vinnie-vladic
# ['Ira', 'Armstead']
# Ira
# Ira
# Ira
# Armstead
# Armstead
# /ira-armstead
# http://www.espn.com/college-football/player/_/id/4429219/ira-armstead
# ['Brennan', 'Armstrong']
# Brennan
# Brennan
# Brennan
# Armstrong
# Armstrong
# /brennan-armstrong
# http://www.espn.com/college-football/player/_/id/4370775/brennan-armstrong
# ['Jared', 'Rayman']
# Jared
# Jared
# Jared
# Rayman
# Rayman
# /jared-rayman
# http://www.espn.com/college-football/player/_/id/4568497/jared-rayman
# ['Lindell', 'Stone']
# Lindell
# Lindell
# Lindell
# Stone
# Stone
# /lindell-stone
# http://www.espn.com/college-football/player/_/id/4240850/lindell-stone
# ['Keytaon', 'Thompson']
# Keytaon
# Keytaon
# Keytaon
# Thompson
# Thompson
# /keytaon-thompson
# http://www.espn.com/college-football/player/_/id/4242243/keytaon-thompson
# ['Chris', 'Barfield']
# Chris
# Chris
# Chris
# Barfield
# Barfield
# /chris-barfield
# http://www.espn.com/college-football/player/_/id/4684946/chris-barfield
# ['Mike', 'Hollins']
# Mike
# Mike
# Mike
# Hollins
# Hollins
# /mike-hollins
# http://www.espn.com/college-football/player/_/id/4427503/mike-hollins
# ['Perris', 'Jones']
# Perris
# Perris
# Perris
# Jones
# Jones
# /perris-jones
# http://www.espn.com/college-football/player/_/id/4370794/perris-jones
# ['Billy', 'Kemp', 'IV']
# Billy
# Billy
# Billy
# Kemp
# Kemp
# Kemp
# IV
# IV
# /billy-kemp-iv
# http://www.espn.com/college-football/player/_/id/4370797/billy-kemp-iv
# ['Shane', 'Simpson']
# Shane
# Shane
# Shane
# Simpson
# Simpson
# /shane-simpson
# http://www.espn.com/college-football/player/_/id/3935232/shane-simpson
# ['Wayne', 'Taulapapa']
# Wayne
# Wayne
# Wayne
# Taulapapa
# Taulapapa
# /wayne-taulapapa
# http://www.espn.com/college-football/player/_/id/4370813/wayne-taulapapa
# ['Ronnie', 'Walker', 'Jr.']
# Ronnie
# Ronnie
# Ronnie
# Walker
# Walker
# Walker
# Jr.
# Jr
# /ronnie-walker-jr
# http://www.espn.com/college-football/player/_/id/4360425/ronnie-walker-jr
# ['Justin', 'Zollar']
# Justin
# Justin
# Justin
# Zollar
# Zollar
# /justin-zollar
# http://www.espn.com/college-football/player/_/id/4240857/justin-zollar
# ['Jamari', 'Peacock']
# Jamari
# Jamari
# Jamari
# Peacock
# Peacock
# /jamari-peacock
# http://www.espn.com/college-football/player/_/id/4240844/jamari-peacock
# ['Andrew', 'Yavinsky']
# Andrew
# Andrew
# Andrew
# Yavinsky
# Yavinsky
# /andrew-yavinsky
# http://www.espn.com/college-football/player/_/id/4240854/andrew-yavinsky
# ['Nathaniel', 'Beal', 'III']
# Nathaniel
# Nathaniel
# Nathaniel
# Beal
# Beal
# Beal
# III
# III
# /nathaniel-beal-iii
# http://www.espn.com/college-football/player/_/id/4426654/nathaniel-beal-iii
# ['Josh', 'Clifford']
# Josh
# Josh
# Josh
# Clifford
# Clifford
# /josh-clifford
# http://www.espn.com/college-football/player/_/id/4370781/josh-clifford
# ['Lavel', 'Davis']
# Lavel
# Lavel
# Lavel
# Davis
# Davis
# /lavel-davis
# http://www.espn.com/college-football/player/_/id/4431058/lavel-davis
# ['Dorien', 'Goddard']
# Dorien
# Dorien
# Dorien
# Goddard
# Goddard
# /dorien-goddard
# http://www.espn.com/college-football/player/_/id/4427287/dorien-goddard
# ['Jalen', 'Harrison']
# Jalen
# Jalen
# Jalen
# Harrison
# Harrison
# /jalen-harrison
# http://www.espn.com/college-football/player/_/id/4228300/jalen-harrison
# ["Ra'Shaun", 'Henry']
# Ra'Shaun
# Ra'Shaun
# RaShaun
# Henry
# Henry
# /rashaun-henry
# http://www.espn.com/college-football/player/_/id/4032625/rashaun-henry
# ['Terrell', 'Jana']
# Terrell
# Terrell
# Terrell
# Jana
# Jana
# /terrell-jana
# http://www.espn.com/college-football/player/_/id/4240838/terrell-jana
# ['Tavares', 'Kelly', 'Jr.']
# Tavares
# Tavares
# Tavares
# Kelly
# Kelly
# Kelly
# Jr.
# Jr
# /tavares-kelly-jr
# http://www.espn.com/college-football/player/_/id/4370796/tavares-kelly-jr
# ['Zack', 'Kindel']
# Zack
# Zack
# Zack
# Kindel
# Kindel
# /zack-kindel
# http://www.espn.com/college-football/player/_/id/4568493/zack-kindel
# ['Hayden', 'Mitchell']
# Hayden
# Hayden
# Hayden
# Mitchell
# Mitchell
# /hayden-mitchell
# http://www.espn.com/college-football/player/_/id/4240842/hayden-mitchell
# ['Sean', 'Moore']
# Sean
# Sean
# Sean
# Moore
# Moore
# /sean-moore
# http://www.espn.com/college-football/player/_/id/4568495/sean-moore
# ['Ugo', 'Obasi']
# Ugo
# Ugo
# Ugo
# Obasi
# Obasi
# /ugo-obasi
# http://www.espn.com/college-football/player/_/id/4370806/ugo-obasi
# ['Demick', 'Starling']
# Demick
# Demick
# Demick
# Starling
# Starling
# /demick-starling
# http://www.espn.com/college-football/player/_/id/4613165/demick-starling
# ['Luke', 'Wentz']
# Luke
# Luke
# Luke
# Wentz
# Wentz
# /luke-wentz
# http://www.espn.com/college-football/player/_/id/4428820/luke-wentz
# ['Brandon', 'White']
# Brandon
# Brandon
# Brandon
# White
# White
# /brandon-white
# http://www.espn.com/college-football/player/_/id/4370819/brandon-white
# ['Dontayvion', 'Wicks']
# Dontayvion
# Dontayvion
# Dontayvion
# Wicks
# Wicks
# /dontayvion-wicks
# http://www.espn.com/college-football/player/_/id/4428850/dontayvion-wicks
# ['T.J.', 'Kitts']
# T.J.
# TJ
# TJ
# Kitts
# Kitts
# /tj-kitts
# http://www.espn.com/college-football/player/_/id/4257941/tj-kitts
# ['Mike', 'Kosar']
# Mike
# Mike
# Mike
# Kosar
# Kosar
# /mike-kosar
# http://www.espn.com/college-football/player/_/id/4568494/mike-kosar
# ['Grant', 'Misch']
# Grant
# Grant
# Grant
# Misch
# Misch
# /grant-misch
# http://www.espn.com/college-football/player/_/id/4370803/grant-misch
# ['Joshua', 'Rawlings']
# Joshua
# Joshua
# Joshua
# Rawlings
# Rawlings
# /joshua-rawlings
# http://www.espn.com/college-football/player/_/id/4565360/joshua-rawlings
# ['Sackett', 'Wood', 'Jr.']
# Sackett
# Sackett
# Sackett
# Wood
# Wood
# Wood
# Jr.
# Jr
# /sackett-wood-jr
# http://www.espn.com/college-football/player/_/id/4684953/sackett-wood-jr
# ['Tyler', 'Fannin']
# Tyler
# Tyler
# Tyler
# Fannin
# Fannin
# /tyler-fannin
# http://www.espn.com/college-football/player/_/id/4240834/tyler-fannin
# ['Olusegun', 'Oluwatimi']
# Olusegun
# Olusegun
# Olusegun
# Oluwatimi
# Oluwatimi
# /olusegun-oluwatimi
# http://www.espn.com/college-football/player/_/id/4370807/olusegun-oluwatimi
# ['Kariem', 'Al', 'Soufi']
# Kariem
# Kariem
# Kariem
# Al
# Al
# Al
# Soufi
# Soufi
# /kariem-al-soufi
# http://www.espn.com/college-football/player/_/id/4426547/kariem-al-soufi
# ['Joe', 'Bissinger']
# Joe
# Joe
# Joe
# Bissinger
# Bissinger
# /joe-bissinger
# http://www.espn.com/college-football/player/_/id/4370777/joe-bissinger
# ['Zachary', 'Teter']
# Zachary
# Zachary
# Zachary
# Teter
# Teter
# /zachary-teter
# http://www.espn.com/college-football/player/_/id/4428654/zachary-teter
# ['Gerrik', 'Vollmer']
# Gerrik
# Gerrik
# Gerrik
# Vollmer
# Vollmer
# /gerrik-vollmer
# http://www.espn.com/college-football/player/_/id/4240853/gerrik-vollmer
# ['Jestus', 'Johnson', 'III']
# Jestus
# Jestus
# Jestus
# Johnson
# Johnson
# Johnson
# III
# III
# /jestus-johnson-iii
# http://www.espn.com/college-football/player/_/id/4430074/jestus-johnson-iii
# ['Tommy', 'Christ']
# Tommy
# Tommy
# Tommy
# Christ
# Christ
# /tommy-christ
# http://www.espn.com/college-football/player/_/id/4240829/tommy-christ
# ['Derek', 'Devine']
# Derek
# Derek
# Derek
# Devine
# Devine
# /derek-devine
# http://www.espn.com/college-football/player/_/id/4370784/derek-devine
# ['Alex', 'Gellerstedt']
# Alex
# Alex
# Alex
# Gellerstedt
# Gellerstedt
# /alex-gellerstedt
# http://www.espn.com/college-football/player/_/id/4033747/alex-gellerstedt
# ['Chris', 'Glaser']
# Chris
# Chris
# Chris
# Glaser
# Glaser
# /chris-glaser
# http://www.espn.com/college-football/player/_/id/4240836/chris-glaser
# ['Bobby', 'Haskins']
# Bobby
# Bobby
# Bobby
# Haskins
# Haskins
# /bobby-haskins
# http://www.espn.com/college-football/player/_/id/4370790/bobby-haskins
# ['Luke', 'Johnson']
# Luke
# Luke
# Luke
# Johnson
# Johnson
# /luke-johnson
# http://www.espn.com/college-football/player/_/id/4684949/luke-johnson
# ['Jack', 'Keenan']
# Jack
# Jack
# Jack
# Keenan
# Keenan
# /jack-keenan
# http://www.espn.com/college-football/player/_/id/4370795/jack-keenan
# ['Jonathan', 'Leech']
# Jonathan
# Jonathan
# Jonathan
# Leech
# Leech
# /jonathan-leech
# http://www.espn.com/college-football/player/_/id/4430032/jonathan-leech
# ['Colby', 'McGhee']
# Colby
# Colby
# Colby
# McGhee
# McGhee
# /colby-mcghee
# http://www.espn.com/college-football/player/_/id/4684950/colby-mcghee
# ['Ryan', 'Nelson']
# Ryan
# Ryan
# Ryan
# Nelson
# Nelson
# /ryan-nelson
# http://www.espn.com/college-football/player/_/id/4240843/ryan-nelson
# ['Dillon', 'Reinkensmeyer']
# Dillon
# Dillon
# Dillon
# Reinkensmeyer
# Reinkensmeyer
# /dillon-reinkensmeyer
# http://www.espn.com/college-football/player/_/id/4037592/dillon-reinkensmeyer
# ['Ryan', 'Swoboda']
# Ryan
# Ryan
# Ryan
# Swoboda
# Swoboda
# /ryan-swoboda
# http://www.espn.com/college-football/player/_/id/4240851/ryan-swoboda
# ['Su', 'Agunloye']
# Su
# Su
# Su
# Agunloye
# Agunloye
# /su-agunloye
# http://www.espn.com/college-football/player/_/id/4684945/su-agunloye
# ['Adeeb', 'Atariwa']
# Adeeb
# Adeeb
# Adeeb
# Atariwa
# Atariwa
# /adeeb-atariwa
# http://www.espn.com/college-football/player/_/id/4028748/adeeb-atariwa
# ['Jahmeer', 'Carter']
# Jahmeer
# Jahmeer
# Jahmeer
# Carter
# Carter
# /jahmeer-carter
# http://www.espn.com/college-football/player/_/id/4429371/jahmeer-carter
# ['Sam', 'Galletta']
# Sam
# Sam
# Sam
# Galletta
# Galletta
# /sam-galletta
# http://www.espn.com/college-football/player/_/id/4568488/sam-galletta
# ['Nusi', 'Malani']
# Nusi
# Nusi
# Nusi
# Malani
# Malani
# /nusi-malani
# http://www.espn.com/college-football/player/_/id/4430306/nusi-malani
# ['Jordan', 'Redmond']
# Jordan
# Jordan
# Jordan
# Redmond
# Redmond
# /jordan-redmond
# http://www.espn.com/college-football/player/_/id/4370809/jordan-redmond
# ['Samson', 'Reed']
# Samson
# Samson
# Samson
# Reed
# Reed
# /samson-reed
# http://www.espn.com/college-football/player/_/id/4370810/samson-reed
# ['Mandy', 'Alonso']
# Mandy
# Mandy
# Mandy
# Alonso
# Alonso
# /mandy-alonso
# http://www.espn.com/college-football/player/_/id/4240822/mandy-alonso
# ['Sam', 'Bond']
# Sam
# Sam
# Sam
# Bond
# Bond
# /sam-bond
# http://www.espn.com/college-football/player/_/id/4684947/sam-bond
# ['Richard', 'Burney']
# Richard
# Richard
# Richard
# Burney
# Burney
# /richard-burney
# http://www.espn.com/college-football/player/_/id/3917922/richard-burney
# ['Nate', 'Morris']
# Nate
# Nate
# Nate
# Morris
# Morris
# /nate-morris
# http://www.espn.com/college-football/player/_/id/4684951/nate-morris
# ['Ben', 'Smiley', 'III']
# Ben
# Ben
# Ben
# Smiley
# Smiley
# Smiley
# III
# III
# /ben-smiley-iii
# http://www.espn.com/college-football/player/_/id/4430499/ben-smiley-iii
# ['Jowon', 'Briggs']
# Jowon
# Jowon
# Jowon
# Briggs
# Briggs
# /jowon-briggs
# http://www.espn.com/college-football/player/_/id/4426676/jowon-briggs
# ['Aaron', 'Faumui']
# Aaron
# Aaron
# Aaron
# Faumui
# Faumui
# /aaron-faumui
# http://www.espn.com/college-football/player/_/id/4370786/aaron-faumui
# ['Josh', 'Ahern']
# Josh
# Josh
# Josh
# Ahern
# Ahern
# /josh-ahern
# http://www.espn.com/college-football/player/_/id/4426541/josh-ahern
# ['Sam', 'Brady']
# Sam
# Sam
# Sam
# Brady
# Brady
# /sam-brady
# http://www.espn.com/college-football/player/_/id/4429292/sam-brady
# ['Elliott', 'Brown']
# Elliott
# Elliott
# Elliott
# Brown
# Brown
# /elliott-brown
# http://www.espn.com/college-football/player/_/id/4240826/elliott-brown
# ['Dre', 'Bryant']
# Dre
# Dre
# Dre
# Bryant
# Bryant
# /dre-bryant
# http://www.espn.com/college-football/player/_/id/4037578/dre-bryant
# ['Matt', 'Gahm']
# Matt
# Matt
# Matt
# Gahm
# Gahm
# /matt-gahm
# http://www.espn.com/college-football/player/_/id/4240835/matt-gahm
# ['John', 'Hardy']
# John
# John
# John
# Hardy
# Hardy
# /john-hardy
# http://www.espn.com/college-football/player/_/id/4684948/john-hardy
# ['T.C.', 'Harrison']
# T.C.
# TC
# TC
# Harrison
# Harrison
# /tc-harrison
# http://www.espn.com/college-football/player/_/id/4370789/tc-harrison
# ['Jonathan', 'Horton']
# Jonathan
# Jonathan
# Jonathan
# Horton
# Horton
# /jonathan-horton
# http://www.espn.com/college-football/player/_/id/4608680/jonathan-horton
# ['Nick', 'Jackson']
# Nick
# Nick
# Nick
# Jackson
# Jackson
# /nick-jackson
# http://www.espn.com/college-football/player/_/id/4568492/nick-jackson
# ['DaJuan', 'Moore']
# DaJuan
# DaJuan
# DaJuan
# Moore
# Moore
# /dajuan-moore
# http://www.espn.com/college-football/player/_/id/4370804/dajuan-moore
# ["D'Sean", 'Perry']
# D'Sean
# D'Sean
# DSean
# Perry
# Perry
# /dsean-perry
# http://www.espn.com/college-football/player/_/id/4428221/dsean-perry
# ['Jairus', 'Satiu']
# Jairus
# Jairus
# Jairus
# Satiu
# Satiu
# /jairus-satiu
# http://www.espn.com/college-football/player/_/id/4428429/jairus-satiu
# ['Brayden', 'Sheffer']
# Brayden
# Brayden
# Brayden
# Sheffer
# Sheffer
# /brayden-sheffer
# http://www.espn.com/college-football/player/_/id/4684952/brayden-sheffer
# ['Charles', 'Snowden']
# Charles
# Charles
# Charles
# Snowden
# Snowden
# /charles-snowden
# http://www.espn.com/college-football/player/_/id/4240849/charles-snowden
# ['Rob', 'Snyder']
# Rob
# Rob
# Rob
# Snyder
# Snyder
# /rob-snyder
# http://www.espn.com/college-football/player/_/id/4037595/rob-snyder
# ['Hunter', 'Stewart']
# Hunter
# Hunter
# Hunter
# Stewart
# Stewart
# /hunter-stewart
# http://www.espn.com/college-football/player/_/id/4568500/hunter-stewart
# ['Noah', 'Taylor']
# Noah
# Noah
# Noah
# Taylor
# Taylor
# /noah-taylor
# http://www.espn.com/college-football/player/_/id/4370814/noah-taylor
# ['Brandon', 'Williams']
# Brandon
# Brandon
# Brandon
# Williams
# Williams
# /brandon-williams
# http://www.espn.com/college-football/player/_/id/4429188/brandon-williams
# ['Zane', 'Zandier']
# Zane
# Zane
# Zane
# Zandier
# Zandier
# /zane-zandier
# http://www.espn.com/college-football/player/_/id/4240855/zane-zandier
# ['Jaylon', 'Baker']
# Jaylon
# Jaylon
# Jaylon
# Baker
# Baker
# /jaylon-baker
# http://www.espn.com/college-football/player/_/id/4370776/jaylon-baker
# ['Darrius', 'Bratton']
# Darrius
# Darrius
# Darrius
# Bratton
# Bratton
# /darrius-bratton
# http://www.espn.com/college-football/player/_/id/4240825/darrius-bratton
# ['Mark', 'Chichester']
# Mark
# Mark
# Mark
# Chichester
# Chichester
# /mark-chichester
# http://www.espn.com/college-football/player/_/id/4370779/mark-chichester
# ['Nick', 'Grant']
# Nick
# Nick
# Nick
# Grant
# Grant
# /nick-grant
# http://www.espn.com/college-football/player/_/id/4037583/nick-grant
# ['Heskin', 'Smith']
# Heskin
# Heskin
# Heskin
# Smith
# Smith
# /heskin-smith
# http://www.espn.com/college-football/player/_/id/4240848/heskin-smith
# ['Chayce', 'Chalmers']
# Chayce
# Chayce
# Chayce
# Chalmers
# Chalmers
# /chayce-chalmers
# http://www.espn.com/college-football/player/_/id/4426895/chayce-chalmers
# ['Antonio', 'Clary']
# Antonio
# Antonio
# Antonio
# Clary
# Clary
# /antonio-clary
# http://www.espn.com/college-football/player/_/id/4426931/antonio-clary
# ['Fentrell', 'Cypress', 'II']
# Fentrell
# Fentrell
# Fentrell
# Cypress
# Cypress
# Cypress
# II
# II
# /fentrell-cypress-ii
# http://www.espn.com/college-football/player/_/id/4429488/fentrell-cypress-ii
# ['Jake', 'Dewease']
# Jake
# Jake
# Jake
# Dewease
# Dewease
# /jake-dewease
# http://www.espn.com/college-football/player/_/id/4568485/jake-dewease
# ['Tenyeh', 'Dixon']
# Tenyeh
# Tenyeh
# Tenyeh
# Dixon
# Dixon
# /tenyeh-dixon
# http://www.espn.com/college-football/player/_/id/4429522/tenyeh-dixon
# ['Elijah', 'Gaines']
# Elijah
# Elijah
# Elijah
# Gaines
# Gaines
# /elijah-gaines
# http://www.espn.com/college-football/player/_/id/4429785/elijah-gaines
# ['Dave', 'Herard']
# Dave
# Dave
# Dave
# Herard
# Herard
# /dave-herard
# http://www.espn.com/college-football/player/_/id/4565536/dave-herard
# ['Donovan', 'Johnson']
# Donovan
# Donovan
# Donovan
# Johnson
# Johnson
# /donovan-johnson
# http://www.espn.com/college-football/player/_/id/4431177/donovan-johnson
# ['Coen', 'King']
# Coen
# Coen
# Coen
# King
# King
# /coen-king
# http://www.espn.com/college-football/player/_/id/4370799/coen-king
# ['Darnell', 'Pratt']
# Darnell
# Darnell
# Darnell
# Pratt
# Pratt
# /darnell-pratt
# http://www.espn.com/college-football/player/_/id/4240846/darnell-pratt
# ['Joseph', 'White']
# Joseph
# Joseph
# Joseph
# White
# White
# /joseph-white
# http://www.espn.com/college-football/player/_/id/4370820/joseph-white
# ["D'Angelo", 'Amos']
# D'Angelo
# D'Angelo
# DAngelo
# Amos
# Amos
# /dangelo-amos
# http://www.espn.com/college-football/player/_/id/4049429/dangelo-amos
# ['Joey', 'Blount']
# Joey
# Joey
# Joey
# Blount
# Blount
# /joey-blount
# http://www.espn.com/college-football/player/_/id/4240824/joey-blount
# ["De'Vante", 'Cross']
# De'Vante
# De'Vante
# DeVante
# Cross
# Cross
# /devante-cross
# http://www.espn.com/college-football/player/_/id/4037579/devante-cross
# ['Darren', 'Klein']
# Darren
# Darren
# Darren
# Klein
# Klein
# /darren-klein
# http://www.espn.com/college-football/player/_/id/4370800/darren-klein
# ['Brenton', 'Nelson']
# Brenton
# Brenton
# Brenton
# Nelson
# Nelson
# /brenton-nelson
# http://www.espn.com/college-football/player/_/id/4047915/brenton-nelson
# ['Vinnie', 'Vladic']
# Vinnie
# Vinnie
# Vinnie
# Vladic
# Vladic
# /vinnie-vladic
# http://www.espn.com/college-football/player/_/id/4370816/vinnie-vladic
# ['Brian', 'Delaney']
# Brian
# Brian
# Brian
# Delaney
# Delaney
# /brian-delaney
# http://www.espn.com/college-football/player/_/id/4240831/brian-delaney
# ['Justin', 'Duenkel']
# Justin
# Justin
# Justin
# Duenkel
# Duenkel
# /justin-duenkel
# http://www.espn.com/college-football/player/_/id/4568486/justin-duenkel
# ['A.J.', 'Mejia']
# A.J.
# AJ
# AJ
# Mejia
# Mejia
# /aj-mejia
# http://www.espn.com/college-football/player/_/id/4240841/aj-mejia
# ['Hunter', 'Pearson']
# Hunter
# Hunter
# Hunter
# Pearson
# Pearson
# /hunter-pearson
# http://www.espn.com/college-football/player/_/id/4370808/hunter-pearson
# ['Brendan', 'Farrell']
# Brendan
# Brendan
# Brendan
# Farrell
# Farrell
# /brendan-farrell
# http://www.espn.com/college-football/player/_/id/4568487/brendan-farrell
# ['Nash', 'Griffin']
# Nash
# Nash
# Nash
# Griffin
# Griffin
# /nash-griffin
# http://www.espn.com/college-football/player/_/id/4047914/nash-griffin
# ['Danny', 'Caracciolo']
# Danny
# Danny
# Danny
# Caracciolo
# Caracciolo
# /danny-caracciolo
# http://www.espn.com/college-football/player/_/id/4049435/danny-caracciolo
# ['Lee', 'Dudley']
# Lee
# Lee
# Lee
# Dudley
# Dudley
# /lee-dudley
# http://www.espn.com/college-football/player/_/id/4370785/lee-dudley
# ['Tucker', 'Finkelston']
# Tucker
# Tucker
# Tucker
# Finkelston
# Finkelston
# /tucker-finkelston
# http://www.espn.com/college-football/player/_/id/4370787/tucker-finkelston

# %% [markdown]
# ### Congratulations! Yo have finished Part B of the problem.
