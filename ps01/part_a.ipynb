# %% [markdown]
# # CPSC 4300/6300-001 Applied Data Science (Fall 2020)
#
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Joshua Lin"
COLLABORATORS = ""

# %% [markdown]
# # CPSC4300/6300-001 Problem Set #1

# %% [markdown]
# In this problem set, you will create a NCAA College Football team dataset by scraping data from the Internet and perform some basic data manipulations. The purpose of this problem set is to get familiar with data collection with Python and gain some hand-on skills of using Python to some routine tasks.
#
# The assignment has four parts: part A and B are auto-graded. Part C and D are manually graded by the TA.
#
# Before submission, make sure you run all the cells. Because the TA could not run your notebook, your grade will be only based on the output and the writing part of your submitted notebook.

# %% [markdown]
# ## Part A: Find the List of NCAA College Football Teams (30 points)
#
# To start, we first create a list of NCAA football teams from ESPN's website. To save your time, we provide a Python module which scrapes the list of teams from url.

# %%
# %%writefile espn.py
import requests
from bs4 import BeautifulSoup
from requests.exceptions import HTTPError

NCAAF_URL="https://www.espn.com/college-football/teams"

def fetch_ncaaf_teams(url=NCAAF_URL):
    """Fetch the list of ncaa football teams
    
    Args:
        url (string): the url of the web page for ncaa football teams 
    
    Returns:
            
    """
    teams = []
    
    response = requests.get(url)
    html = response.content
    soup = BeautifulSoup(html, 'html.parser')
    
    conferences = soup.find_all("div", class_="headline")
    for conference in conferences:
        conference_name = conference.get_text()
        team_links = conference.parent.find_all("a", class_="AnchorLink")
        for team_link in team_links:
            if team_link.find("h2"):
                team_url = team_link['href']
                team_name = team_link.get_text()
                team_id = int(team_url.split("/")[-2])
                teams.append({"id": team_id, "name": team_name, "conference": conference_name, "url": team_url})
    return teams
# Out:
# Overwriting espn.py

# %%
# !ls
# Out:
# acc_team_rosters.json  acc_teans.csv	 part_a.ipynb  part_d.ipynb
# acc_teams.csv	       espn.py		 part_b.ipynb  __pycache__
# acc_teams.json	       ncaaf_teams.json  part_c.ipynb  roster.py

# %% [markdown]
# ### Question 1.  Import and use python functions
#
# Write a Python statement to import the `fetch_ncaaf_teams()` function and use it to fetch the list of college football teams and save the list into a variable named `team_list`. (2 points)

# %%
# YOUR CODE HERE
from espn import fetch_ncaaf_teams
team_list = []
team_list = fetch_ncaaf_teams()
team_list
#raise NotImplementedError()
# Out:
# [{'id': 2132,
#   'name': 'Cincinnati Bearcats',
#   'conference': 'American',
#   'url': '/college-football/team/_/id/2132/cincinnati-bearcats'},
#  {'id': 151,
#   'name': 'East Carolina Pirates',
#   'conference': 'American',
#   'url': '/college-football/team/_/id/151/east-carolina-pirates'},
#  {'id': 248,
#   'name': 'Houston Cougars',
#   'conference': 'American',
#   'url': '/college-football/team/_/id/248/houston-cougars'},
#  {'id': 235,
#   'name': 'Memphis Tigers',
#   'conference': 'American',
#   'url': '/college-football/team/_/id/235/memphis-tigers'},
#  {'id': 2426,
#   'name': 'Navy Midshipmen',
#   'conference': 'American',
#   'url': '/college-football/team/_/id/2426/navy-midshipmen'},
#  {'id': 2567,
#   'name': 'SMU Mustangs',
#   'conference': 'American',
#   'url': '/college-football/team/_/id/2567/smu-mustangs'},
#  {'id': 58,
#   'name': 'South Florida Bulls',
#   'conference': 'American',
#   'url': '/college-football/team/_/id/58/south-florida-bulls'},
#  {'id': 218,
#   'name': 'Temple Owls',
#   'conference': 'American',
#   'url': '/college-football/team/_/id/218/temple-owls'},
#  {'id': 2655,
#   'name': 'Tulane Green Wave',
#   'conference': 'American',
#   'url': '/college-football/team/_/id/2655/tulane-green-wave'},
#  {'id': 202,
#   'name': 'Tulsa Golden Hurricane',
#   'conference': 'American',
#   'url': '/college-football/team/_/id/202/tulsa-golden-hurricane'},
#  {'id': 2116,
#   'name': 'UCF Knights',
#   'conference': 'American',
#   'url': '/college-football/team/_/id/2116/ucf-knights'},
#  {'id': 103,
#   'name': 'Boston College Eagles',
#   'conference': 'ACC',
#   'url': '/college-football/team/_/id/103/boston-college-eagles'},
#  {'id': 228,
#   'name': 'Clemson Tigers',
#   'conference': 'ACC',
#   'url': '/college-football/team/_/id/228/clemson-tigers'},
#  {'id': 150,
#   'name': 'Duke Blue Devils',
#   'conference': 'ACC',
#   'url': '/college-football/team/_/id/150/duke-blue-devils'},
#  {'id': 52,
#   'name': 'Florida State Seminoles',
#   'conference': 'ACC',
#   'url': '/college-football/team/_/id/52/florida-state-seminoles'},
#  {'id': 59,
#   'name': 'Georgia Tech Yellow Jackets',
#   'conference': 'ACC',
#   'url': '/college-football/team/_/id/59/georgia-tech-yellow-jackets'},
#  {'id': 97,
#   'name': 'Louisville Cardinals',
#   'conference': 'ACC',
#   'url': '/college-football/team/_/id/97/louisville-cardinals'},
#  {'id': 2390,
#   'name': 'Miami Hurricanes',
#   'conference': 'ACC',
#   'url': '/college-football/team/_/id/2390/miami-hurricanes'},
#  {'id': 152,
#   'name': 'NC State Wolfpack',
#   'conference': 'ACC',
#   'url': '/college-football/team/_/id/152/nc-state-wolfpack'},
#  {'id': 153,
#   'name': 'North Carolina Tar Heels',
#   'conference': 'ACC',
#   'url': '/college-football/team/_/id/153/north-carolina-tar-heels'},
#  {'id': 87,
#   'name': 'Notre Dame Fighting Irish',
#   'conference': 'ACC',
#   'url': '/college-football/team/_/id/87/notre-dame-fighting-irish'},
#  {'id': 221,
#   'name': 'Pittsburgh Panthers',
#   'conference': 'ACC',
#   'url': '/college-football/team/_/id/221/pittsburgh-panthers'},
#  {'id': 183,
#   'name': 'Syracuse Orange',
#   'conference': 'ACC',
#   'url': '/college-football/team/_/id/183/syracuse-orange'},
#  {'id': 258,
#   'name': 'Virginia Cavaliers',
#   'conference': 'ACC',
#   'url': '/college-football/team/_/id/258/virginia-cavaliers'},
#  {'id': 259,
#   'name': 'Virginia Tech Hokies',
#   'conference': 'ACC',
#   'url': '/college-football/team/_/id/259/virginia-tech-hokies'},
#  {'id': 154,
#   'name': 'Wake Forest Demon Deacons',
#   'conference': 'ACC',
#   'url': '/college-football/team/_/id/154/wake-forest-demon-deacons'},
#  {'id': 239,
#   'name': 'Baylor Bears',
#   'conference': 'Big 12',
#   'url': '/college-football/team/_/id/239/baylor-bears'},
#  {'id': 66,
#   'name': 'Iowa State Cyclones',
#   'conference': 'Big 12',
#   'url': '/college-football/team/_/id/66/iowa-state-cyclones'},
#  {'id': 2305,
#   'name': 'Kansas Jayhawks',
#   'conference': 'Big 12',
#   'url': '/college-football/team/_/id/2305/kansas-jayhawks'},
#  {'id': 2306,
#   'name': 'Kansas State Wildcats',
#   'conference': 'Big 12',
#   'url': '/college-football/team/_/id/2306/kansas-state-wildcats'},
#  {'id': 201,
#   'name': 'Oklahoma Sooners',
#   'conference': 'Big 12',
#   'url': '/college-football/team/_/id/201/oklahoma-sooners'},
#  {'id': 197,
#   'name': 'Oklahoma State Cowboys',
#   'conference': 'Big 12',
#   'url': '/college-football/team/_/id/197/oklahoma-state-cowboys'},
#  {'id': 2628,
#   'name': 'TCU Horned Frogs',
#   'conference': 'Big 12',
#   'url': '/college-football/team/_/id/2628/tcu-horned-frogs'},
#  {'id': 251,
#   'name': 'Texas Longhorns',
#   'conference': 'Big 12',
#   'url': '/college-football/team/_/id/251/texas-longhorns'},
#  {'id': 2641,
#   'name': 'Texas Tech Red Raiders',
#   'conference': 'Big 12',
#   'url': '/college-football/team/_/id/2641/texas-tech-red-raiders'},
#  {'id': 277,
#   'name': 'West Virginia Mountaineers',
#   'conference': 'Big 12',
#   'url': '/college-football/team/_/id/277/west-virginia-mountaineers'},
#  {'id': 356,
#   'name': 'Illinois Fighting Illini',
#   'conference': 'Big Ten',
#   'url': '/college-football/team/_/id/356/illinois-fighting-illini'},
#  {'id': 84,
#   'name': 'Indiana Hoosiers',
#   'conference': 'Big Ten',
#   'url': '/college-football/team/_/id/84/indiana-hoosiers'},
#  {'id': 2294,
#   'name': 'Iowa Hawkeyes',
#   'conference': 'Big Ten',
#   'url': '/college-football/team/_/id/2294/iowa-hawkeyes'},
#  {'id': 120,
#   'name': 'Maryland Terrapins',
#   'conference': 'Big Ten',
#   'url': '/college-football/team/_/id/120/maryland-terrapins'},
#  {'id': 127,
#   'name': 'Michigan State Spartans',
#   'conference': 'Big Ten',
#   'url': '/college-football/team/_/id/127/michigan-state-spartans'},
#  {'id': 130,
#   'name': 'Michigan Wolverines',
#   'conference': 'Big Ten',
#   'url': '/college-football/team/_/id/130/michigan-wolverines'},
#  {'id': 135,
#   'name': 'Minnesota Golden Gophers',
#   'conference': 'Big Ten',
#   'url': '/college-football/team/_/id/135/minnesota-golden-gophers'},
#  {'id': 158,
#   'name': 'Nebraska Cornhuskers',
#   'conference': 'Big Ten',
#   'url': '/college-football/team/_/id/158/nebraska-cornhuskers'},
#  {'id': 77,
#   'name': 'Northwestern Wildcats',
#   'conference': 'Big Ten',
#   'url': '/college-football/team/_/id/77/northwestern-wildcats'},
#  {'id': 194,
#   'name': 'Ohio State Buckeyes',
#   'conference': 'Big Ten',
#   'url': '/college-football/team/_/id/194/ohio-state-buckeyes'},
#  {'id': 213,
#   'name': 'Penn State Nittany Lions',
#   'conference': 'Big Ten',
#   'url': '/college-football/team/_/id/213/penn-state-nittany-lions'},
#  {'id': 2509,
#   'name': 'Purdue Boilermakers',
#   'conference': 'Big Ten',
#   'url': '/college-football/team/_/id/2509/purdue-boilermakers'},
#  {'id': 164,
#   'name': 'Rutgers Scarlet Knights',
#   'conference': 'Big Ten',
#   'url': '/college-football/team/_/id/164/rutgers-scarlet-knights'},
#  {'id': 275,
#   'name': 'Wisconsin Badgers',
#   'conference': 'Big Ten',
#   'url': '/college-football/team/_/id/275/wisconsin-badgers'},
#  {'id': 2429,
#   'name': 'Charlotte 49ers',
#   'conference': 'Conference USA',
#   'url': '/college-football/team/_/id/2429/charlotte-49ers'},
#  {'id': 2226,
#   'name': 'Florida Atlantic Owls',
#   'conference': 'Conference USA',
#   'url': '/college-football/team/_/id/2226/florida-atlantic-owls'},
#  {'id': 2229,
#   'name': 'Florida International Panthers',
#   'conference': 'Conference USA',
#   'url': '/college-football/team/_/id/2229/florida-international-panthers'},
#  {'id': 2348,
#   'name': 'Louisiana Tech Bulldogs',
#   'conference': 'Conference USA',
#   'url': '/college-football/team/_/id/2348/louisiana-tech-bulldogs'},
#  {'id': 276,
#   'name': 'Marshall Thundering Herd',
#   'conference': 'Conference USA',
#   'url': '/college-football/team/_/id/276/marshall-thundering-herd'},
#  {'id': 2393,
#   'name': 'Middle Tennessee Blue Raiders',
#   'conference': 'Conference USA',
#   'url': '/college-football/team/_/id/2393/middle-tennessee-blue-raiders'},
#  {'id': 249,
#   'name': 'North Texas Mean Green',
#   'conference': 'Conference USA',
#   'url': '/college-football/team/_/id/249/north-texas-mean-green'},
#  {'id': 295,
#   'name': 'Old Dominion Monarchs',
#   'conference': 'Conference USA',
#   'url': '/college-football/team/_/id/295/old-dominion-monarchs'},
#  {'id': 242,
#   'name': 'Rice Owls',
#   'conference': 'Conference USA',
#   'url': '/college-football/team/_/id/242/rice-owls'},
#  {'id': 2572,
#   'name': 'Southern Mississippi Golden Eagles',
#   'conference': 'Conference USA',
#   'url': '/college-football/team/_/id/2572/southern-mississippi-golden-eagles'},
#  {'id': 5,
#   'name': 'UAB Blazers',
#   'conference': 'Conference USA',
#   'url': '/college-football/team/_/id/5/uab-blazers'},
#  {'id': 2638,
#   'name': 'UTEP Miners',
#   'conference': 'Conference USA',
#   'url': '/college-football/team/_/id/2638/utep-miners'},
#  {'id': 2636,
#   'name': 'UTSA Roadrunners',
#   'conference': 'Conference USA',
#   'url': '/college-football/team/_/id/2636/utsa-roadrunners'},
#  {'id': 98,
#   'name': 'Western Kentucky Hilltoppers',
#   'conference': 'Conference USA',
#   'url': '/college-football/team/_/id/98/western-kentucky-hilltoppers'},
#  {'id': 349,
#   'name': 'Army Black Knights',
#   'conference': 'FBS Independents',
#   'url': '/college-football/team/_/id/349/army-black-knights'},
#  {'id': 252,
#   'name': 'BYU Cougars',
#   'conference': 'FBS Independents',
#   'url': '/college-football/team/_/id/252/byu-cougars'},
#  {'id': 2335,
#   'name': 'Liberty Flames',
#   'conference': 'FBS Independents',
#   'url': '/college-football/team/_/id/2335/liberty-flames'},
#  {'id': 166,
#   'name': 'New Mexico State Aggies',
#   'conference': 'FBS Independents',
#   'url': '/college-football/team/_/id/166/new-mexico-state-aggies'},
#  {'id': 41,
#   'name': 'UConn Huskies',
#   'conference': 'FBS Independents',
#   'url': '/college-football/team/_/id/41/uconn-huskies'},
#  {'id': 113,
#   'name': 'UMass Minutemen',
#   'conference': 'FBS Independents',
#   'url': '/college-football/team/_/id/113/umass-minutemen'},
#  {'id': 2006,
#   'name': 'Akron Zips',
#   'conference': 'Mid-American',
#   'url': '/college-football/team/_/id/2006/akron-zips'},
#  {'id': 2050,
#   'name': 'Ball State Cardinals',
#   'conference': 'Mid-American',
#   'url': '/college-football/team/_/id/2050/ball-state-cardinals'},
#  {'id': 189,
#   'name': 'Bowling Green Falcons',
#   'conference': 'Mid-American',
#   'url': '/college-football/team/_/id/189/bowling-green-falcons'},
#  {'id': 2084,
#   'name': 'Buffalo Bulls',
#   'conference': 'Mid-American',
#   'url': '/college-football/team/_/id/2084/buffalo-bulls'},
#  {'id': 2117,
#   'name': 'Central Michigan Chippewas',
#   'conference': 'Mid-American',
#   'url': '/college-football/team/_/id/2117/central-michigan-chippewas'},
#  {'id': 2199,
#   'name': 'Eastern Michigan Eagles',
#   'conference': 'Mid-American',
#   'url': '/college-football/team/_/id/2199/eastern-michigan-eagles'},
#  {'id': 2309,
#   'name': 'Kent State Golden Flashes',
#   'conference': 'Mid-American',
#   'url': '/college-football/team/_/id/2309/kent-state-golden-flashes'},
#  {'id': 193,
#   'name': 'Miami (OH) RedHawks',
#   'conference': 'Mid-American',
#   'url': '/college-football/team/_/id/193/miami-oh-redhawks'},
#  {'id': 2459,
#   'name': 'Northern Illinois Huskies',
#   'conference': 'Mid-American',
#   'url': '/college-football/team/_/id/2459/northern-illinois-huskies'},
#  {'id': 195,
#   'name': 'Ohio Bobcats',
#   'conference': 'Mid-American',
#   'url': '/college-football/team/_/id/195/ohio-bobcats'},
#  {'id': 2649,
#   'name': 'Toledo Rockets',
#   'conference': 'Mid-American',
#   'url': '/college-football/team/_/id/2649/toledo-rockets'},
#  {'id': 2711,
#   'name': 'Western Michigan Broncos',
#   'conference': 'Mid-American',
#   'url': '/college-football/team/_/id/2711/western-michigan-broncos'},
#  {'id': 2005,
#   'name': 'Air Force Falcons',
#   'conference': 'Mountain West',
#   'url': '/college-football/team/_/id/2005/air-force-falcons'},
#  {'id': 68,
#   'name': 'Boise State Broncos',
#   'conference': 'Mountain West',
#   'url': '/college-football/team/_/id/68/boise-state-broncos'},
#  {'id': 36,
#   'name': 'Colorado State Rams',
#   'conference': 'Mountain West',
#   'url': '/college-football/team/_/id/36/colorado-state-rams'},
#  {'id': 278,
#   'name': 'Fresno State Bulldogs',
#   'conference': 'Mountain West',
#   'url': '/college-football/team/_/id/278/fresno-state-bulldogs'},
#  {'id': 62,
#   'name': "Hawai'i Rainbow Warriors",
#   'conference': 'Mountain West',
#   'url': '/college-football/team/_/id/62/hawaii-rainbow-warriors'},
#  {'id': 2440,
#   'name': 'Nevada Wolf Pack',
#   'conference': 'Mountain West',
#   'url': '/college-football/team/_/id/2440/nevada-wolf-pack'},
#  {'id': 167,
#   'name': 'New Mexico Lobos',
#   'conference': 'Mountain West',
#   'url': '/college-football/team/_/id/167/new-mexico-lobos'},
#  {'id': 21,
#   'name': 'San Diego State Aztecs',
#   'conference': 'Mountain West',
#   'url': '/college-football/team/_/id/21/san-diego-state-aztecs'},
#  {'id': 23,
#   'name': 'San Jose State Spartans',
#   'conference': 'Mountain West',
#   'url': '/college-football/team/_/id/23/san-jose-state-spartans'},
#  {'id': 2439,
#   'name': 'UNLV Rebels',
#   'conference': 'Mountain West',
#   'url': '/college-football/team/_/id/2439/unlv-rebels'},
#  {'id': 328,
#   'name': 'Utah State Aggies',
#   'conference': 'Mountain West',
#   'url': '/college-football/team/_/id/328/utah-state-aggies'},
#  {'id': 2751,
#   'name': 'Wyoming Cowboys',
#   'conference': 'Mountain West',
#   'url': '/college-football/team/_/id/2751/wyoming-cowboys'},
#  {'id': 9,
#   'name': 'Arizona State Sun Devils',
#   'conference': 'Pac-12',
#   'url': '/college-football/team/_/id/9/arizona-state-sun-devils'},
#  {'id': 12,
#   'name': 'Arizona Wildcats',
#   'conference': 'Pac-12',
#   'url': '/college-football/team/_/id/12/arizona-wildcats'},
#  {'id': 25,
#   'name': 'California Golden Bears',
#   'conference': 'Pac-12',
#   'url': '/college-football/team/_/id/25/california-golden-bears'},
#  {'id': 38,
#   'name': 'Colorado Buffaloes',
#   'conference': 'Pac-12',
#   'url': '/college-football/team/_/id/38/colorado-buffaloes'},
#  {'id': 2483,
#   'name': 'Oregon Ducks',
#   'conference': 'Pac-12',
#   'url': '/college-football/team/_/id/2483/oregon-ducks'},
#  {'id': 204,
#   'name': 'Oregon State Beavers',
#   'conference': 'Pac-12',
#   'url': '/college-football/team/_/id/204/oregon-state-beavers'},
#  {'id': 24,
#   'name': 'Stanford Cardinal',
#   'conference': 'Pac-12',
#   'url': '/college-football/team/_/id/24/stanford-cardinal'},
#  {'id': 26,
#   'name': 'UCLA Bruins',
#   'conference': 'Pac-12',
#   'url': '/college-football/team/_/id/26/ucla-bruins'},
#  {'id': 30,
#   'name': 'USC Trojans',
#   'conference': 'Pac-12',
#   'url': '/college-football/team/_/id/30/usc-trojans'},
#  {'id': 254,
#   'name': 'Utah Utes',
#   'conference': 'Pac-12',
#   'url': '/college-football/team/_/id/254/utah-utes'},
#  {'id': 264,
#   'name': 'Washington Huskies',
#   'conference': 'Pac-12',
#   'url': '/college-football/team/_/id/264/washington-huskies'},
#  {'id': 265,
#   'name': 'Washington State Cougars',
#   'conference': 'Pac-12',
#   'url': '/college-football/team/_/id/265/washington-state-cougars'},
#  {'id': 333,
#   'name': 'Alabama Crimson Tide',
#   'conference': 'SEC',
#   'url': '/college-football/team/_/id/333/alabama-crimson-tide'},
#  {'id': 8,
#   'name': 'Arkansas Razorbacks',
#   'conference': 'SEC',
#   'url': '/college-football/team/_/id/8/arkansas-razorbacks'},
#  {'id': 2,
#   'name': 'Auburn Tigers',
#   'conference': 'SEC',
#   'url': '/college-football/team/_/id/2/auburn-tigers'},
#  {'id': 57,
#   'name': 'Florida Gators',
#   'conference': 'SEC',
#   'url': '/college-football/team/_/id/57/florida-gators'},
#  {'id': 61,
#   'name': 'Georgia Bulldogs',
#   'conference': 'SEC',
#   'url': '/college-football/team/_/id/61/georgia-bulldogs'},
#  {'id': 96,
#   'name': 'Kentucky Wildcats',
#   'conference': 'SEC',
#   'url': '/college-football/team/_/id/96/kentucky-wildcats'},
#  {'id': 99,
#   'name': 'LSU Tigers',
#   'conference': 'SEC',
#   'url': '/college-football/team/_/id/99/lsu-tigers'},
#  {'id': 344,
#   'name': 'Mississippi State Bulldogs',
#   'conference': 'SEC',
#   'url': '/college-football/team/_/id/344/mississippi-state-bulldogs'},
#  {'id': 142,
#   'name': 'Missouri Tigers',
#   'conference': 'SEC',
#   'url': '/college-football/team/_/id/142/missouri-tigers'},
#  {'id': 145,
#   'name': 'Ole Miss Rebels',
#   'conference': 'SEC',
#   'url': '/college-football/team/_/id/145/ole-miss-rebels'},
#  {'id': 2579,
#   'name': 'South Carolina Gamecocks',
#   'conference': 'SEC',
#   'url': '/college-football/team/_/id/2579/south-carolina-gamecocks'},
#  {'id': 2633,
#   'name': 'Tennessee Volunteers',
#   'conference': 'SEC',
#   'url': '/college-football/team/_/id/2633/tennessee-volunteers'},
#  {'id': 245,
#   'name': 'Texas A&M Aggies',
#   'conference': 'SEC',
#   'url': '/college-football/team/_/id/245/texas-am-aggies'},
#  {'id': 238,
#   'name': 'Vanderbilt Commodores',
#   'conference': 'SEC',
#   'url': '/college-football/team/_/id/238/vanderbilt-commodores'},
#  {'id': 2026,
#   'name': 'Appalachian State Mountaineers',
#   'conference': 'Sun Belt',
#   'url': '/college-football/team/_/id/2026/appalachian-state-mountaineers'},
#  {'id': 2032,
#   'name': 'Arkansas State Red Wolves',
#   'conference': 'Sun Belt',
#   'url': '/college-football/team/_/id/2032/arkansas-state-red-wolves'},
#  {'id': 324,
#   'name': 'Coastal Carolina Chanticleers',
#   'conference': 'Sun Belt',
#   'url': '/college-football/team/_/id/324/coastal-carolina-chanticleers'},
#  {'id': 290,
#   'name': 'Georgia Southern Eagles',
#   'conference': 'Sun Belt',
#   'url': '/college-football/team/_/id/290/georgia-southern-eagles'},
#  {'id': 2247,
#   'name': 'Georgia State Panthers',
#   'conference': 'Sun Belt',
#   'url': '/college-football/team/_/id/2247/georgia-state-panthers'},
#  {'id': 309,
#   'name': "Louisiana Ragin' Cajuns",
#   'conference': 'Sun Belt',
#   'url': '/college-football/team/_/id/309/louisiana-ragin-cajuns'},
#  {'id': 6,
#   'name': 'South Alabama Jaguars',
#   'conference': 'Sun Belt',
#   'url': '/college-football/team/_/id/6/south-alabama-jaguars'},
#  {'id': 326,
#   'name': 'Texas State Bobcats',
#   'conference': 'Sun Belt',
#   'url': '/college-football/team/_/id/326/texas-state-bobcats'},
#  {'id': 2653,
#   'name': 'Troy Trojans',
#   'conference': 'Sun Belt',
#   'url': '/college-football/team/_/id/2653/troy-trojans'},
#  {'id': 2433,
#   'name': 'UL Monroe Warhawks',
#   'conference': 'Sun Belt',
#   'url': '/college-football/team/_/id/2433/ul-monroe-warhawks'}]

# %%
# test
assert type(team_list) is list
print("There are {} ncaa football teams".format(len(team_list)))
# Out:
# There are 130 ncaa football teams

# %%
assert 'fetch_ncaaf_teams' in dir()
assert type(team_list) is list

# %%
assert "Clemson Tigers" in [team["name"] for team in team_list]

# %% [markdown]
# ### Question 2. Write files in JSON format
#
# JSON (JavaScript Object Notation) is a common data file format that uses human-readable text to store and transmit data objects consisting of attribute–value pairs and array data types. For more, see https://en.wikipedia.org/wiki/JSON. Complete a code segment that write the team list into a JSON file named `"ncaaf_teams.json"`. (2 points)

# %%
import json
with open("ncaaf_teams.json", "w") as outfile: 
    json.dump(team_list, outfile)
#raise NotImplementedError()

# %%
import os
assert os.path.exists("ncaaf_teams.json")

# %% [markdown]
# ## Question 3. Read JSON file into a Data Frame
#
# Write a code segment that reads the teams from a JSON file into a DataFrame object named `teams`. (2 poinst)

# %%
import numpy as np
import pandas as pd
teams = pd.read_json (r'ncaaf_teams.json')
#raise NotImplementedError()

# %%
assert type(teams) is pd.core.frame.DataFrame

# %%
assert pd.unique(teams["conference"]).size == 11

# %% [markdown]
# ### Question 4. Examine a DataFrame Object
#
# Write a code segment that outputs the first 20 rows of the Dataframe `teams` to a variable `row1_20`. (2 points)

# %%
row1_20 = teams.head(20)
#raise NotImplementedError()
print(row1_20.shape)
# Out:
# (20, 4)

# %%
assert row1_20.shape == (20, 4)

# %% [markdown]
# ### Question 5. Find the columns of the DataFrame Object
#
# Write a code segment that saves the names of the columns of the `teams` object. (2 points)

# %%
# YOUR CODE HERE
columns = teams.columns
#print(columns)
#raise NotImplementedError()

# %%
assert type(columns) == pd.core.indexes.base.Index and columns.shape == (4,)

# %% [markdown]
# ### Question 6. Find the size of the DataFrame Object
#
# Write a single statement that outputs the number of rows and columns of the `teams` DataFrame Object and save the number rows to variable `nrow` and the number of columns to variable `ncols`. (2 points)

# %%
# YOUR CODE HERE
#raise NotImplementedError()
nrows = teams.index.size
ncols = teams.columns.size
#print("rows: ", nrows)
#print("columns: ", ncols)
#teams

# %% [markdown]
# ### Question 7. Drop a Column in DataFrame
#
# Write a statement to drop the url column in the teams DataFrame object without creating a new copy of the object. (2 points)

# %%
# YOUR CODE HERE
#raise NotImplementedError()
teams = teams.drop(columns = ['url'])

# %%
assert teams.columns.size == 3 and "url" not in teams.columns

# %% [markdown]
# ### Question 8. Set the team id as the Index of the teams object

# %%
# YOUR CODE HERE
#raise NotImplementedError()
teams.set_index('id', inplace = True)

# %%
teams.head()
# Out:
#                        name conference
# id
# 2132    Cincinnati Bearcats   American
# 151   East Carolina Pirates   American
# 248         Houston Cougars   American
# 235          Memphis Tigers   American
# 2426        Navy Midshipmen   American

# %%
assert(teams.index.name == 'id')

# %% [markdown]
# ### Question 9. Select Rows by Column Value or Index
#
# Select the team whose team id is 259 and save it team_259.

# %%
# YOUR CODE HERE
#raise NotImplementedError()
#team_259 = teams.loc[259]
teams.reset_index(inplace = True)
team_259 = teams.loc[teams['id'] == 259]

# %%
assert team_259.iloc[0]['name'] == 'Virginia Tech Hokies'

# %% [markdown]
# ### Question 10. Select Rows Based on Specific Conditions
#
# Find rows in the teams DataFrame object in which the team in the ACC conference and save the results into a variable `acc_teams`. (2 points)

# %%
# YOUR CODE HERE
#raise NotImplementedError()
teams.set_index('id', inplace = True)
acc_teams = teams[teams['conference'] == 'ACC']
acc_teams
# Out:
#                              name conference
# id
# 103         Boston College Eagles        ACC
# 228                Clemson Tigers        ACC
# 150              Duke Blue Devils        ACC
# 52        Florida State Seminoles        ACC
# 59    Georgia Tech Yellow Jackets        ACC
# 97           Louisville Cardinals        ACC
# 2390             Miami Hurricanes        ACC
# 152             NC State Wolfpack        ACC
# 153      North Carolina Tar Heels        ACC
# 87      Notre Dame Fighting Irish        ACC
# 221           Pittsburgh Panthers        ACC
# 183               Syracuse Orange        ACC
# 258            Virginia Cavaliers        ACC
# 259          Virginia Tech Hokies        ACC
# 154     Wake Forest Demon Deacons        ACC

# %%
# test
assert pd.unique(acc_teams['conference'])[0] == 'ACC'

# %%
assert pd.unique(acc_teams['conference'])[0] == 'ACC'

# %%
assert acc_teams['conference'].shape[0] == 15

# %% [markdown]
# ### Question 11. Write a DataFrame Object to a JSON File
#
# Write to the acc_teams object to a JSON file named `acc_teams.json`. (2 points)

# %%
# YOUR CODE HERE
#raise NotImplementedError()
#print(acc_teams)
acc_teams.to_json(r'acc_teams.json')
acc_teams1 = pd.read_json (r'ncaaf_teams.json')
print(acc_teams1)
# Out:
#        id                     name conference  \
# 0    2132      Cincinnati Bearcats   American
# 1     151    East Carolina Pirates   American
# 2     248          Houston Cougars   American
# 3     235           Memphis Tigers   American
# 4    2426          Navy Midshipmen   American
# ..    ...                      ...        ...
# 125   309  Louisiana Ragin' Cajuns   Sun Belt
# 126     6    South Alabama Jaguars   Sun Belt
# 127   326      Texas State Bobcats   Sun Belt
# 128  2653             Troy Trojans   Sun Belt
# 129  2433       UL Monroe Warhawks   Sun Belt
#
#                                                    url
# 0    /college-football/team/_/id/2132/cincinnati-be...
# 1    /college-football/team/_/id/151/east-carolina-...
# 2      /college-football/team/_/id/248/houston-cougars
# 3       /college-football/team/_/id/235/memphis-tigers
# 4     /college-football/team/_/id/2426/navy-midshipmen
# ..                                                 ...
# 125  /college-football/team/_/id/309/louisiana-ragi...
# 126  /college-football/team/_/id/6/south-alabama-ja...
# 127  /college-football/team/_/id/326/texas-state-bo...
# 128      /college-football/team/_/id/2653/troy-trojans
# 129  /college-football/team/_/id/2433/ul-monroe-war...
#
# [130 rows x 4 columns]

# %%
# !cat 'acc_teams.json'
# Out:
# {"name":{"103":"Boston College Eagles","228":"Clemson Tigers","150":"Duke Blue Devils","52":"Florida State Seminoles","59":"Georgia Tech Yellow Jackets","97":"Louisville Cardinals","2390":"Miami Hurricanes","152":"NC State Wolfpack","153":"North Carolina Tar Heels","87":"Notre Dame Fighting Irish","221":"Pittsburgh Panthers","183":"Syracuse Orange","258":"Virginia Cavaliers","259":"Virginia Tech Hokies","154":"Wake Forest Demon Deacons"},"conference":{"103":"ACC","228":"ACC","150":"ACC","52":"ACC","59":"ACC","97":"ACC","2390":"ACC","152":"ACC","153":"ACC","87":"ACC","221":"ACC","183":"ACC","258":"ACC","259":"ACC","154":"ACC"}}

# %%
assert os.path.exists('acc_teams.json')

# %% [markdown]
# ### Question 12. The Data Oragnization of JSON Format
#
# Compare the file `ncaaf_teams.json` and the file `acc_teams.json`, you may notice that even though both files store similar type of information, the data organizations in the two files are different.
#
# Which file organizes the data as a list of dict?

# %%
# YOUR CODE HERE
#raise NotImplementedError()
with open('ncaaf_teams.json') as jsonfile:
    parsed = json.load(jsonfile)
with open('acc_teams.json') as jsonfile2:
    parsed2= json.load(jsonfile2)
print(json.dumps(parsed, indent=2, sort_keys=True))
# Out:
# [
#   {
#     "conference": "American",
#     "id": 2132,
#     "name": "Cincinnati Bearcats",
#     "url": "/college-football/team/_/id/2132/cincinnati-bearcats"
#   },
#   {
#     "conference": "American",
#     "id": 151,
#     "name": "East Carolina Pirates",
#     "url": "/college-football/team/_/id/151/east-carolina-pirates"
#   },
#   {
#     "conference": "American",
#     "id": 248,
#     "name": "Houston Cougars",
#     "url": "/college-football/team/_/id/248/houston-cougars"
#   },
#   {
#     "conference": "American",
#     "id": 235,
#     "name": "Memphis Tigers",
#     "url": "/college-football/team/_/id/235/memphis-tigers"
#   },
#   {
#     "conference": "American",
#     "id": 2426,
#     "name": "Navy Midshipmen",
#     "url": "/college-football/team/_/id/2426/navy-midshipmen"
#   },
#   {
#     "conference": "American",
#     "id": 2567,
#     "name": "SMU Mustangs",
#     "url": "/college-football/team/_/id/2567/smu-mustangs"
#   },
#   {
#     "conference": "American",
#     "id": 58,
#     "name": "South Florida Bulls",
#     "url": "/college-football/team/_/id/58/south-florida-bulls"
#   },
#   {
#     "conference": "American",
#     "id": 218,
#     "name": "Temple Owls",
#     "url": "/college-football/team/_/id/218/temple-owls"
#   },
#   {
#     "conference": "American",
#     "id": 2655,
#     "name": "Tulane Green Wave",
#     "url": "/college-football/team/_/id/2655/tulane-green-wave"
#   },
#   {
#     "conference": "American",
#     "id": 202,
#     "name": "Tulsa Golden Hurricane",
#     "url": "/college-football/team/_/id/202/tulsa-golden-hurricane"
#   },
#   {
#     "conference": "American",
#     "id": 2116,
#     "name": "UCF Knights",
#     "url": "/college-football/team/_/id/2116/ucf-knights"
#   },
#   {
#     "conference": "ACC",
#     "id": 103,
#     "name": "Boston College Eagles",
#     "url": "/college-football/team/_/id/103/boston-college-eagles"
#   },
#   {
#     "conference": "ACC",
#     "id": 228,
#     "name": "Clemson Tigers",
#     "url": "/college-football/team/_/id/228/clemson-tigers"
#   },
#   {
#     "conference": "ACC",
#     "id": 150,
#     "name": "Duke Blue Devils",
#     "url": "/college-football/team/_/id/150/duke-blue-devils"
#   },
#   {
#     "conference": "ACC",
#     "id": 52,
#     "name": "Florida State Seminoles",
#     "url": "/college-football/team/_/id/52/florida-state-seminoles"
#   },
#   {
#     "conference": "ACC",
#     "id": 59,
#     "name": "Georgia Tech Yellow Jackets",
#     "url": "/college-football/team/_/id/59/georgia-tech-yellow-jackets"
#   },
#   {
#     "conference": "ACC",
#     "id": 97,
#     "name": "Louisville Cardinals",
#     "url": "/college-football/team/_/id/97/louisville-cardinals"
#   },
#   {
#     "conference": "ACC",
#     "id": 2390,
#     "name": "Miami Hurricanes",
#     "url": "/college-football/team/_/id/2390/miami-hurricanes"
#   },
#   {
#     "conference": "ACC",
#     "id": 152,
#     "name": "NC State Wolfpack",
#     "url": "/college-football/team/_/id/152/nc-state-wolfpack"
#   },
#   {
#     "conference": "ACC",
#     "id": 153,
#     "name": "North Carolina Tar Heels",
#     "url": "/college-football/team/_/id/153/north-carolina-tar-heels"
#   },
#   {
#     "conference": "ACC",
#     "id": 87,
#     "name": "Notre Dame Fighting Irish",
#     "url": "/college-football/team/_/id/87/notre-dame-fighting-irish"
#   },
#   {
#     "conference": "ACC",
#     "id": 221,
#     "name": "Pittsburgh Panthers",
#     "url": "/college-football/team/_/id/221/pittsburgh-panthers"
#   },
#   {
#     "conference": "ACC",
#     "id": 183,
#     "name": "Syracuse Orange",
#     "url": "/college-football/team/_/id/183/syracuse-orange"
#   },
#   {
#     "conference": "ACC",
#     "id": 258,
#     "name": "Virginia Cavaliers",
#     "url": "/college-football/team/_/id/258/virginia-cavaliers"
#   },
#   {
#     "conference": "ACC",
#     "id": 259,
#     "name": "Virginia Tech Hokies",
#     "url": "/college-football/team/_/id/259/virginia-tech-hokies"
#   },
#   {
#     "conference": "ACC",
#     "id": 154,
#     "name": "Wake Forest Demon Deacons",
#     "url": "/college-football/team/_/id/154/wake-forest-demon-deacons"
#   },
#   {
#     "conference": "Big 12",
#     "id": 239,
#     "name": "Baylor Bears",
#     "url": "/college-football/team/_/id/239/baylor-bears"
#   },
#   {
#     "conference": "Big 12",
#     "id": 66,
#     "name": "Iowa State Cyclones",
#     "url": "/college-football/team/_/id/66/iowa-state-cyclones"
#   },
#   {
#     "conference": "Big 12",
#     "id": 2305,
#     "name": "Kansas Jayhawks",
#     "url": "/college-football/team/_/id/2305/kansas-jayhawks"
#   },
#   {
#     "conference": "Big 12",
#     "id": 2306,
#     "name": "Kansas State Wildcats",
#     "url": "/college-football/team/_/id/2306/kansas-state-wildcats"
#   },
#   {
#     "conference": "Big 12",
#     "id": 201,
#     "name": "Oklahoma Sooners",
#     "url": "/college-football/team/_/id/201/oklahoma-sooners"
#   },
#   {
#     "conference": "Big 12",
#     "id": 197,
#     "name": "Oklahoma State Cowboys",
#     "url": "/college-football/team/_/id/197/oklahoma-state-cowboys"
#   },
#   {
#     "conference": "Big 12",
#     "id": 2628,
#     "name": "TCU Horned Frogs",
#     "url": "/college-football/team/_/id/2628/tcu-horned-frogs"
#   },
#   {
#     "conference": "Big 12",
#     "id": 251,
#     "name": "Texas Longhorns",
#     "url": "/college-football/team/_/id/251/texas-longhorns"
#   },
#   {
#     "conference": "Big 12",
#     "id": 2641,
#     "name": "Texas Tech Red Raiders",
#     "url": "/college-football/team/_/id/2641/texas-tech-red-raiders"
#   },
#   {
#     "conference": "Big 12",
#     "id": 277,
#     "name": "West Virginia Mountaineers",
#     "url": "/college-football/team/_/id/277/west-virginia-mountaineers"
#   },
#   {
#     "conference": "Big Ten",
#     "id": 356,
#     "name": "Illinois Fighting Illini",
#     "url": "/college-football/team/_/id/356/illinois-fighting-illini"
#   },
#   {
#     "conference": "Big Ten",
#     "id": 84,
#     "name": "Indiana Hoosiers",
#     "url": "/college-football/team/_/id/84/indiana-hoosiers"
#   },
#   {
#     "conference": "Big Ten",
#     "id": 2294,
#     "name": "Iowa Hawkeyes",
#     "url": "/college-football/team/_/id/2294/iowa-hawkeyes"
#   },
#   {
#     "conference": "Big Ten",
#     "id": 120,
#     "name": "Maryland Terrapins",
#     "url": "/college-football/team/_/id/120/maryland-terrapins"
#   },
#   {
#     "conference": "Big Ten",
#     "id": 127,
#     "name": "Michigan State Spartans",
#     "url": "/college-football/team/_/id/127/michigan-state-spartans"
#   },
#   {
#     "conference": "Big Ten",
#     "id": 130,
#     "name": "Michigan Wolverines",
#     "url": "/college-football/team/_/id/130/michigan-wolverines"
#   },
#   {
#     "conference": "Big Ten",
#     "id": 135,
#     "name": "Minnesota Golden Gophers",
#     "url": "/college-football/team/_/id/135/minnesota-golden-gophers"
#   },
#   {
#     "conference": "Big Ten",
#     "id": 158,
#     "name": "Nebraska Cornhuskers",
#     "url": "/college-football/team/_/id/158/nebraska-cornhuskers"
#   },
#   {
#     "conference": "Big Ten",
#     "id": 77,
#     "name": "Northwestern Wildcats",
#     "url": "/college-football/team/_/id/77/northwestern-wildcats"
#   },
#   {
#     "conference": "Big Ten",
#     "id": 194,
#     "name": "Ohio State Buckeyes",
#     "url": "/college-football/team/_/id/194/ohio-state-buckeyes"
#   },
#   {
#     "conference": "Big Ten",
#     "id": 213,
#     "name": "Penn State Nittany Lions",
#     "url": "/college-football/team/_/id/213/penn-state-nittany-lions"
#   },
#   {
#     "conference": "Big Ten",
#     "id": 2509,
#     "name": "Purdue Boilermakers",
#     "url": "/college-football/team/_/id/2509/purdue-boilermakers"
#   },
#   {
#     "conference": "Big Ten",
#     "id": 164,
#     "name": "Rutgers Scarlet Knights",
#     "url": "/college-football/team/_/id/164/rutgers-scarlet-knights"
#   },
#   {
#     "conference": "Big Ten",
#     "id": 275,
#     "name": "Wisconsin Badgers",
#     "url": "/college-football/team/_/id/275/wisconsin-badgers"
#   },
#   {
#     "conference": "Conference USA",
#     "id": 2429,
#     "name": "Charlotte 49ers",
#     "url": "/college-football/team/_/id/2429/charlotte-49ers"
#   },
#   {
#     "conference": "Conference USA",
#     "id": 2226,
#     "name": "Florida Atlantic Owls",
#     "url": "/college-football/team/_/id/2226/florida-atlantic-owls"
#   },
#   {
#     "conference": "Conference USA",
#     "id": 2229,
#     "name": "Florida International Panthers",
#     "url": "/college-football/team/_/id/2229/florida-international-panthers"
#   },
#   {
#     "conference": "Conference USA",
#     "id": 2348,
#     "name": "Louisiana Tech Bulldogs",
#     "url": "/college-football/team/_/id/2348/louisiana-tech-bulldogs"
#   },
#   {
#     "conference": "Conference USA",
#     "id": 276,
#     "name": "Marshall Thundering Herd",
#     "url": "/college-football/team/_/id/276/marshall-thundering-herd"
#   },
#   {
#     "conference": "Conference USA",
#     "id": 2393,
#     "name": "Middle Tennessee Blue Raiders",
#     "url": "/college-football/team/_/id/2393/middle-tennessee-blue-raiders"
#   },
#   {
#     "conference": "Conference USA",
#     "id": 249,
#     "name": "North Texas Mean Green",
#     "url": "/college-football/team/_/id/249/north-texas-mean-green"
#   },
#   {
#     "conference": "Conference USA",
#     "id": 295,
#     "name": "Old Dominion Monarchs",
#     "url": "/college-football/team/_/id/295/old-dominion-monarchs"
#   },
#   {
#     "conference": "Conference USA",
#     "id": 242,
#     "name": "Rice Owls",
#     "url": "/college-football/team/_/id/242/rice-owls"
#   },
#   {
#     "conference": "Conference USA",
#     "id": 2572,
#     "name": "Southern Mississippi Golden Eagles",
#     "url": "/college-football/team/_/id/2572/southern-mississippi-golden-eagles"
#   },
#   {
#     "conference": "Conference USA",
#     "id": 5,
#     "name": "UAB Blazers",
#     "url": "/college-football/team/_/id/5/uab-blazers"
#   },
#   {
#     "conference": "Conference USA",
#     "id": 2638,
#     "name": "UTEP Miners",
#     "url": "/college-football/team/_/id/2638/utep-miners"
#   },
#   {
#     "conference": "Conference USA",
#     "id": 2636,
#     "name": "UTSA Roadrunners",
#     "url": "/college-football/team/_/id/2636/utsa-roadrunners"
#   },
#   {
#     "conference": "Conference USA",
#     "id": 98,
#     "name": "Western Kentucky Hilltoppers",
#     "url": "/college-football/team/_/id/98/western-kentucky-hilltoppers"
#   },
#   {
#     "conference": "FBS Independents",
#     "id": 349,
#     "name": "Army Black Knights",
#     "url": "/college-football/team/_/id/349/army-black-knights"
#   },
#   {
#     "conference": "FBS Independents",
#     "id": 252,
#     "name": "BYU Cougars",
#     "url": "/college-football/team/_/id/252/byu-cougars"
#   },
#   {
#     "conference": "FBS Independents",
#     "id": 2335,
#     "name": "Liberty Flames",
#     "url": "/college-football/team/_/id/2335/liberty-flames"
#   },
#   {
#     "conference": "FBS Independents",
#     "id": 166,
#     "name": "New Mexico State Aggies",
#     "url": "/college-football/team/_/id/166/new-mexico-state-aggies"
#   },
#   {
#     "conference": "FBS Independents",
#     "id": 41,
#     "name": "UConn Huskies",
#     "url": "/college-football/team/_/id/41/uconn-huskies"
#   },
#   {
#     "conference": "FBS Independents",
#     "id": 113,
#     "name": "UMass Minutemen",
#     "url": "/college-football/team/_/id/113/umass-minutemen"
#   },
#   {
#     "conference": "Mid-American",
#     "id": 2006,
#     "name": "Akron Zips",
#     "url": "/college-football/team/_/id/2006/akron-zips"
#   },
#   {
#     "conference": "Mid-American",
#     "id": 2050,
#     "name": "Ball State Cardinals",
#     "url": "/college-football/team/_/id/2050/ball-state-cardinals"
#   },
#   {
#     "conference": "Mid-American",
#     "id": 189,
#     "name": "Bowling Green Falcons",
#     "url": "/college-football/team/_/id/189/bowling-green-falcons"
#   },
#   {
#     "conference": "Mid-American",
#     "id": 2084,
#     "name": "Buffalo Bulls",
#     "url": "/college-football/team/_/id/2084/buffalo-bulls"
#   },
#   {
#     "conference": "Mid-American",
#     "id": 2117,
#     "name": "Central Michigan Chippewas",
#     "url": "/college-football/team/_/id/2117/central-michigan-chippewas"
#   },
#   {
#     "conference": "Mid-American",
#     "id": 2199,
#     "name": "Eastern Michigan Eagles",
#     "url": "/college-football/team/_/id/2199/eastern-michigan-eagles"
#   },
#   {
#     "conference": "Mid-American",
#     "id": 2309,
#     "name": "Kent State Golden Flashes",
#     "url": "/college-football/team/_/id/2309/kent-state-golden-flashes"
#   },
#   {
#     "conference": "Mid-American",
#     "id": 193,
#     "name": "Miami (OH) RedHawks",
#     "url": "/college-football/team/_/id/193/miami-oh-redhawks"
#   },
#   {
#     "conference": "Mid-American",
#     "id": 2459,
#     "name": "Northern Illinois Huskies",
#     "url": "/college-football/team/_/id/2459/northern-illinois-huskies"
#   },
#   {
#     "conference": "Mid-American",
#     "id": 195,
#     "name": "Ohio Bobcats",
#     "url": "/college-football/team/_/id/195/ohio-bobcats"
#   },
#   {
#     "conference": "Mid-American",
#     "id": 2649,
#     "name": "Toledo Rockets",
#     "url": "/college-football/team/_/id/2649/toledo-rockets"
#   },
#   {
#     "conference": "Mid-American",
#     "id": 2711,
#     "name": "Western Michigan Broncos",
#     "url": "/college-football/team/_/id/2711/western-michigan-broncos"
#   },
#   {
#     "conference": "Mountain West",
#     "id": 2005,
#     "name": "Air Force Falcons",
#     "url": "/college-football/team/_/id/2005/air-force-falcons"
#   },
#   {
#     "conference": "Mountain West",
#     "id": 68,
#     "name": "Boise State Broncos",
#     "url": "/college-football/team/_/id/68/boise-state-broncos"
#   },
#   {
#     "conference": "Mountain West",
#     "id": 36,
#     "name": "Colorado State Rams",
#     "url": "/college-football/team/_/id/36/colorado-state-rams"
#   },
#   {
#     "conference": "Mountain West",
#     "id": 278,
#     "name": "Fresno State Bulldogs",
#     "url": "/college-football/team/_/id/278/fresno-state-bulldogs"
#   },
#   {
#     "conference": "Mountain West",
#     "id": 62,
#     "name": "Hawai'i Rainbow Warriors",
#     "url": "/college-football/team/_/id/62/hawaii-rainbow-warriors"
#   },
#   {
#     "conference": "Mountain West",
#     "id": 2440,
#     "name": "Nevada Wolf Pack",
#     "url": "/college-football/team/_/id/2440/nevada-wolf-pack"
#   },
#   {
#     "conference": "Mountain West",
#     "id": 167,
#     "name": "New Mexico Lobos",
#     "url": "/college-football/team/_/id/167/new-mexico-lobos"
#   },
#   {
#     "conference": "Mountain West",
#     "id": 21,
#     "name": "San Diego State Aztecs",
#     "url": "/college-football/team/_/id/21/san-diego-state-aztecs"
#   },
#   {
#     "conference": "Mountain West",
#     "id": 23,
#     "name": "San Jose State Spartans",
#     "url": "/college-football/team/_/id/23/san-jose-state-spartans"
#   },
#   {
#     "conference": "Mountain West",
#     "id": 2439,
#     "name": "UNLV Rebels",
#     "url": "/college-football/team/_/id/2439/unlv-rebels"
#   },
#   {
#     "conference": "Mountain West",
#     "id": 328,
#     "name": "Utah State Aggies",
#     "url": "/college-football/team/_/id/328/utah-state-aggies"
#   },
#   {
#     "conference": "Mountain West",
#     "id": 2751,
#     "name": "Wyoming Cowboys",
#     "url": "/college-football/team/_/id/2751/wyoming-cowboys"
#   },
#   {
#     "conference": "Pac-12",
#     "id": 9,
#     "name": "Arizona State Sun Devils",
#     "url": "/college-football/team/_/id/9/arizona-state-sun-devils"
#   },
#   {
#     "conference": "Pac-12",
#     "id": 12,
#     "name": "Arizona Wildcats",
#     "url": "/college-football/team/_/id/12/arizona-wildcats"
#   },
#   {
#     "conference": "Pac-12",
#     "id": 25,
#     "name": "California Golden Bears",
#     "url": "/college-football/team/_/id/25/california-golden-bears"
#   },
#   {
#     "conference": "Pac-12",
#     "id": 38,
#     "name": "Colorado Buffaloes",
#     "url": "/college-football/team/_/id/38/colorado-buffaloes"
#   },
#   {
#     "conference": "Pac-12",
#     "id": 2483,
#     "name": "Oregon Ducks",
#     "url": "/college-football/team/_/id/2483/oregon-ducks"
#   },
#   {
#     "conference": "Pac-12",
#     "id": 204,
#     "name": "Oregon State Beavers",
#     "url": "/college-football/team/_/id/204/oregon-state-beavers"
#   },
#   {
#     "conference": "Pac-12",
#     "id": 24,
#     "name": "Stanford Cardinal",
#     "url": "/college-football/team/_/id/24/stanford-cardinal"
#   },
#   {
#     "conference": "Pac-12",
#     "id": 26,
#     "name": "UCLA Bruins",
#     "url": "/college-football/team/_/id/26/ucla-bruins"
#   },
#   {
#     "conference": "Pac-12",
#     "id": 30,
#     "name": "USC Trojans",
#     "url": "/college-football/team/_/id/30/usc-trojans"
#   },
#   {
#     "conference": "Pac-12",
#     "id": 254,
#     "name": "Utah Utes",
#     "url": "/college-football/team/_/id/254/utah-utes"
#   },
#   {
#     "conference": "Pac-12",
#     "id": 264,
#     "name": "Washington Huskies",
#     "url": "/college-football/team/_/id/264/washington-huskies"
#   },
#   {
#     "conference": "Pac-12",
#     "id": 265,
#     "name": "Washington State Cougars",
#     "url": "/college-football/team/_/id/265/washington-state-cougars"
#   },
#   {
#     "conference": "SEC",
#     "id": 333,
#     "name": "Alabama Crimson Tide",
#     "url": "/college-football/team/_/id/333/alabama-crimson-tide"
#   },
#   {
#     "conference": "SEC",
#     "id": 8,
#     "name": "Arkansas Razorbacks",
#     "url": "/college-football/team/_/id/8/arkansas-razorbacks"
#   },
#   {
#     "conference": "SEC",
#     "id": 2,
#     "name": "Auburn Tigers",
#     "url": "/college-football/team/_/id/2/auburn-tigers"
#   },
#   {
#     "conference": "SEC",
#     "id": 57,
#     "name": "Florida Gators",
#     "url": "/college-football/team/_/id/57/florida-gators"
#   },
#   {
#     "conference": "SEC",
#     "id": 61,
#     "name": "Georgia Bulldogs",
#     "url": "/college-football/team/_/id/61/georgia-bulldogs"
#   },
#   {
#     "conference": "SEC",
#     "id": 96,
#     "name": "Kentucky Wildcats",
#     "url": "/college-football/team/_/id/96/kentucky-wildcats"
#   },
#   {
#     "conference": "SEC",
#     "id": 99,
#     "name": "LSU Tigers",
#     "url": "/college-football/team/_/id/99/lsu-tigers"
#   },
#   {
#     "conference": "SEC",
#     "id": 344,
#     "name": "Mississippi State Bulldogs",
#     "url": "/college-football/team/_/id/344/mississippi-state-bulldogs"
#   },
#   {
#     "conference": "SEC",
#     "id": 142,
#     "name": "Missouri Tigers",
#     "url": "/college-football/team/_/id/142/missouri-tigers"
#   },
#   {
#     "conference": "SEC",
#     "id": 145,
#     "name": "Ole Miss Rebels",
#     "url": "/college-football/team/_/id/145/ole-miss-rebels"
#   },
#   {
#     "conference": "SEC",
#     "id": 2579,
#     "name": "South Carolina Gamecocks",
#     "url": "/college-football/team/_/id/2579/south-carolina-gamecocks"
#   },
#   {
#     "conference": "SEC",
#     "id": 2633,
#     "name": "Tennessee Volunteers",
#     "url": "/college-football/team/_/id/2633/tennessee-volunteers"
#   },
#   {
#     "conference": "SEC",
#     "id": 245,
#     "name": "Texas A&M Aggies",
#     "url": "/college-football/team/_/id/245/texas-am-aggies"
#   },
#   {
#     "conference": "SEC",
#     "id": 238,
#     "name": "Vanderbilt Commodores",
#     "url": "/college-football/team/_/id/238/vanderbilt-commodores"
#   },
#   {
#     "conference": "Sun Belt",
#     "id": 2026,
#     "name": "Appalachian State Mountaineers",
#     "url": "/college-football/team/_/id/2026/appalachian-state-mountaineers"
#   },
#   {
#     "conference": "Sun Belt",
#     "id": 2032,
#     "name": "Arkansas State Red Wolves",
#     "url": "/college-football/team/_/id/2032/arkansas-state-red-wolves"
#   },
#   {
#     "conference": "Sun Belt",
#     "id": 324,
#     "name": "Coastal Carolina Chanticleers",
#     "url": "/college-football/team/_/id/324/coastal-carolina-chanticleers"
#   },
#   {
#     "conference": "Sun Belt",
#     "id": 290,
#     "name": "Georgia Southern Eagles",
#     "url": "/college-football/team/_/id/290/georgia-southern-eagles"
#   },
#   {
#     "conference": "Sun Belt",
#     "id": 2247,
#     "name": "Georgia State Panthers",
#     "url": "/college-football/team/_/id/2247/georgia-state-panthers"
#   },
#   {
#     "conference": "Sun Belt",
#     "id": 309,
#     "name": "Louisiana Ragin' Cajuns",
#     "url": "/college-football/team/_/id/309/louisiana-ragin-cajuns"
#   },
#   {
#     "conference": "Sun Belt",
#     "id": 6,
#     "name": "South Alabama Jaguars",
#     "url": "/college-football/team/_/id/6/south-alabama-jaguars"
#   },
#   {
#     "conference": "Sun Belt",
#     "id": 326,
#     "name": "Texas State Bobcats",
#     "url": "/college-football/team/_/id/326/texas-state-bobcats"
#   },
#   {
#     "conference": "Sun Belt",
#     "id": 2653,
#     "name": "Troy Trojans",
#     "url": "/college-football/team/_/id/2653/troy-trojans"
#   },
#   {
#     "conference": "Sun Belt",
#     "id": 2433,
#     "name": "UL Monroe Warhawks",
#     "url": "/college-football/team/_/id/2433/ul-monroe-warhawks"
#   }
# ]

# %%
print(json.dumps(parsed2, indent=2, sort_keys=True))
# Out:
# {
#   "conference": {
#     "103": "ACC",
#     "150": "ACC",
#     "152": "ACC",
#     "153": "ACC",
#     "154": "ACC",
#     "183": "ACC",
#     "221": "ACC",
#     "228": "ACC",
#     "2390": "ACC",
#     "258": "ACC",
#     "259": "ACC",
#     "52": "ACC",
#     "59": "ACC",
#     "87": "ACC",
#     "97": "ACC"
#   },
#   "name": {
#     "103": "Boston College Eagles",
#     "150": "Duke Blue Devils",
#     "152": "NC State Wolfpack",
#     "153": "North Carolina Tar Heels",
#     "154": "Wake Forest Demon Deacons",
#     "183": "Syracuse Orange",
#     "221": "Pittsburgh Panthers",
#     "228": "Clemson Tigers",
#     "2390": "Miami Hurricanes",
#     "258": "Virginia Cavaliers",
#     "259": "Virginia Tech Hokies",
#     "52": "Florida State Seminoles",
#     "59": "Georgia Tech Yellow Jackets",
#     "87": "Notre Dame Fighting Irish",
#     "97": "Louisville Cardinals"
#   }
# }

# %%
#acc_teams.json seems to organize their data as a list of dict

# %% [markdown]
# Suppose both files are read into memory and the number of teams is large, which data organization is more efficient to search a team by their team id?

# %%
# YOUR CODE HERE
#raise NotImplementedError()
#acc_teams.json is more efficient to search a team by their team id

# %% [markdown]
# ### Question 13. CSV file format.
#
# Write the `acc_teams` data frame into a csv file `acc_teams.csv`. (2 points)

# %%
# YOUR CODE HERE
#raise NotImplementedError()
acc_teams.to_csv('acc_teams.csv')

# %%
import os
assert os.path.exists('acc_teams.csv')

# %%
# !cat 'acc_teams.csv'
# Out:
# id,name,conference
# 103,Boston College Eagles,ACC
# 228,Clemson Tigers,ACC
# 150,Duke Blue Devils,ACC
# 52,Florida State Seminoles,ACC
# 59,Georgia Tech Yellow Jackets,ACC
# 97,Louisville Cardinals,ACC
# 2390,Miami Hurricanes,ACC
# 152,NC State Wolfpack,ACC
# 153,North Carolina Tar Heels,ACC
# 87,Notre Dame Fighting Irish,ACC
# 221,Pittsburgh Panthers,ACC
# 183,Syracuse Orange,ACC
# 258,Virginia Cavaliers,ACC
# 259,Virginia Tech Hokies,ACC
# 154,Wake Forest Demon Deacons,ACC

# %% [markdown]
# ### Question 14. Sort Arrays
#
# Sort the ACC teams by team names in alphabeta order and save the results in a list `sorted acc_team_names`. (2 points)

# %%
# YOUR CODE HERE
#raise NotImplementedError()
#print(acc_teams)
sorted_acc_team_names = acc_teams['name']
#print(sorted_acc_team_names)
sorted_acc_team_names = sorted_acc_team_names.sort_values()
print(sorted_acc_team_names)
#print(''.join([team[0] for team in sorted_acc_team_names]))
# Out:
# id
# 103           Boston College Eagles
# 228                  Clemson Tigers
# 150                Duke Blue Devils
# 52          Florida State Seminoles
# 59      Georgia Tech Yellow Jackets
# 97             Louisville Cardinals
# 2390               Miami Hurricanes
# 152               NC State Wolfpack
# 153        North Carolina Tar Heels
# 87        Notre Dame Fighting Irish
# 221             Pittsburgh Panthers
# 183                 Syracuse Orange
# 258              Virginia Cavaliers
# 259            Virginia Tech Hokies
# 154       Wake Forest Demon Deacons
# Name: name, dtype: object

# %%
### BEGIN TESTS
assert ''.join([team[0] for team in sorted_acc_team_names]) == 'BCDFGLMNNNPSVVW'
### END TESTS

# %% [markdown]
# ### Congratulations! You have finished Part A of the problem.
